# %% [markdown]
# ## jupyter-lab 실행 옵션
#
# jupyter-lab --ServerApp.iopub_data_rate_limit=100000000

# %%
# %run db_utils.py

# %%
from pprint import pprint

# %%
tt_1_info = {
    "category": "육가공품",
    "my_headers": {
        "referer": "https://www.coupang.com/np/categories/393760",
        "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.110 Safari/537.36"
    },
    "url": "https://www.coupang.com/np/categories/420234?channel=plp_C2&page={page_number}",
    "pages": range(1, 18),
    "table_type": 1,
    "stopwords": {
        "noun": ["세트", "팩", "산", "것", "냉동", "개", "냉장", "용", "내", "나", "수", "게", "말"],
        "adj": [],
        "adv": []
    }
}

tt_2_info = {
    "category": "조미수산가공품",
    "my_headers": {
        "referer": "https://www.coupang.com/np/categories/393760",
        "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.110 Safari/537.36"
    },
    "url": "https://www.coupang.com/np/categories/420266?channel=plp_C2&page={page_number}",
    "pages": range(1, 18),
    "table_type": 2,
    "stopwords": {
        "noun": ["팩", "산", "것", "냉동", "개", "냉장", "용", "내", "나", "수", "게", "말"],
        "adj": [],
        "adv": []
    }
}

tt_3_info = {
    "category": "유가공품",
    "my_headers": {
        "referer": "https://www.coupang.com/np/categories/393760",
        "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.110 Safari/537.36"
    },
    "url": "https://www.coupang.com/np/categories/435052?channel=plp_C2&page={page_number}",
    "pages": range(1, 18),
    "table_type": 3,
    "stopwords": {
        "noun": ["팩", "산", "것", "냉동", "개", "냉장", "용", "내", "나", "수", "게", "말"],
        "adj": [],
        "adv": []
    }
}

tt_4_info = {
    "category": "빵",
    "my_headers": {
        "referer": "https://www.coupang.com/np/categories/393760",
        "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.110 Safari/537.36"
    },
    "url": "https://www.coupang.com/np/categories/420376?channel=plp_C2&page={page_number}",
    "pages": range(1, 18),
    "table_type": 4,
    "stopwords": {
        "noun": ["입", "세트", "팩", "산", "것", "냉동", "개", "냉장", "용", "내", "나", "수", "게", "말"],
        "adj": [],
        "adv": []
    }
}

tt_5_info = {
    "category": "떡",
    "my_headers": {
        "referer": "https://www.coupang.com/np/categories/393760",
        "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.110 Safari/537.36"
    },
    "url": "https://www.coupang.com/np/categories/437835?channel=plp_C2&page={page_number}",
    "pages": range(1, 10),
    "table_type": 5,
    "stopwords": {
        "noun": ["입", "세트", "팩", "산", "것", "냉동", "개", "냉장", "용", "내", "나", "수", "게", "말"],
        "adj": [],
        "adv": []
    }
}

tt_6_info = {
    "category": "간편식품",
    "my_headers": {
        "referer": "https://www.coupang.com/np/categories/393760",
        "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.110 Safari/537.36"
    },
    "url": "https://www.coupang.com/np/categories/502492?channel=plp_C2&page={page_number}",
    "pages": range(1, 18),
    "table_type": 6,
    "stopwords": {
        "noun": ["입", "세트", "팩", "산", "것", "냉동", "개", "냉장", "용", "내", "나", "수", "게", "말"],
        "adj": [],
        "adv": []
    }
}


tt_7_info = {
    "category": "면류",
    "my_headers": {
        "referer": "https://www.coupang.com/np/categories/502492?channel=plp_C2",
        "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.110 Safari/537.36"
    },
    "url": "https://www.coupang.com/np/categories/502537?listSize=60&brand=&offerCondition=&filterType=&isPriceRange=false&minPrice=&maxPrice=&page={page_number}&channel=user&fromComponent=Y&selectedPlpKeepFilter=&sorter=bestAsc&filter=&component=502437&rating=0",
    "pages": range(1, 8),
    "table_type": 7,
    "stopwords": {
        "noun": ["인분", "입", "세트", "팩", "산", "것", "냉동", "개", "냉장", "용", "내", "나", "수", "게", "말"],
        "adj": [],
        "adv": []
    }
}

tt_8_info = {
    "category": "전분분말류",
    "my_headers": {
        "referer": "https://www.coupang.com/np/categories/195576",
        "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.110 Safari/537.36"
    },
    "url": "https://www.coupang.com/np/categories/195578?page={page_number}",
    "pages": range(1, 18),
    "table_type": 8,
    "stopwords": {
        "noun": ["믹스", "인분", "입", "세트", "팩", "산", "것", "냉동", "개", "냉장", "용", "내", "나", "수", "게", "말"],
        "adj": [],
        "adv": []
    }
}


tt_9_info = {
    "category": "다류",
    "my_headers": {
        "referer": "https://www.coupang.com/np/categories/195142",
        "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.110 Safari/537.36"
    },
    "url": "https://www.coupang.com/np/categories/195142?page={page_number}",
    "pages": range(1, 28),
    "table_type": 9,
    "stopwords": {
        "noun": ["믹스", "인분", "입", "세트", "팩", "산", "것", "냉동", "개", "냉장", "용", "내", "나", "수", "게", "말"],
        "adj": [],
        "adv": []
    }
}

# %%
tt_list = [
    tt_1_info, 
    tt_2_info, 
    tt_3_info, 
    tt_4_info, 
    tt_5_info, 
    tt_6_info, 
    tt_7_info, 
    tt_8_info, 
    tt_9_info,
]

# %%
for tt_info in tt_list:
    pprint(tt_info)
    total_data_list = coupang_crawler(tt_info)
    print(len(total_data_list))
    noun_list = extract_nouns(total_data_list, tt_info)
    print(len(noun_list))
    insert_wordlist(tt_info["table_type"], noun_list)
# Out:
# {'category': '육가공품',
#  'my_headers': {'referer': 'https://www.coupang.com/np/categories/393760',
#                 'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) '
#                               'AppleWebKit/537.36 (KHTML, like Gecko) '
#                               'Chrome/96.0.4664.110 Safari/537.36'},
#  'pages': range(1, 18),
#  'stopwords': {'adj': [],
#                'adv': [],
#                'noun': ['세트',
#                         '팩',
#                         '산',
#                         '것',
#                         '냉동',
#                         '개',
#                         '냉장',
#                         '용',
#                         '내',
#                         '나',
#                         '수',
#                         '게',
#                         '말']},
#  'table_type': 1,
#  'url': 'https://www.coupang.com/np/categories/420234?channel=plp_C2&page={page_number}'}
# ...
