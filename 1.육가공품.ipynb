# %%
import requests
import bs4
import time
import random

# %%
my_headers={"referer": "https://www.coupang.com/np/categories/393760",
     "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.110 Safari/537.36"
}

# %%
total_data_list=[]
for page_number in range (1,18):
    url="https://www.coupang.com/np/categories/420234?channel=plp_C2&page={}".format(page_number)
    res = requests.get(url=url, headers=my_headers)
    
    soup=bs4.BeautifulSoup(res.text)
    
    div_elements =soup.select("dd.descriptions > div.name")
    for e in div_elements:
        div_elements = e
        data_list=[]
        data_list.append(div_elements.text.strip())
        total_data_list.append(data_list)
    time.sleep(1)

# %%
total_data_list
# Out:
# [['이로우 국내산 소고기 1등급 등심 정육세트 1.2kg, 1세트'],
#  ['명장의맛 토마호크 프리미엄 스테이크 세트 (냉동), 1세트'],
#  ['건화한우다 한우 1등급 일품구이 250g x 3종 세트 (냉장), 1세트'],
#  ['미국산 찜갈비 선물세트 (냉동) + 부직포가방, 3.2kg, 1세트'],
#  ['목우촌 품격가득 흑돈 수제 2호 햄 선물세트, 1세트'],
#  ['블랙앵거스 모둠 선물세트 (냉장), 1.4kg, 1세트'],
#  ['미국산 프라임 냉장 구이용 소고기세트 (냉장), 1.2kg, 1세트'],
#  ['파머스팩 제주 돼지 4종 선물세트, 1세트'],
#  ['파머스팩 제주 흑돼지 4종 선물세트 (냉장), 1세트'],
#  ['67 고메 눈꽃 우대갈비 선물세트 (냉동), 900g, 3팩'],
#  ['설로인 한우 플래티넘 세트 2100g (냉장), 1세트'],
#  ['호주산 블랙앵거스 구이용 선물세트 (냉장), 1.44kg, 1세트'],
#  ['삼원가든 양념갈비 꽃살 세트 4팩 (냉동), 2000g, 1세트'],
#  ['횡성한우 1++등급 No 9 gourmet 세트 (냉장), 1.6kg, 1세트'],
#  ['경복궁 명품 한우 불고기 (냉동), 1000g, 2개'],
#  ['삼원가든 양념 꽃살 + 불고기 혼합세트 1700g (냉동), 1세트'],
#  ['강강술래 술래양념구이 2팩 선물세트 2호 (냉동), 1600g, 1개'],
#  ['곰곰 돌돌말이 무연골 대패 삼겹살 (냉동), 1kg, 1개입'],
#  ['곰곰 돌돌말이 무연골 대패 삼겹살, 750g, 2개입'],
#  ['곰곰 양념 소불고기 (냉장), 1kg, 1개'],
#  ['견우푸드 미국산 LA식 갈비 선물세트 (냉동), 3kg, 1개'],
#  ['설로인 한우 플래티넘 S10 세트 4000g (냉장), 1세트'],
#  ['경복궁 칼집 LA갈비 대 (냉동), 1kg, 2개'],
#  ['경복궁 시그니처 양념육 1kg x 4팩 세트 (냉동), 1세트'],
#  ['셰프초이스 춘천식닭갈비 (냉장), 1kg, 1개'],
#  ['모아미트 보리먹인 캐나다산 냉장 항정살 구이용 (냉장), 600g, 1개'],
#  ['셰프초이스 칼집 돼지왕구이, 1kg, 1개'],
#  ['수원축협 무항생제 특란, 1800g, 1개'],
#  ['견우마을 프라임 채끝 뉴욕 스테이크컷 (냉장), 350g, 1개'],
#  ['설로인 무항생제 인증 베이비로인 한우 1등급 우둔 이유식용 (냉장), 240g, 1개'],
#  ['횡성명품한우 꽃갈비살 1+등급 이상 (냉장), 200g, 1개'],
#  ['미국산 토마호크스테이크 (냉장), 500g, 1개'],
#  ['감동란 반숙계란 30구, 1500g, 1개'],
#  ['맛있닭 닭가슴살 볼 100g x 4종 x 3팩 세트 (냉동), 1세트'],
#  ['EXCELCUT 미국산 살치 스테이크 컷 (냉장), 400g, 1개'],
#  ['크리스탈 팜스 미국산 초이스 꽃갈비살 구이용 (냉장), 1kg, 1개'],
#  ['푸드랩플러스 미국산 프라임 립아이 등심 스테이크컷 (냉장), 300g, 1개'],
#  ['로켓프레시] 하이포크 꽃목심 (냉장), 500g, 2개'],
#  ['엑셀컷 토마호크 스테이크 (냉장), 500g, 1개'],
#  ['건화 1+ 한우 국거리용 세절 (냉장), 300g, 1개'],
#  ['포크빌포도먹은돼지 목심 수육용 (냉장), 1kg, 1개'],
#  ['푸드랩플러스 미국산 초이스 꽃갈비살 (냉장), 600g, 1개'],
#  ['설야멱적 노포백반 제육볶음, 800g, 1개'],
#  ['포크밸리 한돈 1등급이상 삼겹살 구이용 (냉장), 1kg, 1팩'],
#  ['도뜰 파머스팩 한돈 앞다리 수육용 (냉장), 1kg, 1개'],
#  ['도드람한돈 1등급 칼집 삼겹살 구이용 (냉장), 1kg, 1개'],
#  ['설로인 한우 안심 샤토브리앙 1++등급(8이상) 스테이크용 (냉장), 150g, 1팩'],
#  ['성진본고기 한우 보신 세트 (냉동), 4.5kg, 1박스'],
#  ['견우마을 미국산 소꽃갈비살구이 (냉장), 400g, 1개'],
#  ['호주산 LA 갈비 선물세트 (냉동), 2.8kg, 1개'],
#  ['SAVOR 호주산 블랙앵거스 치마살 구이용 (냉장), 400g, 1개'],
#  ['화담우 한우 불고기 (냉장), 500g, 1팩'],
#  ['화담우 한우 2등급 등심구이용 (냉장), 300g, 1팩'],
#  ['파머스팩 제주 돼지 뒷다리 다짐육 볶음용 (냉장), 1kg, 1개'],
#  ['굽네 오븐구이 통닭가슴살 오리지널 110g x 7팩 + 매콤바베큐 110g x 5팩 세트 (냉동), 1세트'],
#  ['횡성한우 양지 1+ 등급 이상 국거리용 (냉장), 300g, 1팩'],
#  ['화담우 한우 국거리 (냉장), 500g, 1팩'],
#  ['쉐프 파트너 미국산 블랙앵거스 부채살 스테이크용 (냉장), 400g, 1팩'],
#  ['호주산 냉장 램 숄더랙 구이용 (냉장), 400g, 1팩'],
#  ['횡성한우 1등급 등심 구이 (냉장), 200g, 1개'],
#  ['쉐프 파트너 미국산 초이스 살치살 스테이크용 (냉장), 400g, 1팩'],
#  ['설로인 한우 살치살 1++등급(8이상) 구이용 (냉장), 200g, 1팩'],
#  ['맛있닭 닭가슴살 수비드 스팀 100g x 2종 x 6팩 세트 (냉동), 1세트'],
#  ['횡성명품한우 갈비살 1+등급 이상(냉장), 200g, 1개'],
#  ['굽네 소스가 맛잇는 닭가슴살 슬라이스 화이트머쉬룸 120g x 4p + 레드크림커리 120g x 4p + 스파이시커리 120g x 4p 세트 (냉동), 1세트'],
#  ['67고메 우대 꽃갈비 (냉장), 900g, 1팩'],
#  ['모아미트 보리먹인 삼겹 목살 반반팩 구이용 (냉장), 1kg, 1개'],
#  ['설성목장 무항생제 인증 한우 1+등급 채끝 스테이크 (냉장), 200g, 1개'],
#  ['도드람한돈 1등급삼겹살 구이용 (냉장), 1000g, 1개'],
#  ['바디나인 촉촉한 한입 닭가슴살 탄두리맛 (냉동), 100g, 20팩'],
#  ['EXCELCUT 미국산 살치 시즈닝 스테이크 (냉장), 400g, 1개'],
#  ['미국산 살치살 스테이크 (냉장), 400g, 1개'],
#  ['녹색한우 무항생제 1+등급 등심 구이용 (냉장), 250g, 1개'],
#  ['남도화우 한우 암소 1등급 이상 다짐육 (냉장), 300g, 1개'],
#  ['횡성한우 제비추리 앞치마 업진안살 1+ 등급 이상 구이용모둠 (냉장), 200g, 1팩'],
#  ['대성축산 한우 소곱창 160g + 대창 160g + 염통 160g (냉동), 1세트'],
#  ['파머스팩 도뜰 한돈 목심 구이용 (냉장), 1kg, 1개'],
#  ['파머스팩 제주 흑돼지 미박앞다리 구이용 (냉장), 800g, 1개'],
#  ['녹색한우 무항생제 양지 덩어리 1+등급 (냉장), 250g, 1개'],
#  ['본가집 호주산 삶은 깐양 소위 (냉동), 1kg, 1개'],
#  ['횡성한우 1등급 등심 구이용 (냉장), 300g, 1개'],
#  ['농협 참한알 무항생제 인증 대란, 3120g, 1개'],
#  ['자연실록 무항생제 인증 닭봉 윗날개 (냉장), 1.5kg, 1개'],
#  ['햇살닭 카레닭가슴살 (냉동), 100g, 10팩'],
#  ['견우마을 프라임 부채살 스테이크컷 (냉장), 400g, 1개'],
#  ['생생포크 한돈 1등급 갈비 찜용 (냉장), 2kg, 1팩'],
#  ['미트포유 옛날 삼겹살 구이용 (냉동), 1kg, 1개'],
#  ['횡성한우 1+등급 채끝 구이용 (냉장), 200g, 1팩'],
#  ['더건강한 닭가슴살 소시지, 120g, 10개'],
#  ['하림 자연실록 무항생제 인증 닭다리 북채 (냉장), 500g, 3개'],
#  ['하이포크 한돈 삼겹살 (냉장), 1kg, 1개'],
#  ['도뜰 파머스팩 한돈 앞다리 찌개용 (냉장), 1000g, 1개'],
#  ['횡성한우 1등급 이상 얇은 불고기 (냉장), 300g, 1개'],
#  ['생생포크 한돈 1등급 등갈비 구이 찜용 (냉장), 1.4kg, 1팩'],
#  ['파머스팩 도뜰 한돈 삼겹살 구이용 (냉장), 1kg, 1개'],
#  ['크리스탈 팜스 미국산 프라임 꽃갈비살 구이용 (냉장), 400g, 1개'],
#  ['녹색한우 무항생제 1+등급 세절 국거리 (냉장), 250g, 1개'],
#  ['파머스팩 한돈 무항생제 1등급 암퇘지 삼겹 구이용 (냉장), 1kg, 1개'],
#  ['돈마루 한돈 삼겹살 구이용 (냉장), 1000g, 1개'],
#  ['선진포크한돈 1등급이상 목심 로스 (냉장), 1kg, 1팩'],
#  ['다향오리 오리로스 구이용 (냉장), 1kg, 1개'],
#  ['크리스탈 팜스 미국산 시즈닝 살치살 스테이크 (냉장), 400g, 1개'],
#  ['하이포크 앞다리 찌개용 (냉장), 500g, 2팩'],
#  ['횡성한우 1등급 사태 국거리용 (냉장), 300g, 1팩'],
#  ['모아미트 보리먹인 캐나다산 냉장 통목살 에어프라이어용 (냉장), 1kg, 1개'],
#  ['크리스탈 팜스 미국산 프라임 본갈비살 구이용 (냉장), 400g, 1개'],
#  ['쉐프파트너 쫄깃한 부채살 언양식 불고기 2p, 800g, 1개'],
#  ['크리스탈 팜스 미국산 프라임 토시살 구이용 (냉장), 400g, 1개'],
#  ['로켓프레시] 하이포크 꽃살구이 (냉장), 500g, 2개'],
#  ['맛있닭 닭가슴살 맛보기 16종 세트 패키지 (냉동), 1세트'],
#  ['햇살닭 저염훈제닭가슴살 플러스 (냉동), 100g, 20팩'],
#  ['돈마루 한돈 목심 구이용 (냉장), 1000g, 1개'],
#  ['파머스팩 듀록 한돈 무항생제 인증 프렌치렉뼈등심 구이용 (냉장), 600g, 1개'],
#  ['건화한우 1+ 등급 홍두깨 육전용 (냉장), 300g, 1개'],
#  ['참프레 순수 훈제 닭가슴살, 100g, 10봉'],
#  ['케이프그림 호주산 부채살 스테이크 (냉장), 400g, 1개'],
#  ['햇살닭 카레닭가슴살 (냉동), 100g, 20팩'],
#  ['목우촌 국내산 소고기 등심 구이용 (냉장), 300g, 1개'],
#  ['파머스팩 한돈 뼈없는 얇은삼겹살 구이용 무연골 (냉장), 600g, 1개'],
#  ['푸드랩플러스 미국산 대패 차돌박이 (냉동), 1kg, 1개'],
#  ['횡성한우 1+등급 등심 구이용 (냉장), 200g, 1팩'],
#  ['마니커 1등급 닭안심 (냉장), 1kg, 1개'],
#  ['선진포크한돈 1등급이상 삼겹살 로스 (냉장), 1kg, 1팩'],
#  ['곰곰 저염 훈제 닭가슴살 슬라이스 (냉동), 100g, 20개입'],
#  ['미국산 LA 꽃갈비 선물세트 (냉동) + 부직포가방, 2kg, 1세트'],
#  ['목우촌 프로포크 한돈 삼겹살 구이용 (냉장), 1kg, 1팩'],
#  ['포크밸리 한돈 1등급이상 목심 구이용 (냉장), 1kg, 1팩'],
#  ['오쿡 그릴 닭가슴살 스테이크 (냉동), 200g, 25팩'],
#  ['하이포크 목살 (냉장), 500g, 2팩'],
#  ['엑셀컷 토마호크 스테이크 (냉동), 500g, 1개'],
#  ['화담우 한우 앞다리살 1등급 다짐육 (냉장), 300g, 1개'],
#  ['목우촌 국내산 소고기 잡채용 (냉장), 300g, 1개'],
#  ['파머스팩 도뜰 한돈 도끼삼겹살 구이/숯불/에어프라이어용 (냉장), 600g, 1개'],
#  ['견우마을 미국산 부채살로스 (냉장), 400g, 1개'],
#  ['양지뜨레 무항생제 인증 사포닌을 먹고 자란 닭이 낳은 계란 15구, 780g, 1개'],
#  ['목우촌 국내산 소고기 채끝 구이용 (냉장), 300g, 1개'],
#  ['123푸드 양념돼지막창 1kg + 소스 80g x 2개 세트 (냉동), 1세트'],
#  ['횡성한우 1+등급 우둔 (냉장), 300g, 1개'],
#  ['횡성한우 1등급 이상 다짐육 (냉장), 300g, 1팩'],
#  ['쪄서 촉촉한 아침란, 50g, 30개'],
#  ['파머스팩 제주 흑돼지 미박앞다리 찌개용 (냉장), 800g, 1개'],
#  ['푸드랩플러스 미국산 프라임 채끝 스트립로인 스테이크 (냉장), 400g, 1개'],
#  ['횡성한우 안심 1등급 스테이크용 (냉장), 250g, 1팩'],
#  ['본고기 암소한우 1등급 국거리용 (냉장), 300g, 1개'],
#  ['참프레 순수 흑후추 닭가슴살, 100g, 10봉'],
#  ['도뜰한돈 파머스팩 한돈 등심 꽃살 (냉장), 1000g, 1개'],
#  ['포크밸리 한돈 무항생제 인증 뒷다리살 불고기용 (냉장), 1kg, 1팩'],
#  ['주원산오리 슬라이스 (냉장), 1kg, 1팩'],
#  ['주원산오리 싸먹는오리 슬라이스, 320g, 2개'],
#  ['6다이닝 미국산 오이스터블레이드 바로구이 (냉동), 400g, 2개'],
#  ['선진포크 한돈 간편한돈 큐브목심 스테이크 (냉장), 300g, 1팩'],
#  ['목우촌 프로포크 한돈 갈비 찜용 (냉장), 1kg, 1팩'],
#  ['목우촌 프로포크 한돈 삼겹살 수육용 (냉장), 1kg, 1팩'],
#  ['횡성한우 등심 1++등급(7이상) 구이용 (냉장), 200g, 1개'],
#  ['생생포크 한돈 대패 삼겹살 구이용 (냉동), 800g, 1팩'],
#  ['설성목장 무항생제 인증 한우 1++등급(7이상) 세절 국거리용 (냉장), 300g, 1개'],
#  ['요리락 양념 소 LA 갈비, 800g, 1개'],
#  ['설로인 한우 등심 1++등급(8이상) 구이용 (냉장), 200g, 1팩'],
#  ['횡성한우 홍두깨 1등급 이상 장조림용 (냉장), 300g, 1팩'],
#  ['도뜰 파머스팩 한돈 뒷다리 다짐용 (냉장), 1000g, 1개'],
#  ['횡성한우 1등급 양지 국거리용 (냉장), 300g, 1개'],
#  ['탐육 아리조나 바베큐폭립 (냉동), 450g, 1팩'],
#  ['햇살닭 저염훈제닭가슴살 플러스 (냉동), 100g, 10팩'],
#  ['곰곰 반숙란 50g (냉장), 30구'],
#  ['굽네 소스가 맛있는 닭가슴살 120g 4종 x 2개입 세트 960g (냉동), 1세트'],
#  ['포크밸리 갈비 1등급이상 찜용 (냉장), 1.5kg, 1팩'],
#  ['전통참한우 사태 덩어리 1등급 이상 수육 국거리 장조림용 (냉장), 400g, 1개'],
#  ['전통참한우 1+등급 등심 구이용 (냉장), 300g, 1개'],
#  ['햇살닭 흑미닭가슴살 (냉동), 100g, 10팩'],
#  ['맛있닭 맛보기 패키지 18팩 (냉동), 1세트'],
#  ['생생포크 한돈 삼겹살 수육용 (냉장), 1000g, 1팩'],
#  ['모아미트 보리먹인 암퇘지 목살 구이용 (냉장), 1kg, 1개'],
#  ['목우촌 국내산 소고기 사태 국거리용 (냉장), 300g, 1개'],
#  ['생생한우 1등급이상 등심 구이용 (냉장), 200g, 1개'],
#  ['돈마루한돈 뒷다리 다짐육 (냉장), 1kg, 1개'],
#  ['파머스팩 한돈 뒷다리 수육용 (냉장), 1kg, 1개'],
#  ['횡성한우 1등급 이상 정육세트 (냉동), 1세트'],
#  ['목우촌 국내산 소고기 우리아이 안심 (냉장), 300g, 1개'],
#  ['생생포크 한돈 앞다리살 수육용 (냉장), 1000g, 1팩'],
#  ['견우마을 호주산 곡물비육 토시살 구이용 (냉장), 300g, 1팩'],
#  ['선진 포크한돈 앞다리살 수육용 (냉장), 1kg, 1개'],
#  ['모아미트 보리먹인 캐나다산 삼겹살 에어프라이어용 (냉장), 1kg, 1팩'],
#  ['건화 1+ 한우 불고기, 300g, 1개'],
#  ['마이산 맥반석 구운란 30구, 900g, 2개'],
#  ['자연실록 무항생제 인증 닭윙 아랫날개, 1000g, 1개'],
#  ['파머스팩 도뜰 한돈 바베큐 목심 구이용 (냉장), 1kg, 1팩'],
#  ['포크밸리 항정살 구이용 (냉장), 500g, 1팩'],
#  ['설성목장 무항생제 인증 한우 1+등급 등심 구이용 (냉장), 200g, 1개'],
#  ['미트포유 오스트리아 삼겹살 8mm (냉동), 3kg, 1개'],
#  ['바디나인 촉촉한 한입 닭가슴살 탄두리맛 (냉동), 100g, 10팩'],
#  ['견우푸드 미국산 LA 갈비 (냉동), 1.5kg, 1개'],
#  ['모아미트 보리먹인 대패 삼겹살 (냉장), 1kg, 1팩'],
#  ['굳닭 닭가슴살 소세지 15팩 스페셜 세트 (냉동), 1세트'],
#  ['이로우 국내산 무항생제 소고기 치마살 구이용 (냉장), 200g, 1팩'],
#  ['크리스탈팜스 미국산 프라임부채살 구이용 (냉장), 400g, 1개'],
#  ['화담우 한우 부채살 2등급 롱스테이크용 (냉장), 300g, 1개'],
#  ['케이프그림 호주산 치마살 구이용 (냉장), 300g, 1개'],
#  ['견우마을 678 우대갈비 구이용 (냉동), 2kg, 1팩'],
#  ['곰곰 시즈닝 부채살 스테이크 (냉장), 400g, 1개'],
#  ['아빠가 만든 구운계란 60구, 2kg, 1개'],
#  ['성진본고기 한우 정육 1등급 이상 세트 1.65kg (냉동), 1세트'],
#  ['수원축협 구이란, 35g, 60개입'],
#  ['이로우 국내산 무항생제 육우 소고기 2등급 이유식용 (냉장), 300g, 1개'],
#  ['도드람한돈 1등급 등심꽃살 구이용 (냉장), 600g, 1개'],
#  ['진지 주당맛집 소곱창 (냉동), 180g, 1개'],
#  ['미국산 LA 꽃갈비 선물세트 (냉동) + 부직포가방, 2.8kg, 1세트'],
#  ['수원축산농협 한우 양지 세절 1+등급 국거리용 (냉장), 200g, 1개'],
#  ['요리락 양념 소 LA 갈비 (냉장), 1kg, 1개'],
#  ['화담우 한우 꼬리반골 선물세트 (냉동), 2kg, 2개'],
#  ['존쿡델리미트 비프 파스트라미 슬라이스햄, 100g, 3개'],
#  ['몬트락 무항생제 인증 제주 돼지 오겹살 구이용 (냉장), 500g, 1팩'],
#  ['곰곰 시즈닝 살치살 (냉장), 400g, 1개'],
#  ['녹색한우 무항생제 사태 덩어리 1+등급 (냉장), 250g, 1개'],
#  ['굽네 로드닭 닭가슴살 100g x 12팩 혼합세트 (냉동), 2세트, 3종'],
#  ['횡성한우 채끝 1등급 (냉장), 250g, 1팩'],
#  ['녹색한우 무항생제 불고기 1+등급 (냉장), 250g, 1개'],
#  ['햇살푸드 명작 수제햄 4호 (냉동) + 부직포가방, 1670g, 1세트'],
#  ['화담우 한우 불고기 (냉동), 500g, 1팩'],
#  ['설성목장 무항생제 인증 한우 앞다리 샤브샤브용 (냉동), 300g, 1개'],
#  ['햇살닭 페퍼콘 스팀 닭가슴살 플러스 (냉동), 100g, 8개'],
#  ['햇살닭 닭가슴살 패키지 200g x 6p + 150g x 2p (냉동), 2세트, 저염 훈제 2p + 페퍼콘 스팀 2p + 훈제 닭가슴살 바베큐 2p + 저염 수비드 + 흑마늘 수비드'],
#  ['주원산오리 통오리 (냉장), 1.8kg, 1봉'],
#  ['수원축협 무항생제 특란, 3600g, 1개'],
#  ['마니커 1등급 두마리 생닭 8호 (냉장), 700g, 2개입'],
#  ['목우촌 국내산 소고기 양지 세절 국거리용 (냉장), 300g, 1개'],
#  ['잇메이트 랭킹닭컴 소스 닭가슴살 슬라이스 7종 세트 (냉동), 1세트'],
#  ['셰프초이스 로제 닭갈비 1050g, 1개'],
#  ['돈마루한돈 목심 숯불구이용 (냉장), 1kg, 1개'],
#  ['횡성한우 1+등급 국거리용 (냉장), 300g, 1팩'],
#  ['국제식품 미국산 수입우갈비 탕갈비 갈비탕용 (냉동), 1kg, 3개'],
#  ['하이포크 국내산 돼지고기 뽈살 구이용 (냉동), 300g, 2개'],
#  ['국제식품 국내산 돈등뼈 감자탕용 3~5cm (냉동), 1kg, 3개'],
#  ['설성목장 무항생제 인증 한우 1+등급 치마살 구이용 (냉장), 200g, 1개'],
#  ['맛잽이식품 매운양념닭발 (냉동), 600g, 1개'],
#  ['목우촌 국내산 소고기 치마 (냉장), 200g, 1개'],
#  ['포크밸리 한돈 등갈비 찜용 / 구이용 (냉장), 1kg, 1팩'],
#  ['EXCELCUT 미국산 척아이롤 시즈닝 스테이크 (냉장), 400g, 1개'],
#  ['곰곰 1등급 두꺼운 삼겹살 구이용 (냉장), 1kg, 1개'],
#  ['크리스탈팜스 호주산 꽃갈비 LA 소갈비 선물세트 (냉동), 2kg, 1개'],
#  ['전통참한우 1등급 등심 스테이크용 300g + 소스 30g + 생와사비 3g + 허브솔트 3g (냉장), 1세트'],
#  ['화담우 한우 다짐육 (냉장), 500g, 1팩'],
#  ['자연실록 무항생제 인증 닭안심 (냉장), 1.5kg, 1개'],
#  ['본앤브레드 한우 모듬육 1++등급 (9)국거리용 (냉장), 200g, 1팩'],
#  ['셰프초이스 매실퐁당 소불고기, 1kg, 1팩'],
#  ['모아미트 미국산 돈삼겹 구이용 (냉장), 1kg, 1개'],
#  ['엑셀컷 미국산 등심 찹 스테이크 컷 (냉장), 400g, 1개'],
#  ['로켓프레시] 하이포크 뒷다리 다짐육 (냉장), 500g, 2개'],
#  ['푸드랩플러스 아스펜릿지 미국산 프라임 채끝 스트립로인 스테이크용 (냉장), 300g, 1개'],
#  ['곰곰 한돈 삼겹살 수육용 (냉장), 1000g, 1개'],
#  ['고메 호주산 프리미엄 양갈빗살 꼬치 구이용 (냉동), 200g, 2개'],
#  ['곰곰 1등급 칼집 삼겹살 구이용 (냉장), 1kg, 1개'],
#  ['파머스팩 듀록 한돈 무항생제 인증 눈꽃 목심 구이 에어프라이어용 (냉장), 500g, 1개'],
#  ['맛있닭 저염 닭가슴살 (냉동), 100g, 12팩'],
#  ['저스트 스테이크 호주산 곡물 등심 스테이크 (냉장), 350g, 1개'],
#  ['와이제이푸드 건강하게 구운란 60구, 2100g, 1개'],
#  ['목우촌 국내산 소고기 세절 국거리용 (냉장), 300g, 1개'],
#  ['설야멱적 양념소불고기 (냉장), 1.2kg, 1개'],
#  ['전통참한우 1+등급 갈비살 구이용 (냉장), 200g, 1개'],
#  ['전통참한우 불고기 2등급 (냉장), 300g, 1개'],
#  ['바디나인 내가 몸짱이 될 닭 스테이크 (냉동), 150g, 30팩'],
#  ['미국산 프라임 등심 스테이크 (냉장), 500g, 1개'],
#  ['굽네 로드닭 훈제 닭가슴살 슬라이스 제로 (냉동), 100g, 12팩'],
#  ['설로인 무항생제 인증 베이비로인 한우 1등급 안심 이유식용 (냉장), 240g, 1개'],
#  ['다향오리 트러플 닭가슴살, 600g, 1팩'],
#  ['올품 순살콤보 세트 닭가슴살 400g + 안심 400g + 다리살 400g (냉장), 1세트'],
#  ['목우촌 국내산 소고기 부채살 구이용 (냉장), 300g, 1개'],
#  ['주원산오리 통오리, 2.2kg, 1봉'],
#  ['횡성한우 채끝 1++등급(7이상) 스테이크용 (냉장), 200g, 1개'],
#  ['한돈 도뜰 돼지정육 모듬수육용 (냉장), 1.5kg, 1팩'],
#  ['햇살푸드 햇살닭 현미 닭가슴살 (냉동), 100g, 10팩'],
#  ['바디나인 내가 몸짱이 될 닭 스테이크 (냉동), 150g, 10팩'],
#  ['도드람한돈 1등급 두꺼운 삼겹살 구이용 (냉장), 1kg, 1팩'],
#  ['모아미트 호주산 업진살 (냉동), 600g, 1개'],
#  ['홈스쿡 미국산 소갈비살 (냉동), 300g, 2개'],
#  ['농협 참한알 무항생제 인증 특란, 3600g, 1개'],
#  ['횡성한우 1+등급 이상 깍둑등심 (냉장), 200g, 1개'],
#  ['도드람한돈 삼겹 목심 반반팩 (냉장), 1kg, 1팩'],
#  ['도드람한돈 삼겹 목심 등심꽃살 캠핑팩 (냉장), 1.3kg, 1팩'],
#  ['도누꼬기 LA 한쪽갈비 (냉동), 500g, 2팩'],
#  ['사조원 닭 볶음탕용 (냉장), 1000g, 2개'],
#  ['엑셀컷 우삼겹 구이용 2mm (냉동), 3kg, 1개'],
#  ['생생한우 1등급이상 채끝 구이용 (냉장), 200g, 1개'],
#  ['곰곰 호주산 소고기 치마살 구이용 (냉장), 300g, 1개'],
#  ['셰프초이스 한돈 양념 돼지불고기, 600g, 1개'],
#  ['선진포크 바른농장 한돈 동물복지 인증 삼겹살 로스 (냉장), 1kg, 1팩'],
#  ['진지 주당맛집 소특양 (냉동), 180g, 1개'],
#  ['곰곰 한돈 등갈비 찜/구이용 500g (냉장), 1개'],
#  ['설화우 1등급 이상 한우 정육 세절 국거리 (냉장), 300g, 1개'],
#  ['설로인 한우 채끝 1등급 구이용 (냉장), 200g, 1팩'],
#  ['횡성한우 사골 (냉동), 2kg, 1개'],
#  ['곰곰 직화 무뼈 닭발 (냉동), 160g, 3개'],
#  ['생생포크 한돈 1등급 삼겹살 구이용 (냉장), 1000g, 1팩'],
#  ['파머스팩 제주 돼지 미박앞다리 찌개용 (냉장), 800g, 1개'],
#  ['마니커 1등급 닭아랫날개 윙 (냉장), 1kg, 1개'],
#  ['곰곰 대패 우삼겹 800g (냉동), 1개'],
#  ['존쿡델리미트 컨츄리베이컨, 120g, 3개'],
#  ['횡성한우 1+등급 치마살 (냉장), 200g, 1팩'],
#  ['목우촌 국내산 소고기 양지 미절단 국거리용 (냉장), 300g, 1개'],
#  ['설야멱적 한우 양념 불고기, 600g, 1개'],
#  ['횡성명품한우 업진살 1등급 이상(냉장), 200g, 1개'],
#  ['주원산오리 BAKED 오리 파스트라미 (냉동), 180g, 1개'],
#  ['곰곰 현미 닭가슴살 스테이크, 100g, 15개'],
#  ['푸드랩플러스 미국산 초이스 아롱사태 찜 탕 수육용 (냉장), 500g, 1개'],
#  ['목우촌 국내산 소고기 우둔 장조림용 (냉장), 300g, 1개'],
#  ['푸드랩플러스 아스펜릿지 미국산 초이스 살치살 스테이크용 (냉장), 300g, 1개'],
#  ['하이포크 앞다리 불고기용 S, 1kg, 1개'],
#  ['횡성한우 1++등급 (7이상) 치마살 구이용 (냉장), 200g, 1개'],
#  ['주원산오리 건강한오리 다리살, 500g, 1개'],
#  ['파머스팩 제주 흑돼지 미박칼집삼겹살 구이용 (냉장), 500g, 1팩'],
#  ['하림 닭봉 윗날개 (냉장), 600g, 2개'],
#  ['푸드랩플러스 호주산 곡물비육 양지 국거리용 (냉장), 600g, 1개'],
#  ['셰프초이스 손수 포뜬 양념 돼지갈비 (냉장), 1.8kg, 1개'],
#  ['쉐프 파트너 더 맛있는 춘천식 닭갈비 (냉장), 1kg, 1팩'],
#  ['햇살푸드 명작 수제햄 선물세트 2호 (냉동), 1세트'],
#  ['전통참한우 사태 덩어리 수육 국거리 장조림용 (냉장), 400g, 1개'],
#  ['플레잇 프렌치드 램 숄더랙 (냉동), 500g, 1개'],
#  ['EXCELCUT 미국산 척아이롤 스테이크 컷 (냉장), 400g, 1개'],
#  ['설로인 한우 채끝 1++등급(8이상) 구이용 (냉장), 200g, 1팩'],
#  ['설성목장 무항생제 인증 한우 꼬리반골 탕용 (냉동), 1kg, 2팩'],
#  ['모아미트 보리먹인 암퇘지 삼겹살 구이용 (냉장), 1kg, 1개'],
#  ['횡성한우 1++(7이상) 국거리용 (냉장), 300g, 1개'],
#  ['화담우 한우 채끝 2등급 스테이크용 (냉장), 200g, 1개'],
#  ['자연실록 무항생제 인증 닭윙 아랫날개 (냉장), 1.5kg, 1개'],
#  ['목우촌 국내산 소고기 특수부위 모둠 (냉장), 400g, 1개'],
#  ['1등급 계란으로 만든 구운란 20구, 800g, 1개'],
#  ['횡성한우 1등급 국거리용 (냉장), 300g, 1개'],
#  ['파머스팩 듀록 한돈 무항생제 인증 앞다리 수육용 (냉장), 500g, 1개'],
#  ['이로우 국내산 무항생제 소고기 사태 국거리용 (냉장), 300g, 1팩'],
#  ['설로인 한우 등심 1등급이상 국거리용 (냉장), 200g, 1팩'],
#  ['곰곰 한돈 1등급 삼겹살 구이용 (냉장), 1kg, 1개'],
#  ['감동란 반숙계란 15구, 750g, 1개'],
#  ['횡성한우 1+등급 부채살 구이용 (냉장), 200g, 1팩'],
#  ['설로인 한우 채끝 슬라이스 1++등급(8이상) (냉장), 200g, 1팩'],
#  ['이로우 국내산 무항생제 소고기 양지 덩어리 국거리용 (냉장), 300g, 1팩'],
#  ['케이프라이드 진짜 한돈 돼지 갈비로 만든 수제 양념 돼지 불갈비, 1.5kg, 1개'],
#  ['횡성한우 1등급 이상 정육세트2호 (냉동), 1세트'],
#  ['오쿡 오리지날 닭가슴살 스테이크 (냉동), 200g, 25팩'],
#  ['마니커 1등급 닭윗날개 봉 (냉장), 1kg, 1개'],
#  ['하림 동물복지 유정란 30구, 1560g, 1개'],
#  ['굽네 로드닭 닭가슴살 100g x 12팩 혼합세트 (냉동), 1세트, 3종'],
#  ['햇살푸드 명작 수제햄 선물세트 1호 (냉동), 1세트'],
#  ['국제식품 국내산 돈후지 짜장카레용 1 x 1 x 1 cm (냉동), 1kg, 3개'],
#  ['마니커 1등급 닭다리살 정육 (냉장), 1kg, 1개'],
#  ['화담우 한우 안심 3등급 스테이크용 (냉장), 200g, 1개'],
#  ['크리스탈팜스 미국산 프라임 등심 구이용 (냉장), 500g, 1개'],
#  ['셰프초이스 맛있게 매운 돼지 갈비 (냉장), 1kg, 1개'],
#  ['일품 수제햄 4호 선물세트 (냉동), 1820g, 1세트'],
#  ['주원산오리 건강한오리 네모훈제, 400g, 2개'],
#  ['목우촌 국내산 소고기 안창살 (냉장), 200g, 1개'],
#  ['몬트락 무항생제 인증 제주 돼지 목심 구이용 (냉장), 500g, 1팩'],
#  ['설화우 1등급 이상 한우 샤브샤브용 (냉장), 300g, 1개'],
#  ['국제식품 국내산 돈갈비 찜용 (냉동), 1kg, 3개'],
#  ['마니커 1등급 두마리 생닭 11호 (냉장), 1000g, 2개입'],
#  ['주원산오리 무항생제 인증 건강한오리 슬라이스 (냉장), 800g, 1개'],
#  ['횡성한우 1+등급 이상 차돌박이 (냉동), 250g, 1개'],
#  ['마음가득 수제햄 1호 설날선물세트 (냉동), 2500g, 1세트'],
#  ['설로인 한우 꽃등심 1++등급(8이상) 구이용 (냉장), 200g, 1팩'],
#  ['SAVOR 호주산 와규 윗등심살 스테이크 (냉장), 600g, 1개'],
#  ['파머스팩 제주 흑돼지 미박삼겹살 에어프라이어용 (냉장), 500g, 1팩'],
#  ['횡성한우 우족 (냉동), 2kg, 1팩'],
#  ['해밀 동물복지 인증 자연을 닮은 계란 60구, 3120g, 1개'],
#  ['화산석 구운란 60구, 2.4kg, 1개'],
#  ['푸드랩플러스 호주산 곡물 살치살 스테이크 (냉장), 400g, 1개'],
#  ['본앤브레드 한우 업진살 1++등급 (9)구이용 (냉장), 200g, 1팩'],
#  ['설성목장 무항생제 인증 한우 1+ 채끝 구이용 (냉장), 200g, 1개'],
#  ['쉐프 파트너 호주산 블랙앵거스 부채살 구이용 (냉장), 400g, 1개'],
#  ['클래식 소고기육포 선물세트, 70g, 6개입'],
#  ['곰곰 칼집 돼지 왕구이 (냉장), 1000g, 1개'],
#  ['횡성한우 스지 (냉동), 1.2kg, 1개'],
#  ['파머스팩 한돈 모듬 구이용 (냉장), 1kg, 1개'],
#  ['곰곰 오리지날 닭가슴살 소시지 (냉동), 120g, 6개'],
#  ['이로우 국내산 무항생제 인증 소고기 다짐육 2등급 (냉장), 300g, 1개'],
#  ['햇살닭 고구마 닭가슴살 (냉동), 100g, 10팩'],
#  ['올품 토종대왕 닭볶음탕용 닭고기 (냉장), 1kg, 1팩'],
#  ['저스트 스테이크 미국산 프라임 살치살 스테이크 (냉장), 400g, 1개'],
#  ['크리스탈 팜스 미국산 프라임 안창살 구이용 (냉장), 400g, 1개'],
#  ['모아미트 옥수수먹인 미국산 냉장 통삼겹살 에어프라이용 (냉장), 1kg, 1팩'],
#  ['설화우 1등급 이상 한우 채끝 구이용 (냉장), 200g, 1개'],
#  ['푸드랩플러스 미국산 LA 꽃갈비 세트 (냉동), 1.4kg, 1개'],
#  ['고급진 티본 스테이크 (냉장), 450g, 1팩'],
#  ['정다운 오리주물럭 불고기맛, 800g, 1개'],
#  ['봄내푸드 춘천닭갈비 (냉동), 1kg, 2팩'],
#  ['횡성한우 1++(7이상) 불고기용 (냉장), 300g, 1개'],
#  ['올품 인기3종 세트 닭다리 400g + 윗날개 400g + 아랫날개 400g (냉장), 1세트'],
#  ['푸드랩플러스 호주산 곡물비육 앞다리 불고기 샤브샤브용 (냉장), 800g, 1개'],
#  ['로켓프레시] 이로우 무항생제 인증 국내산 육우 등심 찹스테이크용 (냉장), 300g, 1개'],
#  ['미국산 구이용 본갈비살 (냉장), 400g, 1개'],
#  ['남도화우 한우 암소 1등급 이상 국거리용 (냉장), 300g, 1개'],
#  ['해말금 돼지막창 양념 (냉동), 1kg, 1개'],
#  ['하림 닭가슴살 (냉장), 600g, 2개'],
#  ['이로우 국내산 무항생제 육우 소고기 차돌박이 2등급 구이용 (냉동), 300g, 1개'],
#  ['엑셀컷 미국산 척아이롤 찹 스테이크 컷 (냉장), 400g, 1개'],
#  ['하림 IFF 닭다리살 (냉동), 2000g, 1개'],
#  ['가농 1+ 등급란으로 만든 비타민 구운계란 30구, 1200g, 1개'],
#  ['이로우 국내산 무항생제 소고기 갈비살 구이용 (냉장), 200g, 1팩'],
#  ['선진 포크한돈 돌돌대패 삼겹살 (냉동), 1kg, 1개'],
#  ['농협 참한알 무항생제 인증 특란, 1800g, 1개'],
#  ['건화 한우 1++등급(9) 등심 구이용 (냉장), 300g, 1개'],
#  ['도드람한돈 1등급 항정살 구이용 (냉장), 300g, 1개'],
#  ['국제식품 한우사골 탕용 (냉동), 1kg, 3개'],
#  ['EXCELCUT 미국산 립아이 시즈닝 스테이크 (냉장), 300g, 1개'],
#  ['남도화우 1++ 양지 국거리용 세절 (냉장), 200g, 1개'],
#  ['엑셀컷 한번도 얼리지 않은 프리미엄 양념 소불고기 (냉장), 1kg, 1개'],
#  ['횡성한우 안심 1++등급(7이상) 스테이크용 (냉장), 200g, 1개'],
#  ['돈마루한돈 삼겹살 구이용 (냉장), 1kg, 1개'],
#  ['크리스탈팜스 호주산 곡물비육 소고기 안창살 구이용 (냉장), 300g, 1개'],
#  ['횡성한우 1등급 불고기용 (냉장), 300g, 1개'],
#  ['쉐프파트너 호주산 와규 불고기/샤브샤브용 (냉장), 500g, 1개'],
#  ['호주산 칠면조 Frozen Whole Turkey (냉동), 6kg, 1개'],
#  ['생생한우 1등급이상 등심 스테이크용 (냉장), 300g, 1개'],
#  ['수원축협 구이란, 35g, 30개입'],
#  ['파머스팩 듀록 한돈 무항생제 인증 목심 구이용 (냉장), 500g, 1개'],
#  ['몬트락 제주 흑돼지 앞다리 구이용 (냉장), 600g, 1개'],
#  ['참프레 순수 탄두리 닭가슴살, 100g, 10봉'],
#  ['선진포크한돈 안심 (냉장), 500g, 1개'],
#  ['선진포크한돈 뒷다리 불고기 (냉장), 1kg, 1개'],
#  ['[쿠팡 직수입] 육본 언양식 양념 소불고기 (냉동), 1kg, 1개'],
#  ['횡성한우 1등급 이상 등심불고기 (냉장), 200g, 1개'],
#  ['마니커 1등급 닭다리 북채 (냉장), 1kg, 1개'],
#  ['사조 오리바베큐 슬라이스, 500g, 2개'],
#  ['셰프초이스 손수 포뜬 양념 돼지갈비, 1kg, 1개'],
#  ['돈마루 한돈 목심 구이용 (냉장), 500g, 1개'],
#  ['생생포크 한돈 앞다리 찌개 (냉장), 800g, 1팩'],
#  ['포크밸리 한돈 무항생제 인증 갈비 찜용 (냉장), 1kg, 1팩'],
#  ['횡성한우 잡뼈 (냉동), 2kg, 1개'],
#  ['목우촌 프로포크 한돈 앞다리살 수육용 (냉장), 1kg, 1팩'],
#  ['곰곰 무항생제 신선한 특란, 60구'],
#  ['생생한우 1등급이상 치마살 구이용 (냉장), 200g, 1개'],
#  ['쉐프 파트너 미국산 프라임 척아이롤 소고기 스테이크용 (냉장), 500g, 1팩'],
#  ['설성목장 무항생제 인증 한우 모듬뼈 탕용 (냉동), 1kg, 2팩'],
#  ['횡성명품한우 1등급이상 목심 국거리용 (냉장), 300g, 1개'],
#  ['자연실록 무항생제 인증 닭봉 윗날개, 1000g, 1개'],
#  ['국제식품 국내산 돈후지 불고기용 6 x 5 x 0.3 cm (냉동), 1kg, 3개'],
#  ['미트포유 목살 돌돌이 2mm, 3kg, 1개'],
#  ['곰곰 언양식 소불고기 (냉장), 1kg, 1개'],
#  ['횡성한우 도가니 (냉동), 1.2kg, 1개'],
#  ['하림 IFF 닭 봉 (냉동), 2kg, 1개'],
#  ['설성목장 무항생제 인증 한돈 항정살 구이용 (냉장), 400g, 1개'],
#  ['횡성한우 1++등급 (7이상) 양지 절단 국거리용 (냉장), 200g, 1개'],
#  ['녹색한우 무항생제 채끝 1+등급 구이용 (냉장), 250g, 1개'],
#  ['파머스팩 듀록 한돈 무항생제 인증 목심 수육용 (냉장), 500g, 1개'],
#  ['생생한우 1등급이상 업진살 구이용 (냉장), 200g, 1개'],
#  ['육교시 한우 1등급 국거리용 세절 (냉장), 300g, 1개'],
#  ['마이셰프 버섯가득 소불고기전골, 905g, 1개'],
#  ['횡성명품한우 1등급이상 목심 불고기용 (냉동), 300g, 1개'],
#  ['파머스팩 듀록 한돈 무항생제 인증 항정살 구이용 (냉장), 300g, 1개'],
#  ['글래드 시그니처 램 양 프렌치 랙 (냉동), 400g, 1팩'],
#  ['본고기 암소한우 1등급 잡채용 (냉장), 300g, 1개'],
#  ['설화우 1등급 이상 한우 안심 스테이크용 (냉장), 200g, 1개'],
#  ['도드람한돈 1등급 안심 장조림용 (냉장), 500g, 1개'],
#  ['아임닭 BEST 실속 패키지 (냉동), 1세트'],
#  ['햇살닭 두부 닭가슴살 (냉동), 100g, 10팩'],
#  ['굽네 소스가 맛있는 닭가슴살 한입 볼 120g 토마토칠리 x 3팩 + 까르보나라 x 2팩 + 치즈할리피뇨 x 2팩 세트 840g (냉동), 1세트'],
#  ['EXCELCUT 미국산 립아이 스테이크 컷 (냉장), 300g, 1개'],
#  ['수원축산농협 한우 등심 1등급 스테이크용 (냉장), 300g, 1개'],
#  ['주원산오리 오리로스 (냉동), 1kg, 1개'],
#  ['파머스팩 유황먹인 한돈 앞다리 수육용 (냉장), 1000g, 1개'],
#  ['횡성한우 1등급 이상 등심정육 혼합세트 (냉장), 1세트'],
#  ['본고기 암소한우 1등급 양지세절국거리용 (냉장), 300g, 1개'],
#  ['곰곰 양념 소갈비 (냉장), 500g, 1개'],
#  ['선진포크 한돈 불꽃삼겹에어 (냉장), 500g, 1팩'],
#  ['하이포크 목심 찹스테이크용 (냉장), 500g, 2팩'],
#  ['파머스팩 도뜰 한돈 미박 삼겹살 수육용 (냉장), 500g, 1개'],
#  ['수원축산농협 한우 1등급 채끝 스테이크용 (냉장), 300g, 1개'],
#  ['오쿡 슬라이스 닭가슴살 까르보나라맛 100g x 3팩 + 로제맛 100g x 3팩 + 스파이시맛 100g x 3팩 + 갈비맛 100g x 3팩 + 카레맛 100g x 3팩 (냉동), 1세트'],
#  ['엑셀컷 우삼겹 돌돌이 2mm (냉동), 3kg, 1개'],
#  ['파머스팩 제주 돼지 미박삼겹살 구이용 (냉장), 500g, 1팩'],
#  ['전통참한우 2등급 등심 스테이크용 300g + 소스 30g + 생와사비 3g + 허브솔트 3g (냉장), 1세트'],
#  ['탐육 오세득 s 함박스테이크 (냉동), 380g, 1개'],
#  ['본앤브레드 한우 1++등급(9) 갈비살 구이용 (냉장), 200g, 1팩'],
#  ['마니커 국산 닭가슴살 (냉동), 1kg, 8봉'],
#  ['설로인 한우 안심 미니샤토 1등급 구이용 (냉장), 150g, 1팩'],
#  ['바디나인 촉촉한 한입 닭가슴살 탄두리맛 (냉동), 100g, 20팩'],
#  ['녹색한우 무항생제 안심 1+등급 구이용 (냉장), 250g, 1개'],
#  ['오스트리아산 왕건 돈삼겹살 구이용 4 x 5 x 0.5 cm (냉동), 3kg, 1개'],
#  ['화담우 한우 3등급 안심 찹스테이크용 (냉장), 200g, 1개'],
#  ['글래드 시그니처 램 양갈비 숄더랙 (냉동), 400g, 1팩'],
#  ['도뜰 파머스팩 한돈 앞다리 불고기용 (냉장), 1000g, 1개'],
#  ['횡성한우 1+등급 특수부위 구이용 (냉장), 200g, 1팩'],
#  ['화담우 한우 채끝 2등급 큐브스테이크용 (냉장), 200g, 1개'],
#  ['설화우 1등급 이상 한우 큐브안심 스테이크용 (냉장), 200g, 1개'],
#  ['포크빌 목심 구이용 1kg (냉장), 1개'],
#  ['아임닭 닭가슴살 프랑크 소시지 오리지널 (냉동), 120g, 12개'],
#  ['고메 호주산 프리미엄 양늑간살 구이용 (냉동), 400g, 1개'],
#  ['마니커 1등급 닭아랫날개 윙 (냉장), 600g, 1개'],
#  ['SAVOR 호주산 와규 윗등심살 스테이크 (냉장), 400g, 1개'],
#  ['모아미트 보리먹인 삼겹 목살 항정살 모둠팩 구이용 (냉장), 900g, 1개'],
#  ['주원산오리 건강한오리 가슴살, 500g, 1개'],
#  ['본고기 암소한우 1등급 사태국거리용 (냉장), 300g, 1개'],
#  ['횡성한우 1등급 이상 갈비세트 (냉동), 2.1kg, 1세트'],
#  ['설성목장 무항생제 인증 1등급 한우 꽃등심 구이용 (냉장), 200g, 1팩'],
#  ['설성목장 무항생제 인증 한우 1++등급(7이상) 꽃등심 구이용 (냉장), 200g, 1개'],
#  ['생생한우 1등급이상 양지 세절 국거리용 (냉장), 300g, 1개'],
#  ['맛기픈 수입산 벌집삼겹살 (냉동), 500g, 3개'],
#  ['올품 닭안심 (냉장), 400g, 3개'],
#  ['설로인 한우 차돌박이 1+등급 (냉장), 200g, 1팩'],
#  ['선진포크한돈 갈비찜 (냉장), 1kg, 1팩'],
#  ['쉐프파트너 호주산 꽃갈비살구이용 (냉장), 300g, 1개'],
#  ['생생한우 1등급이상 양지 덩어리 국거리용 (냉장), 300g, 1개'],
#  ['곰곰 한돈 앞다리살 수육용 1000g (냉장), 1개'],
#  ['소울 프리미엄 빌 미니 토마호크 스테이크 3인분 (냉동), 540g, 1개'],
#  ['도뜰 파머스팩 한돈 항정살 에어프라이어용 (냉장), 400g, 1개'],
#  ['베스틱 닭가슴살 소시지 훈제맛 3팩 + 마늘맛 3팩 + 고추맛 2팩 + 매콤치즈맛 2팩 + 카레맛 2팩 (냉동), 1세트'],
#  ['다향오리 열탄불고기 매콤한맛, 600g, 1개'],
#  ['횡성한우 1등급 부채살 구이용 (냉장), 200g, 1팩'],
#  ['햇살닭 닭가슴살 패키지 200g x 6p + 150g x 2p (냉동), 1세트, 저염 훈제 2p + 페퍼콘 스팀 2p + 훈제 닭가슴살 바베큐 2p + 저염 수비드 + 흑마늘 수비드'],
#  ['양념소불고기 세트 (냉동), 2kg, 1세트'],
#  ['설성목장 무항생제 인증 한우 1+등급 양지 세절 국거리용 (냉장), 200g, 1개'],
#  ['선진포크한돈 1등급이상 목심 로스 (냉장), 500g, 1팩'],
#  ['화담우 한우 본인 스테이크 티본 2등급 스테이크용 (냉동), 550g, 1팩'],
#  ['횡성한우 1+등급 불고기용 (냉장), 300g, 1팩'],
#  ['국제식품 덴마크산 수입돈삼겹 구이용 1cm (냉동), 1kg, 3개'],
#  ['곰곰 대패삼겹살(냉동), 500g, 3개'],
#  ['청정원 안주야 논현동포차 돈막창 (냉동), 450g, 1개'],
#  ['파머스팩 도뜰 한돈 토시살 구이용 (냉장), 600g, 1개'],
#  ['마니커에프앤지 버팔로치킨윙 (냉동), 1.2kg, 1개'],
#  ['생생포크 한돈 무항생제 인증 대패 삼겹살 구이용 (냉동), 500g, 1팩'],
#  ['설화우 1등급 이상 한우 채끝 스테이크용 (냉장), 200g, 1개'],
#  ['파머스팩 삼겹살 500g + 목살 500g + 갈매기살 500g + 등심꽃살 500g 모둠 구이 세트, 1세트'],
#  ['존쿡델리미트 담백한 베이컨 (냉동), 1kg, 1개'],
#  ['설로인 한우 1++등급(7이상) 불고기용 (냉장), 200g, 1팩'],
#  ['설로인 한우 꽃등심 1등급 구이용 (냉장), 200g, 1팩'],
#  ['쉐프 파트너 호주산 와규 업진안살 구이용 (냉장), 300g, 1팩'],
#  ['횡성한우 1++등급 (7이상) 등심 스테이크용 (냉장), 200g, 1개'],
#  ['설야멱적 수제포갈비구이 (냉장), 1.5kg, 1개'],
#  ['본고기 육교시 암소한우 1등급 등심 정육 혼합세트 (냉장), 1.2kg, 1세트'],
#  ['포크밸리 한돈 무항생제 인증 앞다리 불고기용 (냉장), 1kg, 1팩'],
#  ['마니커 1등급 닭안심 (냉장), 600g, 1개'],
#  ['맛잽이식품 닭불갈비 왕꼬지 (냉동), 600g, 1봉'],
#  ['롯데푸드 델리카 온 햄선물세트 2호, 1세트'],
#  ['하림 세마리 통닭 7호 (냉장), 1950g, 1개'],
#  ['크리스탈 팜스 미국산 초이스 시즈닝 부채살 스테이크 (냉장), 400g, 1개'],
#  ['전통참한우 1+등급 살치살 구이용 (냉장), 200g, 1개'],
#  ['설로인 한우 1등급 이상 숙성 등심 불고기 세트 1.2kg (냉장), 1세트'],
#  ['몬트락 제주 흑돼지 삼겹살 에어프라이어용 (냉장), 500g, 1개'],
#  ['정다운 오리로스 구이용 (냉장), 1kg, 1개'],
#  ['오뗄 수제햄 선물세트 특선1호, 1세트'],
#  ['설화우 1등급 이상 한우 우둔 국거리용 덩어리 (냉장), 300g, 1개'],
#  ['횡성한우 1+등급 설깃 샤브샤브 (냉동), 300g, 1개'],
#  ['허닭 프레시업 슬라이스 닭가슴살 훈제 (냉동), 100g, 10개'],
#  ['탐육 치즈 함박스테이크 (냉동), 380g, 1개'],
#  ['고메 호주산 프리미엄 양갈비살 구이용 (냉동), 400g, 1개'],
#  ['선진포크 한돈 불꽃등심에어 (냉장), 500g, 1팩'],
#  ['설로인 한우 1++등급(8이상) 꽃등심 스테이크용 (냉장), 300g, 1팩'],
#  ['설성목장 무항생제 인증 한우 1++등급(7이상) 채끝 스키야키용 (냉장), 200g, 1개'],
#  ['목우촌 프로포크 한돈 목심살 구이용 (냉장), 1kg, 1팩'],
#  ['무항생제 인증 햇살계란 대란 60구, 3120g, 1개'],
#  ['육식학 전통 쇠고기육포 선물세트, 480g, 1개'],
#  ['파머스팩 제주 돼지 칼집목심 구이용 (냉장), 500g, 1팩'],
#  ['돈마루 한돈 앞다리 찌개용 (냉장), 1000g, 1개'],
#  ['횡성한우 건강세트 우족 2kg + 사골 2kg (냉동) +부직포가방, 4kg, 1세트'],
#  ['이로우 국내산 무항생제 소고기 부채살 스테이크용 (냉장), 300g, 1팩'],
#  ['파머스팩 유황먹인 한돈 등심 카레용 (냉장), 800g, 1개'],
#  ['포크빌 삼겹살 수육용 (덩어리) 1kg (냉장), 1개'],
#  ['맛있닭 닭가슴살 큐브 100g x 2종 x 6팩 세트 (냉동), 1세트'],
#  ['남도화우 암소한우 1++등급 (7이상) 불고기용 (냉장), 300g, 1개'],
#  ['6다이닝 호주산 갈비탕용 소등갈비 (냉동), 2kg, 1개'],
#  ['6다이닝 미국산 살치살 바로구이 (냉동), 500g, 1팩'],
#  ['육교시 한우 1등급 안심 스테이크용 (냉장), 200g, 1개'],
#  ['곰곰 현미 닭가슴살 스테이크, 100g, 10개'],
#  ['제주 설성한돈 뽈살 (냉동), 300g, 2팩'],
#  ['홈스쿡 솔트에이징 소갈비살구이 (냉동), 600g, 1팩'],
#  ['곰곰 맥반석 구운란, 35g, 60구'],
#  ['이로우 국내산 무항생제 소고기 채끝 스테이크용 (냉장), 300g, 1팩'],
#  ['파머스팩 듀록 한돈 무항생제 인증 등심 잡채용 (냉장), 500g, 1개'],
#  ['도드람한돈 1등급 등심덧살 구이용 (냉장), 300g, 1개'],
#  ['설로인 베이비로인 한우 안심 1등급 이상 이유식용 (냉장), 240g, 1개'],
#  ['푸드랩플러스 아스펜릿지 미국산 프리미엄 앵거스 선물세트 1kg (냉장), 1세트'],
#  ['하이포크 뒷다리 불고기용 S, 1kg, 1개'],
#  ['목우촌 시그니처 수제6호, 1세트'],
#  ['곰곰 한우 1등급 국거리용 (냉장), 300g, 1개'],
#  ['설야멱적 한우 언양식 불고기, 600g, 1개'],
#  ['글래드호텔 호주산 프리미엄 양갈비 세트 (냉동), 1세트'],
#  ['하림 자연실록 무항생제 인증 닭 안심 (냉장), 350g, 2팩'],
#  ['화담우 한우 앞다리살 1등급 불고기용 (냉장), 300g, 1개'],
#  ['설성목장 무항생제 인증 한우 1+등급 토시살 구이용 (냉장), 200g, 1개'],
#  ['설성목장 무항생제 인증 한우 1++등급(7이상) 등심 구이용 (냉장), 200g, 1개'],
#  ['하이포크 청계 수제 꿀갈비 (냉동), 400g, 6개'],
#  ['선진 포크 한돈 등갈비 구이용 (냉장), 500g, 1개'],
#  ['슁켄하우스 코시롱 안심육포 선물세트 2개입, 360g, 1박스'],
#  ['킬코이640 호주산 곡물 부채살 샤브샤브 바로구이용 (냉장), 600g, 1개'],
#  ['6다이닝 이베리코 항정살 돼지고기 (냉동), 300g, 2개'],
#  ['수원축산농협 한우 갈비 정육 혼합 세트 (냉동), 1.7kg, 1세트'],
#  ['하림 닭다리살 정육 (냉장), 600g, 2개'],
#  ['진지 주당맛집 소막창 (냉동), 180g, 1개'],
#  ['엑셀컷 미국산 LA갈비 선물세트 2.8kg (냉동), 1세트'],
#  ['도뜰 무항생제 인증 듀록 눈꽃 삼겹살 500g + 뼈 등심 600g 간편 선물세트 (냉장), 1세트'],
#  ['도뜰 무항생제 인증 듀록 눈꽃 목심 500g + 뼈 등심 600g 간편 선물세트 (냉장), 1세트'],
#  ['곰곰 한돈 칼집 삼겹살, 500g, 2개'],
#  ['탐육 오리지널 생소시지 5p (냉동), 1kg, 1개'],
#  ['건화한우다 한우 1+ 등급 정육세트 (냉동), 2.4kg, 1세트'],
#  ['오늘차림 서울식 육수 소불고기 700g + 육수 300g + 당면 60g, 1세트'],
#  ['자연실록 무항생제 인증 닭안심, 1000g, 1개'],
#  ['셰프초이스 국내산 양념돼지갈비 (냉장), 1kg, 1개'],
#  ['쉐프파트너 호주산 와규 양지 국거리용 (냉장), 300g, 1개'],
#  ['포크밸리 한돈 무항생제 인증 목심 구이용 (냉장), 1kg, 1팩'],
#  ['설성목장 무항생제 인증 한우 1++등급(7이상) 채끝 구이용 (냉장), 200g, 1개'],
#  ['하림 닭안심 (냉장), 600g, 1팩'],
#  ['수원축산농협 한우 치마살 1+등급 구이용 (냉장), 200g, 1개'],
#  ['푸드밀리 매운양념닭발 (냉동), 400g, 2개'],
#  ['횡성한우 1++등급 (7이상) 사태 찜용 (냉장), 200g, 1개'],
#  ['설로인 한우 안심추리 1등급 구이용 (냉장), 150g, 1팩'],
#  ['곰곰 쫄깃한 편육 (냉장), 1.03kg, 1개'],
#  ['맛잽이식품 양념닭발 (냉동), 600g, 1봉'],
#  ['생생포크 한돈 뒷다리살 불고기용 (냉장), 1000g, 1팩'],
#  ['선진포크 바른농장 한돈 동물복지 인증 등심 돈까스 (냉장), 500g, 1팩'],
#  ['농협목우촌 국내산 육우 우족 (냉동), 2kg, 1개'],
#  ['설화우 1등급 이상 한우 정육 불고기용 (냉장), 300g, 1개'],
#  ['설로인 한우 1등급 이상 채끝 스테이크용 (냉장), 300g, 1팩'],
#  ['설성목장 무항생제 한우 1등급 안심 스테이크용 (냉장), 200g, 1개'],
#  ['모아미트 옥수수먹인 미국산 냉장 대패 삼겹살 (냉장), 1kg, 1팩'],
#  ['설성목장 무항생제 인증 1등급 한우 채끝 스테이크용 (냉장), 250g, 1팩'],
#  ['목우촌 시그니처 수제5호, 1세트'],
#  ['설성목장 무항생제 인증 한우 부채살 1등급 구이용 (냉장), 200g, 1개'],
#  ['맛있는녀석들 춘천닭갈비 (냉동), 1kg, 2개'],
#  ['노랑오리 오리훈제 슬라이스, 400g, 2개'],
#  ['설성목장 제주 설성한돈 특수부위 1.5kg 세트 (냉동), 1세트'],
#  ['본고기 암소한우 1등급 안심구이용 (냉장), 200g, 1팩'],
#  ['곰곰 호주산 소고기 안창살 구이용 (냉장), 300g, 1개'],
#  ['설로인 한우 1등급 이상 등심 실속 세트 600g (냉장), 1세트'],
#  ['목우촌 국내산 소고기 업진살 (냉장), 300g, 1개'],
#  ['전통참한우 1+등급 업진살 구이용 (냉장), 200g, 1개'],
#  ['횡성한우 1등급 이상 등심세트 (냉장), 1세트'],
#  ['국제식품 국내산 돈후지 채용 5 x 0.5 x 0.5 cm (냉동), 1kg, 3개'],
#  ['맛잽이식품 매운오리불고기 (냉동), 800g, 1봉'],
#  ['경복궁 칼집 LA갈비 (냉동), 600g, 2개'],
#  ['견우마을 호주산 홍두깨 육전샤브 (냉장), 400g, 1개'],
#  ['수원축협 한우 1등급 이상 냉장 국거리용 (냉장), 300g, 1개'],
#  ['하이포크 한돈 옛날삼겹살 (냉장), 1kg, 1팩'],
#  ['쉐프 파트너 호주산 와규 윗등심구이용 (냉장), 300g, 1개'],
#  ['설성목장 무항생제 인증 한우 1+등급 사태 국거리용 (냉장), 300g, 1개'],
#  ['다이닝스토리 이집고기 닭갈비 (냉동), 400g, 3개'],
#  ['횡성한우 1++ 등급(7이상) 터프 스테이크 우둔 설도 (냉장), 200g, 1개'],
#  ['오쿡 훈제 닭가슴살 스테이크 (냉동), 100g, 20팩'],
#  ['꿀맛나는세상 매실in양념 소불고기 (냉동), 300g, 3팩'],
#  ['생생한우 1등급이상 부채살 스테이크용 (냉장), 300g, 1개'],
#  ['다향오리 열탄불고기 불맛, 600g, 1개'],
#  ['육교시 한우 1등급 안심 구이용 (냉장), 200g, 1개'],
#  ['도뜰 제주흑돼지 삼겹살 500g + 목심살 500g 간편 선물세트 (냉장), 1세트'],
#  ['남도화우 한우 암소 1등급 이상 잡채용 (냉장), 300g, 1개'],
#  ['롯데푸드 델리카 온 햄선물세트 1호, 1세트'],
#  ['동원에프앤비 비엔나소시지, 1kg, 1개'],
#  ['아워홈 후레쉬햄 오리지널, 150g, 18개'],
#  ['코빅푸드 호주산 소고기 국거리 (냉동), 600g, 1팩'],
#  ['수원축산농협 한우 업진살 1+등급 구이용 (냉장), 200g, 1개'],
#  ['남도화우 암소한우 1++등급 (7이상) 국거리용 (냉장), 300g, 1개'],
#  ['설화우 1등급 이상 한우 양지 세절 국거리 (냉장), 300g, 1개'],
#  ['요리락 양념 소불고기, 600g, 1개'],
#  ['선진포크 바른농장 한돈 동물복지 인증 수육용 삼겹살 (냉장), 500g, 1팩'],
#  ['설성목장 무항생제 인증 한우 1+등급 제비추리 구이용 (냉장), 200g, 1개'],
#  ['설성목장 무항생제 인증 1등급 한우 등심 구이용 (냉장), 200g, 1팩'],
#  ['고급진 부채살 스테이크 (냉장), 250g, 1팩'],
#  ['다향오리 훈제오리 실속트윈팩, 400g, 2개입'],
#  ['곰곰 저염 훈제 닭가슴살 슬라이스 (냉동), 100g, 10개입'],
#  ['하림 IFF 닭 윙 (냉동), 2kg, 1개'],
#  ['설화우 한우 1등급 등심 스테이크용 (냉장), 350g, 1개'],
#  ['케이프그림 호주산 척아이롤 국거리 (냉장), 300g, 1개'],
#  ['존쿡델리미트 불꽃킬바사 소시지, 270g, 2개'],
#  ['글래드 시그니처 램 양 꽃갈비살 (냉동), 400g, 1팩'],
#  ['해밀 동물복지 인증 자연을 닮은 초란 30구, 1200g, 1개'],
#  ['쉐프 파트너 호주산 와규 플랭크 구이용 (냉장), 300g, 1팩'],
#  ['하이포크 삼겹살 보쌈용 (냉장), 500g, 2팩'],
#  ['목우촌 국내산 소고기 카레용 (냉장), 300g, 1개'],
#  ['설로인 한우 1등급이상 칼집 등심 (냉장), 200g, 1팩'],
#  ['강강술래 한우 양념불고기 2팩 선물세트 2호 (냉동), 1500g, 1개'],
#  ['설화우 1등급 이상 한우 큐브등심 스테이크용 (냉장), 200g, 1개'],
#  ['해밀 한입에 쫀득하고 맛있고 탱탱한 구운란 60구, 2160g, 1개'],
#  ['설성목장 무항생제 인증 한우 1+등급 양지 국거리용 (냉장), 200g, 1개'],
#  ['건화 한우 1++등급(9) 불고기용 (냉장), 300g, 1개'],
#  ['아임닭 닭가슴살 리얼갈릭맛 120g x 5입 + 청양고추맛 120g x 5입 + 통후추맛 120g x 5입 (냉동), 1세트'],
#  ['네추럴킹덤 닭가슴살 슬라이스 칠리맛 (냉동), 100g, 12개'],
#  ['굳닭 닭가슴살 맛보기 23팩 세트 (냉동), 1세트'],
#  ['다향오리 열탄불고기 불고기맛 400g + 매콤한맛 400g, 1세트'],
#  ['건화 1+등급 한우 불고기용 (냉장), 800g, 1개'],
#  ['강강술래 바베큐 폭립 (냉동), 450g, 1개'],
#  ['국제식품 국내산 돈전지 불고기용 6 x 5 x 0.3 cm (냉동), 1kg, 3개'],
#  ['삼원가든 불고기 세트 1호 4팩 (냉동), 1200g, 1세트'],
#  ['맛잽이식품 춘천닭갈비 (냉동), 800g, 1봉'],
#  ['무항생제 인증 이로우 국내산 소고기 2등급 세절 국거리용 (냉장), 300g, 1팩'],
#  ['곰곰 무항생제 신선한 대란, 60구'],
#  ['설성목장 무항생제 인증 한우 1+등급 안심 (냉장), 200g, 1개'],
#  ['제주설성한돈 프렌치렉 뼈등심 (냉장), 600g, 1팩'],
#  ['파머스팩 도뜰 한돈 도깨비살 구이용, 600g, 1팩'],
#  ['모아미트 차돌양지 샤브용 (냉동), 800g, 1개'],
#  ['본고기 암소한우 1등급 채끝구이용 (냉장), 200g, 1팩'],
#  ['고메 호주산 프리미엄 양등심 구이용 (냉동), 400g, 1개'],
#  ['본고기 한우 앞다리 시즈닝 스테이크, 200g, 1팩'],
#  ['이로우 육우 안심 3등급 스테이크용 (냉장), 300g, 1개'],
#  ['설로인 한우 1등급 이상 꽃등심 스테이크용 (냉장), 300g, 1팩'],
#  ['설로인 한우 갈비살 1등급 (냉장), 200g, 1팩'],
#  ['[쿠팡 직수입] 호주산 샤브샤브용 소고기 (냉동), 500g, 2팩'],
#  ['다이닝스토리 이집고기 고추장불고기 (냉동), 400g, 3개'],
#  ['파머스팩 듀록 한돈 무항생제 인증 앞다리 불고기용 (냉장), 500g, 1개'],
#  ['EXCELCUT 미국산 부채 시즈닝 스테이크 (냉장), 400g, 1개'],
#  ['수원축산농협 한우 제비추리 1+등급 구이용 (냉장), 200g, 1개'],
#  ['건화한우다 한우 1+등급 제수용 선물세트 (냉장), 1.6kg, 1세트'],
#  ['엑셀컷 미국산 소 다짐육 (냉동), 3kg, 1개'],
#  ['진지 주당맛집 편육 (냉동), 200g, 2봉'],
#  ['파머스팩 제주 흑돼지 미박삼겹살 구이용 (냉장), 500g, 1팩'],
#  ['정다운 허브를 담은 훈제오리, 1kg, 1개'],
#  ['왕건 호주산 소설도 다짐육 (냉동), 3kg, 1개'],
#  ['전통참한우 1+등급 양지 세절 장조림 / 국거리 / 수육용 (냉장), 300g, 1개'],
#  ['미트지엥 호주산 우안심 찹스테이크용 (냉장), 300g, 1팩'],
#  ['오쿡 훈제 닭가슴살 스테이크 (냉동), 100g, 40팩'],
#  ['육교시 한우 1등급 국거리용 덩어리 (냉장), 300g, 1개'],
#  ['본앤브레드 한우 1++등급(9) 치마살 구이용 (냉장), 200g, 1팩'],
#  ['햇살닭 닭가슴살 스테이크 맛보기 패키지 (냉동), 1세트, 아보카도 100g x 2p + 고구마 100g x 2p + 흑미 100g x 2p + 현미 100g x 2p + 두부 100g x 2p'],
#  ['햇살닭 흑마늘 수비드 닭가슴살 (냉동), 150g, 8개'],
#  ['하림 IFF 닭 안심살 (냉동), 2kg, 1개'],
#  ['선진 포크한돈 냉동삼겹살 구이용 (냉동), 1kg, 1개'],
#  ['파머스팩 제주 돼지 목심 구이용 (냉장), 500g, 1팩'],
#  ['미트포유 한입 대패 삼겹 2mm, 3kg, 1개'],
#  ['곰곰 오리지날 닭가슴살 슬라이스 (냉동), 120g, 10개입'],
#  ['쉐프파트너 호주산 와규 꾸리살 스테이크 (냉장), 300g, 1개'],
#  ['생생한우 1등급이상 산적용 (냉장), 300g, 1개'],
#  ['킬코이640 호주산 곡물 토시살 구이용 (냉장), 500g, 1개'],
#  ['남도화우 암소한우 1++등급 (7이상) 채끝 스테이크용 (냉장), 200g, 1개'],
#  ['국제식품 국내산 돈후지 탕수육용 5 x 1 x 1 cm (냉동), 1kg, 3개'],
#  ['더 맛있는 양념 소불고기, 1kg, 1팩'],
#  ['설성목장 무항생제 인증 한우 1++등급(7이상) 우둔 장조림용 (냉장), 200g, 1개'],
#  ['6다이닝 미국산 프라임 갈비본살 (냉동), 300g, 1개'],
#  ['곰곰 돌돌말이 대패 삼겹살 (냉동), 1kg, 1개'],
#  ['마니커 IQF 닭고기 안심살 (냉동), 2kg, 1개'],
#  ['크리스탈 팜스 시즈닝 살치살 스테이크 (냉장), 200g, 1개'],
#  ['건화한우다 1+등급 정육갈비 세트 2.5kg (냉동), 1세트'],
#  ['파머스팩 듀록 한돈 무항생제 인증 앞다리 구이용 (냉장), 500g, 1개'],
#  ['하림 IFF 닭가슴살 (냉동), 2kg, 1개'],
#  ['건화 1+ 한우 부채살 (냉장), 300g, 1개'],
#  ['바디나인 닭가슴살 든든어묵바 매콤한맛 (냉동), 70g, 10팩'],
#  ['하이포크 뒷다리 불고기용 (냉장), 500g, 2팩'],
#  ['무항생제 인증 건강한 닭이 낳은 신선한 계란 특란 90구, 5400g, 1개'],
#  ['강강술래 궁중 소갈비찜 (냉동), 800g, 1개'],
#  ['허닭 프레시업 슬라이스 닭가슴살 칠리맛 (냉동), 100g, 20개'],
#  ['본앤브레드 한우 1++등급(9) 안심 샤또브리앙 스테이크용 (냉장), 150g, 1팩'],
#  ['수원축산농협 한우 제비추리 1등급 구이용 (냉장), 300g, 1개'],
#  ['수원축산농협 한우 1+등급 등심 정육 세트 (냉장) 1.2kg, 구이용 등심 600g + 국거리용 600g, 1세트'],
#  ['횡성한우 1+ 사태 찜용 (냉장), 300g, 1개'],
#  ['본고기 한우 설도 시즈닝 스테이크, 200g, 1개'],
#  ['무항생제 인증 건강한 닭이 낳은 신선한 계란 대란 90구, 4680g, 1개'],
#  ['셰프초이스 돈육 고추장 불고기 (냉장), 2.4kg, 1개'],
#  ['쉐프 파트너 호주산 블랙앵거스 척아이롤 구이용 (냉장), 400g, 1개'],
#  ['잇메이트 슬라이스 소스 닭가슴살 토마토로제 (냉동), 150g, 9팩'],
#  ['설성목장 무항생제 인증 한우 1++등급(7이상) 안심 스테이크용 (냉장), 200g, 1개'],
#  ['국내산 왕건 돈목심 불고기용 6 x 4 x 0.3 cm (냉동), 3kg, 1개'],
#  ['남도화우 암소 포갈비 세트 (냉동), 1세트'],
#  ['파머스팩 듀록 한돈 무항생제 인증 삼겹살 수육용 (냉장), 500g, 1개'],
#  ['파머스팩 제주 돼지 미박뒷다리 불고기용 (냉장), 1kg, 1개'],
#  ['생생포크 한돈 등뼈 (냉동), 3kg, 1개'],
#  ['수원축산농협 한우 채끝 1+등급 스테이크용 (냉장), 200g, 1개'],
#  ['생생포크 한돈 앞다리살 불고기용 (냉장), 1000g, 1팩'],
#  ['곰곰 훈제 프랑크 닭가슴살 소시지 (냉동), 120g, 6개'],
#  ['설성목장 무항생제 인증 한우 설도 1등급 불고기용 (냉장), 300g, 1개'],
#  ['제주한우 무항생제 인증 등심 1등급 스테이크용 (냉장), 200g, 1개'],
#  ['명품조선막창 오븐에 구운 돼지막창 (냉동), 500g, 2팩'],
#  ['플레잇 미국산 드라이에이징 토마호크 스테이크용 (냉동), 500g, 1개'],
#  ['생생포크 한돈 무항생제 인증 앞다리살 수육용 (냉장), 500g, 1팩'],
#  ['마니커 1등급 두마리 영계 6호 (냉장), 500g, 2개입'],
#  ['화담우 한우 국거리 (냉동), 500g, 1팩'],
#  ['횡성한우 꼬리반골세트 (냉동) + 부직포가방, 4.5kg이상, 1세트'],
#  ['자연실록 무항생제 인증 닭가슴살, 1000g, 1개'],
#  ['엑셀컷 볼라전각 2mm (냉동), 3kg, 1개'],
#  ['킬코이640 호주산 곡물 척아이롤 구이용 (냉장), 600g, 1개'],
#  ['MASTER’S PICK 바베큐 풀드포크 (냉동), 450g, 1개'],
#  ['요리락 언양식소불고기 (냉장), 1kg, 1개'],
#  ['건화한우다 1+등급 등심 정육 세트 1.6kg (냉장), 1세트'],
#  ['햇살닭 레몬닭가슴살 (냉동), 100g, 20팩'],
#  ['생생포크 한돈 대패 삼겹살 구이용 (냉동), 500g, 1팩'],
#  ['전통참한우 1+등급 부채살 구이용 (냉장), 200g, 1개'],
#  ['본앤브레드 한우 등심덧살 1++등급 (9) 구이용 (냉장), 150g, 1팩'],
#  ['모아미트 미국산 돈목심 구이용 (냉장), 1kg, 1개'],
#  ['모아미트 삼겹살 목살 항정살 모둠팩 (냉동), 1.2kg, 1팩'],
#  ['제주 설성한돈 뒷고기롤 (냉동), 300g, 2팩'],
#  ['미트포유 오스트리아 칼집 삼겹살 13mm (냉동), 3kg, 1개'],
#  ['파머스팩 제주 흑돼지 등심 돈가스용 (냉장), 500g, 1개'],
#  ['동물복지 인증 자연을 닮은 계란 30구, 1350g, 1개'],
#  ['설로인 한우 꽃갈비살 1등급 (냉장), 200g, 1팩'],
#  ['호주산 쇠고기 앞다리 불고기용 (냉장), 500g, 1팩'],
#  ['도뜰 파머스팩 모듬구이 세트 1.6kg (냉장), 1세트'],
#  ['설성목장 무항생제 인증 한우 1+ 우둔 장조림용 (냉장), 300g, 1개'],
#  ['곰곰 소곱창 (냉동), 350g, 1개'],
#  ['미트지엥 호주산 곡물비육 갈비살 구이 400g (냉장), 1개'],
#  ['크리스탈 팜스 미국산 목살 보쌈용 (냉장), 1kg, 1팩'],
#  ['수원축산농협 한우 1+등급 잡채용 (냉장), 300g, 1팩'],
#  ['전통참한우 채끝 2등급 구이용 (냉장), 300g, 1개'],
#  ['맛있닭 소스 닭가슴살 스테이크 로스트 갈릭 150g x 3p + 매콤 토마토 150g x 3p + 토마토 150g x 2p + 자색고구마 까르보나라 150g x 2p + 흑마늘 150g x 2p 세트 (냉동), 1세트'],
#  ['사조 신선 통오리, 1.6kg, 1개'],
#  ['생생포크 한돈 목심 칼집구이용 (냉장), 1kg, 1팩'],
#  ['생생포크 한돈 통항정살 구이용 (냉장), 500g, 1개'],
#  ['하림 닭안심 (냉장), 600g, 2개'],
#  ['파머스팩 제주 돼지 미박삼겹살 에어프라이어용 (냉장), 500g, 1팩'],
#  ['도드람한돈 등심꽃살 구이용 1등급 (냉장), 1kg, 1개'],
#  ['곰곰 돌돌말이 대패 삼겹살, 750g, 2개'],
#  ['설성목장 무항생제 인증 한돈 삼겹살 구이용 (냉장), 400g, 1개'],
#  ['6다이닝 감자탕세트 (냉동), 2kg, 1개'],
#  ['마이산 맥반석 구운란 30구, 900g, 1개'],
#  ['전통참한우 1+등급 채끝 구이용 (냉장), 300g, 1개'],
#  ['아샤스마일 미국산 양념LA갈비 구이용 (냉동), 1kg, 1개'],
#  ['파머스팩 제주돼지 추억의 삼겹살 미박 (냉동), 800g, 1팩'],
#  ['돈마루 한돈 뒷다리 다짐육 (냉장), 600g, 1개'],
#  ['잇메이트 슬라이스 소스 닭가슴살 토마토스테이크 (냉동), 150g, 9팩'],
#  ['돈마루 한돈 등갈비 찜/구이용 (냉장), 500g, 1개'],
#  ['미트지엥 호주산 우안심 스테이크용 (냉장), 300g, 1팩'],
#  ['경복궁 궁중본갈비 세트 (냉동), 600g, 2팩'],
#  ['셰프초이스 한돈 양념 돼지 불고기, 1kg, 1개'],
#  ['마니커 IQF 닭고기 가슴살 (냉동), 3kg, 1개'],
#  ['파머스팩 도뜰 한돈 뒷다리살 불고기용 (냉장), 1kg, 1개'],
#  ['횡성한우 1++등급 (7이상) 우둔 산적용 (냉장), 200g, 1개'],
#  ['아임닭 소스 닭가슴살 슬라이스 양송이크림소스 130g x 2입 + 양념치킨소스 130g x 2입 + 갈릭스테이크소스 130g x 2입 (냉동), 1세트'],
#  ['본고기 암소한우 1등급 등심 구이용 (냉장), 200g, 1팩'],
#  ['푸드밀리 순한양념닭발 (냉동), 400g, 2개'],
#  ['코빅푸드 호주산 칼집 불갈비 (냉동), 1.2kg, 1개'],
#  ['케이프그림 호주산 척아이롤 스테이크 (냉장), 400g, 1개'],
#  ['제주 파머스팩 흑돼지 안심 덩어리, 600g, 1개'],
#  ['[쿠팡 직수입] 베타그로 숯불 스위트 앤 스파이시 닭꼬치 (냉동), 1kg, 1팩'],
#  ['국제식품 미국산 수입우갈비 CH 척갈비 갈비찜용 (냉동), 1kg, 3개'],
#  ['본고기 암소한우 1등급 불고기용 (냉장), 300g, 1팩'],
#  ['건강한 마음으로 만든 한돈간장불고기, 1.2kg, 1개'],
#  ['쉐프파트너 호주산 램 목살 시즈닝 (냉장), 300g, 1개'],
#  ['화담우 한우 등심 3등급 샤브샤브용 (냉동), 500g, 1개'],
#  ['푸딩팩토리 국내산 돼지고기 간장 제육볶음 (냉동), 200g, 3개'],
#  ['아그로수퍼 칠레산 칠면조 (냉동), 5.5kg, 1개'],
#  ['경복궁 양념 불고기 (냉동), 600g, 2개'],
#  ['몬트락 제주 흑돼지 삼겹살 구이용 (냉장), 300g, 1개'],
#  ['강강술래 궁중 돼지갈비찜 (냉동), 800g, 1개'],
#  ['오늘은너에게 꼬치닭 데리야끼맛 (냉동), 550g, 2봉'],
#  ['국제식품 국내산 돈삼겹살 보쌈용 5cm (냉동), 1kg, 3개'],
#  ['왕건 미국산 소삼겹양지 불고기용 0.2cm (냉동), 3kg, 1개'],
#  ['돈마루한돈 토시살 구이용 (냉장), 600g, 1개'],
#  ['존쿡델리미트 홀치킨 (냉동), 1500g, 1개'],
#  ['한성기업 통통소세지, 1kg, 10개'],
#  ['그린마운틴 호주산 송아지 다짐육 이유식용 (냉동), 180g, 1팩'],
#  ['카라라 호주산 와규 척아이롤 스테이크용 MB4+ (냉장), 300g, 1개'],
#  ['푸드밀리 안동신찜닭 (냉동), 700g, 2팩'],
#  ['그리팅 맛있는 연화식 더 부드러운 돼지갈비 김치찜 650g x 2p + 뼈까지 먹는 삼치김치조김 340g + 고등어김치조림 330g 선물세트 (냉동), 1세트'],
#  ['엉파 이베리코 베요타 갈비살 (냉동), 400g, 1개'],
#  ['바로 간편한 치떡치떡 강정 (냉동), 200g, 5개'],
#  ['미터스 참숯초벌막창 (냉동), 360g, 1개'],
#  ['올품 닭가슴살 세트(냉장), 1.2kg, 1세트'],
#  ['햇살닭 토마토 슬라이스 닭가슴살 (냉동), 100g, 8개입'],
#  ['이로우 국내산 무항생제 육우 업진살 2등급 구이용 (냉장), 200g, 1개'],
#  ['건강한 마음으로 만든 한돈간장불고기, 1.2kg, 1개'],
#  ['쉐프파트너 호주산 램 목살 시즈닝 (냉장), 300g, 1개'],
#  ['화담우 한우 등심 3등급 샤브샤브용 (냉동), 500g, 1개'],
#  ['푸딩팩토리 국내산 돼지고기 간장 제육볶음 (냉동), 200g, 3개'],
#  ['아그로수퍼 칠레산 칠면조 (냉동), 5.5kg, 1개'],
#  ['경복궁 양념 불고기 (냉동), 600g, 2개'],
#  ['몬트락 제주 흑돼지 삼겹살 구이용 (냉장), 300g, 1개'],
#  ['육교시 한우 1등급 불고기용 (냉장), 300g, 1개'],
#  ['사조원 동물복지 인증 1등급 닭윗날개 봉 (냉장), 300g, 2개'],
#  ['요리락 고기반반 간장 콤보팩 양념 소불고기 400g + 매실양념 돼지불고기 400g (냉장), 1세트'],
#  ['강강술래 궁중 돼지갈비찜 (냉동), 800g, 1개'],
#  ['오늘은너에게 꼬치닭 데리야끼맛 (냉동), 550g, 2봉'],
#  ['국제식품 국내산 돈삼겹살 보쌈용 5cm (냉동), 1kg, 3개'],
#  ['왕건 미국산 소삼겹양지 불고기용 0.2cm (냉동), 3kg, 1개'],
#  ['돈마루한돈 토시살 구이용 (냉장), 600g, 1개'],
#  ['존쿡델리미트 홀치킨 (냉동), 1500g, 1개'],
#  ['한성기업 통통소세지, 1kg, 10개'],
#  ['그린마운틴 호주산 송아지 다짐육 이유식용 (냉동), 180g, 1팩'],
#  ['카라라 호주산 와규 척아이롤 스테이크용 MB4+ (냉장), 300g, 1개'],
#  ['푸드밀리 안동신찜닭 (냉동), 700g, 2팩'],
#  ['그리팅 맛있는 연화식 더 부드러운 돼지갈비 김치찜 650g x 2p + 뼈까지 먹는 삼치김치조김 340g + 고등어김치조림 330g 선물세트 (냉동), 1세트'],
#  ['엉파 이베리코 베요타 갈비살 (냉동), 400g, 1개'],
#  ['바로 간편한 치떡치떡 강정 (냉동), 200g, 5개'],
#  ['경복궁 명품 소양념 본갈비 (냉동), 1000g, 2개'],
#  ['미터스 참숯초벌막창 (냉동), 360g, 1개'],
#  ['더블치즈 스테이크 110g x 10p (냉동), 1.1kg, 1개'],
#  ['미식명가 매콤 오징어 제육불고기 (냉동), 350g, 1개'],
#  ['올품 닭가슴살 세트(냉장), 1.2kg, 1세트'],
#  ['햇살닭 토마토 슬라이스 닭가슴살 (냉동), 100g, 8개입'],
#  ['이로우 국내산 무항생제 육우 업진살 2등급 구이용 (냉장), 200g, 1개'],
#  ['수원축산농협 한우 1+등급 장조림용 (냉장), 300g, 1팩'],
#  ['엑셀컷 알목심 돌돌이 2mm (냉동), 3kg, 1개'],
#  ['육진미가 한돈 시즈닝 숙성 등심꽃살 구이용 (냉동), 300g, 3개'],
#  ['올품 훈제 통닭 (냉동), 700g, 1팩'],
#  ['고메 호주산 프리미엄 양티본 구이용 (냉동), 400g, 1개'],
#  ['파머스팩 제주 흑돼지 미박뒷다리 구이용 (냉장), 500g, 1개'],
#  ['다이닝스토리 이집고기 간장불고기 (냉동), 400g, 3개'],
#  ['곰곰 한우 1+등급 불고기용 (냉장), 300g, 1개'],
#  ['성진 본고기 한우 1등급 이상 설도 샤브샤브용 (냉동), 350g, 1개'],
#  ['설로인 한우 살치살 1등급 이상 (냉장), 200g, 1개'],
#  ['파머스팩 도뜰 한돈 무항생제 인증 1등급이상 암퇘지 목심 에어프라이어용 (냉장), 500g, 1개'],
#  ['호주산 왕건 우척갈비 탕용 3 x 6 x 2 cm (냉동), 3kg, 1개'],
#  ['미터스 흑돼지 고추장불고기 2팩 (냉동), 1.1kg, 1개'],
#  ['청정원 널 응원해 프랑크, 600g, 1개'],
#  ['빌라르 하몽 베요타 이베리코 핸디컷 슬라이스, 100g, 1개'],
#  ['수원축산농협 한우 등심 1+등급 스테이크용 (냉장), 200g, 1팩'],
#  ['몬트락 제주 흑돼지 목심 에어프라이어용 (냉장), 500g, 1팩'],
#  ['횡성한우 꼬리반골 (냉동), 2.3kg, 1개'],
#  ['설성목장 무항생제 인증 1등급 한우 장조림용 (냉장), 250g, 1팩'],
#  ['푸드밀리 매운춘천닭갈비 (냉동), 600g, 2개'],
#  ['싱코호타스 하몽 드 벨로타 이베리코 베이컨, 70g, 1개'],
#  ['본가집 소갈비찜 대용량 (냉동), 800g, 1개'],
#  ['수원축산농협 한우 안심 1등급 스테이크용 (냉장), 300g, 1개'],
#  ['설로인 한우 등심 1등급 구이용 (냉장), 200g, 1팩'],
#  ['생생포크 한돈 1등급 삼겹살 구이용 (냉장), 1.4kg, 1팩'],
#  ['SUNTHEBUD 세호씨 수비드 닭가슴살 머스타드비네거 (냉동), 130g, 5개'],
#  ['토레온 이베리코 베요타 하몽 핸드컷 슬라이스 베이컨, 100g, 1개'],
#  ['양념갈비세트 (냉동), 1.6kg, 1세트'],
#  ['미트스탠다드 오늘차림 돼지짜글이 간장맛, 1210g, 1개'],
#  ['하이포크 매콤오돌뼈 볶음 (냉동), 180g, 2개'],
#  ['굽네 로드닭 저나트륨 후랑크 (냉동), 120g, 6개'],
#  ['미트포유 미국산 돈육 삼겹 찌개용 10 x 20 x 50 mm (냉동), 3kg, 1개'],
#  ['올계 유기가공식품인증 간장닭갈비 (냉동), 400g, 1개'],
#  ['국제식품 호주산 수입우목심 샤브샤브용 2mm (냉동), 1kg, 3개'],
#  ['이로우 국내산 소고기 사골 (냉동), 2.3kg, 1팩'],
#  ['미트포유 미국산 목전지 3mm 슬라이스 컷팅 (냉동), 3kg, 1개'],
#  ['국내산 왕건 돈등심 탕수육용 6 x 1 x 1 cm (냉동), 3kg, 1개'],
#  ['미트포유 오스트리아산 옛날 삼겹 (냉동), 3kg, 1개'],
#  ['본앤브레드 한우 등심로스 1++등급 (9)구이용 (냉장), 200g, 1팩'],
#  ['강강술래 술래 양념구이 (냉동), 800g, 1개'],
#  ['빌라르 이베리코 세보 팔레타 슬라이스햄, 100g, 1개'],
#  ['경복궁 궁중 본갈비 (냉동), 600g, 1개'],
#  ['초록햇살 수입산 수라예찬 치즈불닭 (냉동), 200g, 2팩'],
#  ['성진 본고기 한우 1등급 이상 목심 바로구이용 (냉동), 350g, 1개'],
#  ['국제식품 호주산 수입우목심 불고기용 1.4mm (냉동), 1kg, 3개'],
#  ['돼염 소금 양념 돼지 갈비 (냉동), 1kg, 1개'],
#  ['곰곰 한우 1등급 불고기용 (냉장), 300g, 1개'],
#  ['파머스팩 제주 돼지 1등급이상 암퇘지 미박앞다리 구이용 (냉장), 500g, 1개'],
#  ['생생포크 한돈 무항생제 인증 등심덧살 (냉장), 300g, 1팩'],
#  ['수원축협 한우 냉장 1++등급(7이상) 등심 스테이크용 300g, 1개'],
#  ['카라라 호주산 와규 척아이롤 큐브 스테이크용 MB4 (냉장), 300g, 1개'],
#  ['왕건 오스트리아산 돈삼겹 보쌈용 (냉동), 3kg, 1개'],
#  ['요리락 마포식 매콤갈매기살 구이용, 1kg, 1개'],
#  ['자연별곡 육식당 맵단 닭갈비 (냉동), 750g, 1개'],
#  ['국제식품 미국산 수입우갈비 CH 갈비찜용 (냉동), 1kg, 3개'],
#  ['송추가마골 순수 양념 소갈비 9대 (냉동), 750g, 1개'],
#  ['호주산 척 롤 샤브샤브 (냉동), 1개'],
#  ['국제식품 국내산 돈삼겹살 구이용 1cm (냉동), 1kg, 3개'],
#  ['한성기업 스모크햄S, 1kg, 10개'],
#  ['아임닭 양송이 크림소스 슬라이스 닭가슴살 (냉동), 130g, 8팩'],
#  ['오가니아 호주산 유기농인증 소고기 치마살 (냉동), 300g, 1개'],
#  ['부쉐리랩 호주 청정우 마리네이드 와규 스테이크 (냉동), 320g, 1개'],
#  ['이로우 국내산 육우 뼈갈비살 BBQ 2등급 구이용 (냉동), 600g, 1팩'],
#  ['설로인 한우 등심 1등급 이상 로스용 (냉장), 200g, 1개'],
#  ['맛있는녀석들 뚝배기불고기 (냉동), 410g, 2개'],
#  ['BLAZQUEZ 하몽 데 베요타 이베리코, 50g, 1개'],
#  ['백년초 소양념구이 (냉동), 1kg, 1팩'],
#  ['글랜인스 150 호주산 블랙앵거스 윗등심 구이 400g (냉장), 1개'],
#  ['남도화우 암소한우 1++등급 (7이상) 등심 구이용 (냉장), 200g, 1개'],
#  ['호주산 왕건 우목심 불고기용 6 x 5 x 0.2 cm (냉동), 3kg, 1개'],
#  ['돈마루한돈 삼겹살 숯불구이용 (냉장), 1kg, 1개'],
#  ['호주산 왕건 우앞다리살 잡채용 5 x 0.5 x 0.5 cm (냉동), 3kg, 1개'],
#  ['쉐프 파트너 호주산 찜갈비 (냉동), 2kg, 1개'],
#  ['왕건 국내산 돈목살 찌개용 1 x 1 x 4 cm (냉동), 3kg, 1개'],
#  ['닭집아들 직화닭오돌뼈 (냉동), 200g, 2개'],
#  ['토레온 하몽 이베리코 드 벨로타 슬라이스, 80g, 1개'],
#  ['맛기픈 고향미트 양념 소갈비찜 (냉동), 1kg, 1개'],
#  ['국내산 왕건 돈전지 다짐육 (냉동), 3kg, 1개'],
#  ['목우촌 페페롱 소시지, 120g, 10개'],
#  ['본앤브레드 한우 1++등급(9)본등심 구이용 (냉장), 150g, 1팩'],
#  ['왕건 호주산 소목심 잡채용 5 x 0.5 x 0.5 cm (냉동), 3kg, 1개'],
#  ['존쿡델리미트 하몽 이베리코 베요타 핸드컷, 40g, 1개'],
#  ['올품 닭안심 통살 스테이크 파슬리 (냉동), 900g, 1개'],
#  ['그린마운틴 호주산 송아지 보섭살 스테이크용 (냉장), 250g, 1개'],
#  ['도드람한돈 삼겹살 구이용 냉삼맛집 (냉동), 1200g, 1팩'],
#  ['국내산 왕건 돈전지 불고기용 두께 0.3cm (냉동), 3kg, 1개'],
#  ['오늘은너에게 꼬치닭 매운맛 (냉동), 550g, 2봉'],
#  ['6다이닝 이베리코 베요타 갈비살 (냉동), 300g, 1개'],
#  ['맛있는테이블 한돈 토마호크 스테이크 + 소스 5g (냉동), 305g, 1개'],
#  ['아임닭 안심 프랑크 오리지널 소시지 2개입 (냉동), 120g, 8개'],
#  ['청정원 안주야 논현동포차 양갈비 (냉동), 400g, 1개'],
#  ['엑셀컷 볼라전각 돌돌이 2mm (냉동), 3kg, 1개'],
#  ['올품 닭가슴살 한입 스테이크 파슬리 (냉동), 900g, 1개'],
#  ['맛잽이식품 닭불갈비 (냉동), 900g, 1봉'],
#  ['왕건 국내산 돈삼겹 구이용 0.5cm (냉동), 3kg, 1개'],
#  ['하이포크 한돈 삼겹살 구이용 (냉동), 500g, 1팩'],
#  ['국제식품 한우꼬리반골 탕용 (냉동), 1kg, 3개'],
#  ['선진포크한돈 앞다리살 찌개 (냉장), 500g, 1팩'],
#  ['호주산 왕건 우앞다리살 짜장카레용 1.5 x 1.5 x 1.5 cm (냉동), 3kg, 1개'],
#  ['파머스팩 듀록 한돈 무항생제 인증 갈매기살 구이용 (냉장), 300g, 1개'],
#  ['자연에찬 국내산 달콤 닭정육 (냉동), 500g, 1개'],
#  ['왕건 국내산 돈목살 보쌈용 (냉동), 3kg, 1개'],
#  ['햇살닭 레몬닭가슴살 (냉동), 100g, 10팩'],
#  ['화담우 한우 본인 스테이크 엘본 2등급 스테이크용 (냉동), 450g, 1팩'],
#  ['THE 부드러운 육포 스파이시 30g, 4입'],
#  ['명품조선막창 과일숙성 돼지생막창 (냉동), 500g, 2팩'],
#  ['파머스팩 한돈 미박앞다리 찌개용 (냉장), 500g, 1개'],
#  ['본고기 한우 1등급 우둔 샤브샤브용 (냉동), 350g, 1개'],
#  ['소울 참나무에 두번 구운 훈연막창 (냉동), 410g, 1개'],
#  ['그린쉘 복닭복닭 데리야끼치킨 (냉동), 200g, 12개'],
#  ['강강술래 강강 양념구이 (냉동), 750g, 1개'],
#  ['모르타델라 위드 피스타치오 슬라이스햄, 120g, 2개'],
#  ['건화다이닝 한우 광양 불고기 구이 (냉동), 300g, 1개'],
#  ['국제식품 국내산 돈목살 수육용 5cm (냉동), 1kg, 3개'],
#  ['도드람한돈 LA식 갈비 1200g (냉동), 1개'],
#  ['베허 하몽 이베리코 슬라이스 햄, 100g, 1개'],
#  ['호주산 왕건 우양지 샤브용 6 x 5 x 0.1 cm (냉동), 1개'],
#  ['파머스팩 제주 돼지 대패삼겹살 구이용 (냉동), 800g, 1팩'],
#  ['6다이닝 이베리코 삼겹살 (냉동), 300g, 1팩'],
#  ['그린쉘 국물닭발 (냉동), 500g, 8개'],
#  ['펀쿡 곱도리탕 (냉동), 750g, 1개'],
#  ['NOEL 초리조 슬라이스, 80g, 3개'],
#  ['이플원 소불고기 900g + 파채 100g (냉동), 1세트'],
#  ['수원축산농협 한우 1등급 산적용 (냉장), 300g, 1개'],
#  ['미스터갈비 제육볶음 (냉동), 400g, 1개'],
#  ['파머스팩 한돈 버크셔 흑돼지 미박삼겹살 구이용 (냉장), 800g, 1개'],
#  ['왕건 호주산 소앞다리살 채용 5 x 0.3 x 0.3 cm (냉동), 3kg, 1개'],
#  ['생생포크 한돈 안심 탕수육용 (냉장), 400g, 1팩'],
#  ['아임닭 안심 프랑크 소시지 단호박 고구마 2개입 (냉동), 120g, 8개'],
#  ['그린마운틴 호주산 송아지 채끝 스테이크용 (냉장), 200g, 1팩'],
#  ...]

# %%
import pandas as pd
df=pd.DataFrame(total_data_list)

# %%
df.to_csv('wordtext1.txt',index=False)

# %%
from konlpy.tag import Twitter 
from collections import Counter

# %%
file = open('wordtext.txt', 'r', encoding="UTF-8")

lists = file.readlines()

file.close()

#lists

# %%
twitter = Twitter() 
morphs = [] 

for sentence in lists: 
    morphs.append(twitter.pos(sentence)) 
print(morphs)
# Out:
# [[('0', 'Number'), ('\n', 'Foreign')], [('"', 'Punctuation'), ('이', 'Determiner'), ('로우', 'Noun'), ('국내', 'Noun'), ('산', 'Noun'), ('소고기', 'Noun'), ('1등', 'Number'), ('급', 'Foreign'), ('등심', 'Noun'), ('정육', 'Noun'), ('세트', 'Noun'), ('1.2', 'Number'), ('kg', 'Alpha'), (',', 'Punctuation'), ('1', 'Number'), ('세트', 'Noun'), ('"', 'Punctuation'), ('\n', 'Foreign')], [('"', 'Punctuation'), ('명장', 'Noun'), ('의', 'Josa'), ('맛', 'Noun'), ('토마호크', 'Noun'), ('프리미엄', 'Noun'), ('스테이크', 'Noun'), ('세트', 'Noun'), ('(', 'Punctuation'), ('냉동', 'Noun'), ('),', 'Punctuation'), ('1', 'Number'), ('세트', 'Noun'), ('"', 'Punctuation'), ('\n', 'Foreign')], [('"', 'Punctuation'), ('목', 'Noun'), ('우촌', 'Noun'), ('품격', 'Noun'), ('가득', 'Noun'), ('수제', 'Noun'), ('1', 'Number'), ('호', 'Noun'), ('햄', 'Noun'), ('선물', 'Noun'), ('세트', 'Noun'), (',', 'Punctuation'), ('1', 'Number'), ('세트', 'Noun'), ('"', 'Punctuation'), ('\n', 'Foreign')], [('"', 'Punctuation'), ('건화', 'Noun'), ('한우', 'Noun'), ('다', 'Josa'), ('한우', 'Noun'), ('1등', 'Number'), ('급', 'Foreign'), ('일품', 'Noun'), ('구이', 'Noun'), ('250', 'Number'), ('g', 'Alpha'), ('x', 'Alpha'), ('3', 'Number'), ('종', 'Noun'), ('세트', 'Noun'), ('(', 'Punctuation'), ('냉장', 'Noun'), ('),', 'Punctuation'), ('1', 'Number'), ('세트', 'Noun'), ('"', 'Punctuation'), ('\n', 'Foreign')], [('"', 'Punctuation'), ('목', 'Noun'), ('우촌', 'Noun'), ('품격', 'Noun'), ('가득', 'Noun'), ('흑', 'Adverb'), ('돈', 'Noun'), ('수제', 'Noun'), ('2', 'Number'), ('호', 'Noun'), ('햄', 'Noun'), ('선물', 'Noun'), ('세트', 'Noun'), (',', 'Punctuation'), ('1', 'Number'), ('세트', 'Noun'), ('"', 'Punctuation'), ('\n', 'Foreign')], [('"', 'Punctuation'), ('미국', 'Noun'), ('산', 'Noun'), ('찜', 'Noun'), ('갈비', 'Noun'), ('선물', 'Noun'), ('세트', 'Noun'), ('(', 'Punctuation'), ('냉동', 'Noun'), (')', 'Punctuation'), ('+', 'Punctuation'), ('부직포', 'Noun'), ('가방', 'Noun'), (',', 'Punctuation'), ('3.2', 'Number'), ('kg', 'Alpha'), (',', 'Punctuation'), ('1', 'Number'), ('세트', 'Noun'), ('"', 'Punctuation'), ('\n', 'Foreign')], [('"', 'Punctuation'), ('블랙', 'Noun'), ('앵거스', 'Noun'), ('모', 'Noun'), ('둠', 'Verb'), ('선물', 'Noun'), ('세트', 'Noun'), ('(', 'Punctuation'), ('냉장', 'Noun'), ('),', 'Punctuation'), ('1.4', 'Number'), ('kg', 'Alpha'), (',', 'Punctuation'), ('1', 'Number'), ('세트', 'Noun'), ('"', 'Punctuation'), ('\n', 'Foreign')], [('"', 'Punctuation'), ('미국', 'Noun'), ('산', 'Noun'), ('프라임', 'Noun'), ('냉장', 'Noun'), ('구', 'Modifier'), ('이용', 'Noun'), ('소고기', 'Noun'), ('세트', 'Noun'), ('(', 'Punctuation'), ('냉장', 'Noun'), ('),', 'Punctuation'), ('1.2', 'Number'), ('kg', 'Alpha'), (',', 'Punctuation'), ('1', 'Number'), ('세트', 'Noun'), ('"', 'Punctuation'), ('\n', 'Foreign')], [('"', 'Punctuation'), ('파머', 'Noun'), ('스팩', 'Noun'), ('제주', 'Noun'), ('돼지', 'Noun'), ('4', 'Number'), ('종', 'Noun'), ('선물', 'Noun'), ('세트', 'Noun'), (',', 'Punctuation'), ('1', 'Number'), ('세트', 'Noun'), ('"', 'Punctuation'), ('\n', 'Foreign')], [('"', 'Punctuation'), ('파머', 'Noun'), ('스팩', 'Noun'), ('제주', 'Noun'), ('흑', 'Adverb'), ('돼지', 'Noun'), ('4', 'Number'), ('종', 'Noun'), ('선물', 'Noun'), ('세트', 'Noun'), ('(', 'Punctuation'), ('냉장', 'Noun'), ('),', 'Punctuation'), ('1', 'Number'), ('세트', 'Noun'), ('"', 'Punctuation'), ('\n', 'Foreign')], [('"', 'Punctuation'), ('67', 'Number'), ('고', 'Modifier'), ('메', 'Noun'), ('눈꽃', 'Noun'), ('우대', 'Noun'), ('갈비', 'Noun'), ('선물', 'Noun'), ('세트', 'Noun'), ('(', 'Punctuation'), ('냉동', 'Noun'), ('),', 'Punctuation'), ('900', 'Number'), ('g', 'Alpha'), (',', 'Punctuation'), ('3', 'Number'), ('팩', 'Noun'), ('"', 'Punctuation'), ('\n', 'Foreign')], [('"', 'Punctuation'), ('호주', 'Noun'), ('산', 'Noun'), ('블랙', 'Noun'), ('앵거스', 'Noun'), ('구', 'Modifier'), ('이용', 'Noun'), ('선물', 'Noun'), ('세트', 'Noun'), ('(', 'Punctuation'), ('냉장', 'Noun'), ('),', 'Punctuation'), ('1.44', 'Number'), ('kg', 'Alpha'), (',', 'Punctuation'), ('1', 'Number'), ('세트', 'Noun'), ('"', 'Punctuation'), ('\n', 'Foreign')], [('"', 'Punctuation'), ('삼', 'Modifier'), ('원가', 'Noun'), ('든', 'Josa'), ('양념', 'Noun'), ...

# %%
noun_adj_adv_list=[] 
for sentence in morphs : 
    for word, tag in sentence : 
        if tag in ['Noun'] and ("팩" not in word)and("산" not in word)and("것" not in word)and("냉동" not in word)and("개" not in word)and("냉장" not in word)and("용" not in word)and ("내" not in word)and ("나" not in word)and ("수"not in word) and("게"not in word)and("말"not in word): 
            noun_adj_adv_list.append(word) 

print(noun_adj_adv_list)
# Out:
# ['로우', '소고기', '등심', '정육', '세트', '세트', '명장', '맛', '토마호크', '프리미엄', '스테이크', '세트', '세트', '목', '우촌', '품격', '가득', '호', '햄', '선물', '세트', '세트', '건화', '한우', '한우', '일품', '구이', '종', '세트', '세트', '목', '우촌', '품격', '가득', '돈', '호', '햄', '선물', '세트', '세트', '미국', '찜', '갈비', '선물', '세트', '부직포', '가방', '세트', '블랙', '앵거스', '모', '선물', '세트', '세트', '미국', '프라임', '소고기', '세트', '세트', '파머', '제주', '돼지', '종', '선물', '세트', '세트', '파머', '제주', '돼지', '종', '선물', '세트', '세트', '메', '눈꽃', '우대', '갈비', '선물', '세트', '호주', '블랙', '앵거스', '선물', '세트', '세트', '원가', '양념', '갈비', '꽃살', '세트', '세트', '경복궁', '명품', '한우', '불고기', '원가', '양념', '꽃살', '불고기', '혼합', '세트', '세트', '강강술래', '술래', '양념', '구이', '선물', '세트', '호', '무연', '골', '대패', '삼겹살', '양념', '불고기', '무연', '골', '대패', '삼겹살', '축협', '무', '항생제', '특란', '경복궁', '칼집', '갈비', '경복궁', '처', '양념', '육', '세트', '세트', '셰프', '초이스', '춘천', '닭갈비', '셰프', '초이스', '칼집', '돼지', '구이', '미트', '보리', '항정살', '요리', '락', '양념', '목심', '칼집', '구이', '자연', '실록', '무', '항생제', '인증', '닭', '가슴', '살', '횡성', '명품', '한우', '꽃', '갈비살', '등급', '이상', '미국', '토마호크', '스테이크', '선진', '포크', '돈', '목심', '로스', '호주', '블랙', '앵거스', '치마', '살', '견우', '마을', '프라임', '부채살', '스테이크', '컷', '크리스탈', '팜스', '미국', '초이스', '꽃', '갈비살', '쉐프', '파트너', '더', '춘천', '닭갈비', '저스트', '스테이크', '호주', '곡물', '등심', '스테이크', '설', '인', '한우', '안심', '샤토브리앙', '등급', '이상', '스테이크', '도드람', '돈', '칼집', '삼겹살', '설', '인', '무', '항생제', '인증', '베이', '비로인', '한우', '우둔', '이유', '진본', '고기', '한우', '보신', '세트', '박스', '임닭', '프랑크', '닭', '가슴', '살', '소시지', '꼬치', '쉐프', '파트너', '미국', '블랙', '앵거스', '부채살', '스테이크', '쉐프', '파트너', '미국', '초이스', '살', '스테이크', '호주', '갈비', '선물', '세트', '자연', '실록', '무', '항생제', '인증', '닭', '안심', '임닭', '소스', '닭', '가슴', '살', '슬', '라이스', '양송이', '크림소스', '입', '양념치킨', '소스', '입', '갈릭', '스테이크', '소스', '입', '세트', '생생', '포크', '돈', '등', '갈비', '구이', '미트', '포유', '스페인', '무연', '골', '대패', '삼겹살', '화담', '한우', '등심', '목', '우촌', '프로', '포크', '돈', '갈비', '설', '인', '한우', '살', '등급', '이상', '하림', '닭', '가슴', '살', '견우', '마을', '미국', '꽃', '갈비살', '구이', '횡성', '명품', '한우', '갈비살', '등급', '이상', '미국', '살', '스테이크', '미국', '스테이크', '컷', '견우', '마을', '미국', '부채살', '로스', '횡성', '한우', '등심', '구이', '마니커', '마리', '닭볶음탕', '닭고기', '임닭', '닭', '가슴', '살', '프랑크', '소시지', '리지', '널', '횡성', '한우', '양지', '등급', '이상', '국', '거리', '임닭', '닭', '가슴', '살', '프랑크', '소시지', '리지', '널', '감동', '란', '반숙', '계란', '구', '굽', '소스', '맛', '닭', '가슴', '살', '슬', '라이스', '화이트', '머쉬룸', '레드', '크림', '커리', '스파이', '커리', '세트', '세트', '메', '우대', '꽃', '갈비', '하림', '자연', '실록', '무', '항생제', '인증', '닭다리', '북채', '닝', '살', '셰프', '초이스', '돈', '양념', '돼지', '불고기', '바디', '입', '닭', '가슴', '살', '탄두리', '맛', '설', '목장', '무', '항생제', '인증', '한우', '등급', '채끝', '스테이크', '견우', '마을', '프라임', '채끝', '뉴욕', '스테이크', '컷', '횡성', '한우', '등심', '횡성', '한우', '등급', '채끝', '크리스탈', '팜스', '미국', '초이스', '닝', '부채살', '스테이크', '선진', '포크', '돈', '삼겹살', '로스', '횡성', '한우', '제비', '추리', '앞치마', '살', '등급', '이상', '미국', '갈비살', '횡성', '한우', '이상', '불고기', '견우', '마을', '미국', '초이스', '안심', '스테이크', '숙란', '구', '임닭', '빅볼', '닭', '가슴', '살', '숯불', '갈비', '맛', '횡성', '한우', '등급', '등심', '엑셀', '컷', '토마호크', '스테이크', '마니커', '마리', '생닭', '호', '돈', '마루', '돈', '목심', '푸드', '양념', '돼지', '막창', '소스', '세트', '세트', '크리스탈', '팜스', '미국', '프라임', '토시', '살', '임닭', '정통', '독일', '허브', '맛', '닭', '가슴', '살', '소시지', '쉐프', '파트너', '호주', '블랙', '앵거스', '척', '아이', '롤', '대성', '한우', '곱창', '대창', '염통', '세트', '크리스탈', '팜스', '미국', '프라임', '꽃', '갈비살', '횡성', '한우', '사태', '국', '거리', '크리스탈', '팜스', '미국', '프라임', '갈비살', '하이', '포크', '돈', '삼겹살', '쟌슨빌', '베다', '위드', '체다', '소시지', '파머', '제주', '돼지', '박', '앞다리', '하림', '닭', '안심', '햇살', '닭', '염', '훈제', '닭', '가슴', '살', '플러스', '염', '훈제', '닭', '가슴', '살', '슬', '라이스', '하림', '닭윙', '햇살', '닭', '카레', '닭', '가슴', '살', '마니커', '닭고기', '안심', '살', '대패', '우삼겹', '녹색', '한우', '무', '항생제', '등급', '등심', '케이프', '그림', '호주', '치마', '살', '횡성', '한우', '이상', '다짐', '육', '미국', '꽃', '갈비', '선물', '세트', '부직포', '가방', '세트', '닭', '닭', '가슴', '살', '스팀', '종', '세트', '세트', '설', '인', '한우', '채끝', '크리스탈', '팜스', '미국', '닝', '살', '스테이크', '저스트', '스테이크', '호주', '안심', '스테이크', '케이프', '그림', '호주', '부채살', '스테이크', '설', '목장', '무', '항생제', '인증', '한우', '등급', '이상', '절', '국', '거리', '바디', '닭', '가슴', '살', '어디', '불닭', '맛', ...

# %%
count = Counter(noun_adj_adv_list)

# %%
words = dict(count.most_common())

# %%
# !pip install WordCloud

# %%
pip install nltk
# Out:
# Collecting nltkNote: you may need to restart the kernel to use updated packages.
#   Downloading nltk-3.6.7-py3-none-any.whl (1.5 MB)
# Collecting click
#   Downloading click-8.0.3-py3-none-any.whl (97 kB)
# Collecting regex>=2021.8.3
#   Downloading regex-2021.11.10-cp38-cp38-win_amd64.whl (273 kB)
# Requirement already satisfied: tqdm in c:\users\win10\anaconda3\envs\javaedu\lib\site-packages (from nltk) (4.62.3)
# Collecting joblib
#   Downloading joblib-1.1.0-py2.py3-none-any.whl (306 kB)
# Requirement already satisfied: colorama in c:\users\win10\anaconda3\envs\javaedu\lib\site-packages (from click->nltk) (0.4.4)
# Installing collected packages: regex, joblib, click, nltk
# Successfully installed click-8.0.3 joblib-1.1.0 nltk-3.6.7 regex-2021.11.10
#   WARNING: The script nltk.exe is installed in 'C:\Users\win10\anaconda3\envs\javaEdu\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
from wordcloud import WordCloud 
import matplotlib.pyplot as plt 
import nltk 
from nltk.corpus import stopwords

# %%
# %matplotlib inline 

import matplotlib 
from matplotlib import rc
rc('font', family='NanumBarunGothic')

# %%
from wordcloud import WordCloud

wordcloud = WordCloud(
    font_path = 'C:/Users/win10/workspace/font/NanumBarunGothic.ttf',    # 맥에선 한글폰트 설정 잘해야함.
    background_color='white',                             # 배경 색깔 정하기
    colormap = 'Accent_r',                                # 폰트 색깔 정하기
    width = 800,
    height = 800
)

wordcloud_words = wordcloud.generate_from_frequencies(words)

# %%
array = wordcloud.to_array()
print(type(array)) # numpy.ndarray
print(array.shape) # (800, 800, 3)

fig = plt.figure(figsize=(10, 10))
plt.imshow(array, interpolation="bilinear")
plt.axis('off')
plt.show()
fig.savefig('business_anlytics_worldcloud.png')
# Out:
# <class 'numpy.ndarray'>
# (800, 800, 3)
