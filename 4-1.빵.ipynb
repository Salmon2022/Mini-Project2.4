# %%
import requests
import bs4
import time
import random

# %%
my_headers={"referer": "https://www.coupang.com/np/categories/393760",
     "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.110 Safari/537.36"
}

# %%
total_data_list=[]
for page_number in range (1,18):
    url="https://www.coupang.com/np/categories/420376?channel=plp_C2&page={}".format(page_number)
    res = requests.get(url=url, headers=my_headers)
    
    soup=bs4.BeautifulSoup(res.text)
    
    div_elements =soup.select("dd.descriptions > div.name")
    for e in div_elements:
        div_elements = e
        data_list=[]
        data_list.append(div_elements.text.strip())
        total_data_list.append(data_list)
    time.sleep(1)

# %%
total_data_list
# Out:
# [['크리스피크림도넛 오리지널 글레이즈드, 47g, 6개'],
#  ['후앙 동물 케익 만들기 2호 토끼와 곰, 537g, 1개'],
#  ['신라명과 달보드레 카스테라, 36g, 16개'],
#  ['그린래빗 대만식 앙크림샌드, 80g, 8개'],
#  ['그린래빗 대만식 삼색샌드, 80g, 8개'],
#  ['후앙 케익 만들기 세트, 441g, 1세트'],
#  ['오설록 그린티 롤케익 (냉동), 400g, 1개'],
#  ['플레인 치아바타 (냉동), 108g, 10개'],
#  ['조인 누테이블 블루베리치즈 타르트 6개입 (냉동), 330g, 1개'],
#  ['곰곰 달달 카스테라, 36g, 16입'],
#  ['신성제과 에그타르트 28개입 (냉동), 610g, 1개'],
#  ['춘천 감자빵 오리지널 10개입 (냉동), 1200g, 1개'],
#  ['미니 크로와상 (냉동), 600g, 1개'],
#  ['그린래빗 샌드위치 카야샌드, 70g, 8개'],
#  ['후앙 생크림 롤케익, 540g, 1개'],
#  ['삼립 뉴욕치즈케익 5개입 (냉동), 375g, 1개'],
#  ['신성제과 행복한호두파이 8개입 (냉동), 680g, 1개'],
#  ['후앙 수제쿠키 110g x 4종 세트, 1세트'],
#  ['후앙 솔티카라멜 케익 (냉동), 640g, 1개'],
#  ['르타오 더블 프로마쥬 치즈 케이크 (냉동), 330g, 1개'],
#  ['조인 누테이블 바스크치즈케이크 (냉동), 510g, 1개'],
#  ['밀크앤허니 16결 데니쉬 식빵 (냉동), 260g, 2봉'],
#  ['플레이버랩 다쿠아즈 5종 세트 (냉동), 300g, 1세트'],
#  ['맨치트 발효 미니버터 크로와상 (냉동), 337g, 2개'],
#  ['후앙 까망베르 케익 (냉동), 640g, 1개'],
#  ['아티제 바스크 치즈케이크, 500g, 1개'],
#  ['미니 크로아상 (냉동), 1kg, 1봉'],
#  ['후앙 동물 케익 만들기 2호 사자와 기린, 537g, 1개'],
#  ['플레잇 베이커리 크림치즈 프레즐 (냉동), 100g, 8개'],
#  ['끼리 스틱 치즈케익 플레인 8개입 (냉동), 400g, 1개'],
#  ['파미유 대만 샌드위치 햄치즈 (냉동), 75g, 12개입'],
#  ['크리스피크림도넛 어소티드 6개입 423g, 1세트'],
#  ['가가농장 아카시아꿀 튜브, 500g, 1개'],
#  ['밀크앤허니 연유 생크림 카스텔라 4입 (냉동), 600g, 1개'],
#  ['조르니키친 풀드포크 치아바타 샌드위치 2개입, 480g, 1개'],
#  ['밀크앤허니 호두파이 대, 900g, 1개'],
#  ['조르니키친 햄 앤 에그 루꼴라 크로와상샌드위치, 150g, 2개'],
#  ['신성제과 호두파이 28개입 (냉동), 560g, 1개'],
#  ['치엔바오 대만식 햄치즈샌드 (냉동), 81g, 8입'],
#  ['후앙 초코생크림 롤케익, 540g, 1개'],
#  ['삼립 계란옷 입은 몬테크리스토 토스트 3개입, 540g, 1개'],
#  ['청아냉동식품 팬케익 (냉동), 45g, 30개입'],
#  ['필라델피아 치즈케익 플레인 (냉동), 794g, 1개'],
#  ['후앙 마스카포네 생크림 롤케익, 540g, 1개'],
#  ['안단잼 말차 코코넛잼, 220g, 1개'],
#  ['맨치트 스퀘어 파이 소 생지 (냉동), 110g, 25개입'],
#  ['100 미니 크로아상 (냉동), 1kg, 1봉'],
#  ['아침엔 콘참치 샌드위치 (냉동), 80g, 8개'],
#  ['풍년제과 우리밀 초코파이 오리지널 6입 + 화이트 6입, 1세트'],
#  ['곰곰 미니 버터크루아상 냉동생지, 30g, 30개입'],
#  ['담꽃 CCOT 팥잼, 150g, 1개'],
#  ['조르니키친 BLTC 치아바타 샌드위치 2개입, 480g, 1개'],
#  ['루앙 초코 샌드위치, 63g, 6개'],
#  ['오.달디 수제 달카롱 10종 x 30g 세트 (냉동), 1세트'],
#  ['[쿠팡 직수입] 포르투갈 에그타르트 (냉동), 720g, 1팩'],
#  ['그린래빗 크랜베리 치킨 샌드위치 140g x 3개입, 420g, 1개'],
#  ['플레이버랩 리얼 레몬 다쿠아즈 (냉동), 35g, 10개'],
#  ['곰곰 대만식샌드위치 햄치즈에그, 80g, 8개입'],
#  ['맘쿠킹 브리도 미니 크로아상 생지 (냉동), 25g, 25개'],
#  ['아침엔 에그듬뿍 샌드위치 (냉동), 80g, 8개'],
#  ['풍년제과 우리밀 초코파이 오리지널 3입 + 화이트 3입, 450g, 1세트'],
#  ['아침엔 에그듬뿍 샌드위치 (냉동), 80g, 8개'],
#  ['플레이버랩 현미튀일 쿠키, 80g, 4개'],
#  ['그린래빗 튜나 샐러드 샌드위치 140g x 3개입, 420g, 1개'],
#  ['곰곰 프렌치 버터롤, 520g, 1개'],
#  ['슈거볼 마들렌 (냉동), 397g, 1개'],
#  ['아이스 찰보리 마들렌 (냉동), 25g, 30개'],
#  ['그린래빗 에그 햄 치즈 페스트리 샌드위치C, 165g, 2개'],
#  ['더건강한쌀베이글 블루베리 쌀베이글 3개입 (냉동), 330g, 1개'],
#  ['신라명과 오갓빵 펄슈가 크로플 (냉동), 180g, 1개'],
#  ['소화가잘되는우유 우유크림 롤케이크 (냉동), 360g, 1개'],
#  ['[쿠팡 직수입] 메니세즈 스톤 오븐 바게트 생지 6개입 (냉동), 750g, 1개'],
#  ['곰곰 크림치즈 프레즐 8개입 800g, 1개'],
#  ['아티제 녹차 카스텔라, 200g, 1개'],
#  ['후앙 블루베리 생크림 카스테라 3개입, 360g, 1개'],
#  ['벨기안 슈가 와플 20개입 (냉동), 1100g, 1개'],
#  ['슈거볼 마들렌 (냉동), 794g, 1개'],
#  ['루앙 햄치즈 샌드위치, 73g, 6개'],
#  ['오설록 티마들렌 30g x 3종 + 피낭시에 35g x 3종, 1세트'],
#  ['스윗밸런스 훈제연어 파인애플 샐러드 랩 2p, 488g, 1개'],
#  ['크로와상 (냉동), 560g, 1개'],
#  ['얌!(YAAM!) 트러플 불고기 치아바타 (냉동), 145g, 4개'],
#  ['파리크라상 바삭한 우리찹쌀 모나카 세트 + 쇼핑백, 372g, 1세트'],
#  ['진화과자 우리밀 만쥬 10구 + 화과자 5구 선물세트 625g (냉동), 1세트'],
#  ['달콤 바삭 쁘띠 바게트, 200g, 2개'],
#  ['르타오 초코 프로마쥬 치즈 케이크 (냉동), 330g, 1개'],
#  ['얌!(YAAM!) 멕시칸 치킨 치아바타 (냉동), 145g, 4개'],
#  ['이엘후레쉬 치킨브레스트 바게트 샌드위치, 180g, 2개'],
#  ['킹즈 치아바타 샌드위치 5개입 (냉동), 815g, 1개'],
#  ['신성제과 마카롱 타르트 세트 (냉동), 280g, 1세트'],
#  ['후앙 레드벨벳 크림치즈 케익 (냉동), 640g, 1개'],
#  ['진화과자 우리밀 만쥬 5구 + 화과자 10구 선물세트 725g (냉동), 1세트'],
#  ['[쿠팡 직수입] 메니세즈 사워도우 롤 생지 12개입 (냉동), 900g, 1개'],
#  ['슐스타드 크루아상 미니 24개입 (냉동), 720g, 1개'],
#  ['초코크림빵, 120g, 3개'],
#  ['삼립 모닝 잉글리쉬 머핀 6개입 (냉동), 140g, 6개'],
#  ['떡과정 화과자 20구 + 만쥬 10구 선물세트 (냉동), 1세트'],
#  ['오설록 그린 다쿠아즈 30g x 3입 + 호지초콜릿다쿠아즈 30g x 3입 (냉동), 1세트'],
#  ['아티제 발로나 초코롤, 350g, 1개'],
#  ['조르니키친 핫치킨 치아바타 샌드위치 2개입, 480g, 1개'],
#  ['청정원 미니미바나나 (냉동), 21g, 30개'],
#  ['파스키에 브리오슈 트레쎄 식빵 (냉동), 500g, 2팩'],
#  ['그린래빗 실속 핫도그 4입 세트, 1세트'],
#  ['그린래빗 바질 치킨 머쉬룸 파니니, 225g, 2입'],
#  ['그린래빗 피넛치킨 패스트리 샌드위치C, 130g, 2개'],
#  ['청정원 달콤포근 붓세 (냉동), 20g, 24개'],
#  ['ㅋㅇㅋ 신세계푸드 스노우 티라미수 크림케이크 (냉동), 340g, 1개'],
#  ['콩쉐프 미니크림치즈파이 냉동생지 (냉동), 35g, 20개'],
#  ['곰곰 버터 크루아상 생지, 560g, 1개'],
#  ['파리크라상 골드 치즈케이크 (냉동), 950g, 1개'],
#  ['그린래빗 고르곤졸라 불고기 파니니 샌드위치, 185g, 2팩'],
#  ['소화가잘되는우유 초코크림 롤케이크 (냉동), 380g, 1개'],
#  ['콩쉐프 미니버터크로와상 (냉동), 22.5g, 24개'],
#  ['아티제 뉴욕치즈 케이크, 700g, 1개'],
#  ['플레이버랩 스트로베리 다쿠아즈 (냉동), 30g, 10개'],
#  ['삼립 호빵 발효미종 단팥 7입 + 야채 7입, 1288g, 1세트'],
#  ['그린래빗 쉬림프미트 랩, 532g, 1개'],
#  ['그린래빗 포크쉬니첼 랩, 540g, 1개'],
#  ['그린래빗 단 계 감 모닝 샌드위치C, 220g, 2개'],
#  ['아티제 양과자세트 레몬 마들렌 30g x 5개 + 크랜베리 휘낭시에 37g x 5개 + 월넛 휘낭시에 37g x 5개, 1세트'],
#  ['맨치트 플레이 쿠키 (냉동), 420g, 2개'],
#  ['[쿠팡 직수입] 라비에 미니 버터 크로아상 생지 40입 (냉동), 1000g, 1개'],
#  ['파스키에 마카롱 12개입 (냉동), 154g, 2개'],
#  ['그린래빗 햄모짜렐라 치즈 파니니 샌드위치, 150g, 2팩'],
#  ['곰곰 생크림 롤케익, 540g, 1개'],
#  ['[쿠팡 직수입] 벨기에 와플 20p (냉동), 1100g, 1개'],
#  ['상하치즈 바스크 치즈케이크 (냉동), 470g, 1개'],
#  ['아티제 브레드 세트, 1세트'],
#  ['곰곰 미니 버터크루아상 냉동생지, 30g, 15개입'],
#  ['신성제과 앙금파이만쥬 16개입 (냉동), 320g, 1개'],
#  ['맨치트 서울식품 생지 스퀘어 파이 대 30개입 (냉동), 10200g, 1봉'],
#  ['나폴레옹베이커리 구로칸토슈니탱 (냉동), 416g, 1개'],
#  ['그린래빗 오리지날 햄 크로와상 샌드위치, 120g, 2개'],
#  ['파스키에 라즈베리 타르트 2p (냉동), 220g, 2개'],
#  ['네니아 무농약 우리밀 와플 (냉동), 25g, 20개'],
#  ['진화과자 우리밀 만쥬 10구 + 화과자 10구 선물세트 900g (냉동), 1세트'],
#  ['후앙 요거트 쿠키 머핀, 90g, 5개'],
#  ['베키아에누보 시그니쳐치즈케이크 (냉동), 550g, 1개'],
#  ['끼리 스틱 치즈케익 블루베리 (냉동), 50g, 8개'],
#  ['몽슈슈 몬테카를로 오리지널 (냉동), 44g, 10개'],
#  ['빌리엔젤 당근 케이크 (냉동), 1100g, 1개'],
#  ['나폴레옹베이커리 쇼콜라비스큐슈니탱 (냉동), 385g, 1개'],
#  ['조르니키친 쉬림프 크래미 치아바타 샌드위치 2개입, 480g, 1개'],
#  ['파미유 대만샌드위치 카야 샌드 (냉동), 80g, 12개'],
#  ['그린래빗 반숙란 에그마요 샌드위치, 320g, 1팩'],
#  ['티오페페스 츄러스 38cm (냉동), 55g, 10입'],
#  ['안단잼 저칼로리 딸기 콩포트, 220g, 1개'],
#  ['안단잼 얼그레이 코코넛잼, 220g, 1개'],
#  ['안단잼 신선 딸기잼, 460g, 1개'],
#  ['루앙 딸기 샌드위치, 63g, 6개'],
#  ['빌리엔젤 프레쉬 스트로베리 케이크 (냉동), 1000g, 1개'],
#  ['신라명과 고구마 크림치즈 찰빵 (냉동), 720g, 1개'],
#  ['삼립 리얼 후레쉬 치즈케익 10개입, 700g, 1개'],
#  ['후앙 초코 생크림 카스테라, 120g, 3개'],
#  ['쉐푸드 페파로니살라미샌드, 642g, 1개'],
#  ['쉐푸드 햄치즈 크로와상샌드, 590g, 1개'],
#  ['후앙 리얼 수제 쿠키 100g x 8개입 세트, 1세트'],
#  ['뽐뽐 크림치즈 마녀볼 (냉동), 98g, 4개입'],
#  ['맛있닭 닭가슴살 한끼 소세지빵 (냉동), 120g, 4팩'],
#  ['글레이즈 두부 도너츠 (냉동), 50g, 30개'],
#  ['건강한 쌀베이커리 블루베리 쌀식빵 (냉동), 365g, 1개'],
#  ['파스키에 마카롱 그루망 12p (냉동), 158g, 2개'],
#  ['빙그레 디디디 크럼블 치즈케이크 3종 세트 (냉동), 1세트'],
#  ['서울브레드 초코 퍼지케이크 홀 (냉동), 600g, 1개'],
#  ['파스키에 프렌치 디저트 컬렉션 쁘띠뽀 179g + 마카롱 154g 세트 (냉동), 1세트'],
#  ['미니 메이플 피칸 플레이트 24ea (냉동), 996g, 1개'],
#  ['고메공방 임자있는 흑임자찐빵 (냉동), 400g, 2팩'],
#  ['키플 몽슈슈 도지마롤 (냉동), 80g, 2개'],
#  ['빵어니스타 쑥 타르트 2봉지 (냉동), 180g, 1개'],
#  ['파스키에 초콜릿 타르트 10개입 (냉동), 800g, 1개'],
#  ['하이원푸드 미니 붕어빵 치즈 (냉동), 1kg, 1개'],
#  ['페이브 밤 페스츄리s (냉동), 115g, 4개입'],
#  ['코알라 미니 버터 크로와상 (냉동), 400g, 1개'],
#  ['후앙 리얼초코칩머핀, 90g, 5개'],
#  ['맨치트 미니 초코칩쿠키 다크 생지 (냉동), 18g, 50개입'],
#  ['에쉬레 롤케이크 (냉동), 330g, 1개'],
#  ['천일식품 당근케이크100 4봉지 (냉동), 240g, 1개'],
#  ['더바움 티라미슈 크레이프 (냉동), 700g, 1개'],
#  ['예술방앗간 고메버터 크로플 (냉동), 230g, 1개'],
#  ['곰곰 통통한 오리지널 츄러스 28cm (냉동), 55g, 10개'],
#  ['아티제 쿠키 쇼콜라 프로켄트 150g + 발로나 오트밀 80g + 월넛 네쥬 쿠키 100g 세트, 1세트'],
#  ['블루베리 베이글 6개 (냉동), 594g, 1개'],
#  ['그린래빗 칠리 크랩 샐러드 샌드위치C 2개입, 340g, 1팩'],
#  ['플레잇 크로와상 10개입 (냉동), 650g, 1개'],
#  ['푸딩팩토리 허니버터 브레드 (냉동), 190g, 3개'],
#  ['맨치트 파이피자시트 9 냉동생지 10p (냉동), 1330g, 1개'],
#  ['끼니엔갓빵 버터 마들렌 (냉동), 45g, 10개'],
#  ['후앙 마늘바게트, 200g, 2개'],
#  ['곰곰 초코 붕어빵, 900g, 1개'],
#  ['곰곰 갈릭크림 통바게트 마늘빵, 250g, 2개입'],
#  ['끼리 홀 치즈케익 블루베리 (냉동), 520g, 1개'],
#  ['그린 다쿠아즈 (냉동), 35g, 12개'],
#  ['[쿠팡 직수입] 라비에 미니 크로아상 초코 생지 40입 (냉동), 1240g, 1개'],
#  ['나폴레옹베이커리 미니쿠키 코코넛샤브레 138g + 버터쿠키 70g + 쇼콜라프로겐트 110g, 1세트'],
#  ['서울브레드 딸기 크림케이크 4조각 (냉동), 400g, 1개'],
#  ['빌리엔젤 데블스 초코렛 케이크 S (냉동), 900g, 1개'],
#  ['디엔비 글레이즈드 도넛 50입 (냉동), 2500g, 1박스'],
#  ['디엔비 바바리안필링 도너츠 30입 (냉동), 1950g, 1개'],
#  ['아티제 피칸파이, 600g, 1개'],
#  ['화이트 다쿠아즈 (냉동), 35g, 12개'],
#  ['필라델피아 오레오 치즈케익 (냉동), 794g, 1개'],
#  ['상하치즈 까망베르 치즈케이크 (냉동), 380g, 1개'],
#  ['대상 쉐프원 타코야끼 (냉동), 1kg, 1개'],
#  ['천일식품 간편한 체다치즈 오믈렛 (냉동), 1.4kg, 1개'],
#  ['조르니키친 치킨 앤 바질페스토 루꼴라 크로와상 샌드위치, 130g, 2개'],
#  ['디엔비 바닐라후로스트 도넛 50입 (냉동), 2500g, 1박스'],
#  ['미지엄 다뜨사빵 감자 (냉동), 120g, 5개입'],
#  ['소백산벌꿀 선흥 사양 아카시아꿀, 2.4kg, 1개'],
#  ['캘리포니아 바바리안 크리미 츄러스 25cm (냉동), 78g, 25입'],
#  ['명장 미니붕어빵 카스타드크림 (냉동), 1kg, 1개'],
#  ['맨치트 사각파이 냉동생지, 8000g, 1봉'],
#  ['디엔비 올드글레이즈 도넛 50입 (냉동), 2750g, 1박스'],
#  ['쵸코 마카롱 (냉동), 27g, 12개입'],
#  ['신성제과 까망케익 10개입 (냉동), 220g, 1개'],
#  ['CJ제일제당 크레잇 칠리미트 서브샌드위치(냉동), 552g, 1개'],
#  ['포숑 마카롱 6구 세트 96g (냉동), 1세트'],
#  ['곰곰 크랜베리 치킨 샌드위치, 1개'],
#  ['스페로스페라 럭키 밀크 크레이프 케이크 (냉동), 700g, 1개'],
#  ['더바움 밀 크레이프 (냉동), 600g, 1개'],
#  ['곰곰 햄치즈 크로와상 샌드위치, 1개'],
#  ['몽슈슈 롤쿠키 S, 204g, 1개'],
#  ['단백질과자점 다크에스프레소 사브레 (냉동), 85g, 3입'],
#  ['진화과자 화과자 15구 (냉동), 825g, 1개'],
#  ['베키아에누보 수크레 크레이프 케이크 (냉동), 950g, 1개'],
#  ['안단 하이프로틴 초코잼, 430g, 1개'],
#  ['빌리엔젤 레드벨벳 케이크 (냉동), 1200g, 1개'],
#  ['디엔비 초코퐁당 도넛 30입 (냉동), 1500g, 1개'],
#  ['르제르블랑 스페셜 와인 티라미수 골드에디션 (냉동), 750g, 1개'],
#  ['뭉게구름 프리미엄 수제 뚱카롱 6개입 180g (냉동), 1세트'],
#  ['디엔비 초코츄잉 도넛 50입 (냉동), 2750g, 1박스'],
#  ['디엔비 화이트올드훼션 도넛 50입 (냉동), 2750g, 1박스'],
#  ['디엔비 딸기츄잉 도넛 50입 (냉동), 2750g, 1박스'],
#  ['포숑 마카롱 7구 세트 112g (냉동), 1세트'],
#  ['이츠웰 NEW 쌀 품은 또띠아 12개입 (냉동), 240g, 10입'],
#  ['이츠웰 우리밀 에그타르트 (냉동), 35g, 16개'],
#  ['하이원푸드 미니 붕어빵 고구마 (냉동), 1kg, 1개'],
#  ['아티제 에쉬레 휘낭시에 세트, 25g, 7개입'],
#  ['토피 애플 크라운 12개입 (냉동), 1233.6g, 1개'],
#  ['그린래빗 마크니커리 치킨랩, 516g, 1개'],
#  ['더바움 밀 크레이프 (냉동), 700g, 1개'],
#  ['파스키에 애플 타르트 10개입 (냉동), 1200g, 1개'],
#  ['레브슈 프랑스 미니 크로와상 생지 15개입 (냉동), 450g, 1봉'],
#  ['그린래빗 인기핫도그 2종 x 2p 혼합 세트, 1개'],
#  ['그린래빗 통밀 디럭스 샌드위치C, 170g, 2개'],
#  ['허니 크림치즈 브레드 (냉동), 190g, 20개'],
#  ['디엔비 화이트링 도넛 50입 (냉동), 2500g, 1박스'],
#  ['디엔비 화이트보스톤 도넛 50입 (냉동), 3000g, 1박스'],
#  ['디엔비 딸기맛보스톤 도넛 50입 (냉동), 3000g, 1박스'],
#  ['디엔비 초코쿠키링 도넛 50입 (냉동), 2500g, 1박스'],
#  ['포숑 마카롱 10구 세트 160g (냉동), 1세트'],
#  ['서울브레드 누텔라 생크림 크로와상 4p (냉동), 400g, 1개'],
#  ['클래식 쿠키 생지 도우 청키초코쿠키 (냉동), 890g, 1개'],
#  ['삼립 끼리 진한 크림치즈 롤케익, 110g, 3개'],
#  ['파스키에 레몬머랭 타르트 (냉동), 500g, 1개'],
#  ['하이원푸드 미니 붕어빵 초코 (냉동), 1kg, 1개'],
#  ['몽상클레르 카스테라 플레인 (냉동), 350g, 1개'],
#  ['33티라미수 케이크 달콤한 초코 티라미수 (냉동), 500g, 1개'],
#  ['신성제과 에그타르트 선물용 12개입 (냉동), 260g, 1개'],
#  ['서울브레드 퓨어 치즈케이크 홀 (냉동), 600g, 1개'],
#  ['밀러가또 유자 쏘옥 카스테라 6개입 (냉동), 300g, 1개'],
#  ['푸딩팩토리 푸딩카페 밀크레이프 (냉동), 120g, 6개'],
#  ['명장 미니붕어빵 통팥앙금 (냉동), 1kg, 1개'],
#  ['천일식품 간편한 양송이 오믈렛 (냉동), 1.4kg, 1개'],
#  ['소복 인절미 아이스볼 2p (냉동), 300g, 1개'],
#  ['[로켓프레시]파스키에 초콜릿 타르트 2입 (냉동), 160g, 2개'],
#  ['아티제 롤 케이크 세트 특, 700g, 1세트'],
#  ['얌!(YAAM!) 호두피칸 타르트 (냉동), 70g, 4개'],
#  ['파미유 대만식 크림치즈 샌드 12개입 (냉동), 900g, 1개'],
#  ['아티제 에쉬레 마들렌 세트, 25g, 7개입'],
#  ['지유가오카 바나나 DIY 케이크, 750g, 1개'],
#  ['존쿡델리미트 마스터의브레드 올리브 치아바타 3개입 (냉동), 240g, 4개'],
#  ['맨치트 갈릭파이 (냉동), 360g, 2개'],
#  ['쉐푸드 그릴드치킨샌드, 639g, 1개'],
#  ['근대골목단팥빵 생크림 단팥빵 (냉동), 135g, 5개'],
#  ['올바른 우리밀 네쪽마늘빵 (냉동), 800g, 1개'],
#  ['그린래빗 치즈 에그 샐러드 샌드위치C 2개입, 320g, 1팩'],
#  ['플레이버랩 밀크카라멜 다쿠아즈 (냉동), 30g, 10개'],
#  ['벨라플레이트 초코 치즈케이크 (냉동), 330g, 1개'],
#  ['그린래빗 크랜베리 리코타 고구마 샌드위치C 2개입, 340g, 1팩'],
#  ['고메 베이커리 크로와상 (냉동), 630g, 1개'],
#  ['더바움 초코 크레이프 (냉동), 700g, 1개'],
#  ['호떡당 잡채호떡 (냉동), 450g, 2팩'],
#  ['더바움 딸기 크레이프 (냉동), 700g, 1개'],
#  ['디엔비 딸기맛필링 도너츠 30입 (냉동), 1950g, 1개'],
#  ['벤탄마켓 치아바타 10p (냉동), 600g, 1개'],
#  ['천일식품 간편한 베이컨 오믈렛 (냉동), 1.4kg, 1개'],
#  ['풀무원 풀스키친 호밀이들어간 듀얼쨈파이 생지 (냉동), 1.6kg, 1개'],
#  ['메이플피칸 12개 (냉동), 1164g, 1개'],
#  ['신라명과 뉴욕에서 온 바스크 치즈케이크 (냉동), 290g, 1개'],
#  ['단백질과자점 밀키초코바 (냉동), 66g, 3개'],
#  ['그린래빗 잭다니엘 치킨 샐러드 샌드위치C 2개입, 340g, 1팩'],
#  ['코만스 뚱카롱 6구 퓨어팩 (냉동), 210g, 1팩'],
#  ['조인 누테이블 크림치즈 타르트 6개입 (냉동), 300g, 1개'],
#  ['몽상클레르 까망베르치즈 (냉동), 300g, 1개'],
#  ['서울브레드 초코퍼지 케이크 4조각 (냉동), 480g, 1개'],
#  ['아침엔 블루베리 베이글 (냉동), 110g, 8개'],
#  ['밀러가또 딸기잼 쏘옥 롤케이크 (냉동), 50g, 6개'],
#  ['벨라플레이트 눈꽃 치즈케이크 (냉동), 330g, 1개'],
#  ['아티제 티라미수, 500g, 1개'],
#  ['유로베이크 카페크로크무슈 (냉동), 160g, 8개'],
#  ['이엘후레쉬 오리지날 비프 바게트 샌드위치, 180g, 2개'],
#  ['파스키에 애플 타르트 2p (냉동), 240g, 2개'],
#  ['후앙 뺑드노아 베이커리, 180g, 2개'],
#  ['아티제 베리베리 티라미수 (냉동), 500g, 1개'],
#  ['디엔비 바바리안필링 도너츠 50입 (냉동), 3250g, 1박스'],
#  ['스페로스페라 럭키 블루베리 크레이프 케이크 (냉동), 700g, 1개'],
#  ['서울브레드 순우유 크림 케이크 4개입 (냉동), 400g, 1개'],
#  ['밀러가또 김밥을 꿈꾸는 블루베리 롤케익 (냉동), 415g, 1개'],
#  ['근대골목단팥빵 크림치즈 (냉동), 70g, 5개'],
#  ['그린래빗 BELT 크로와상 샌드위치, 120g, 2개'],
#  ['파리크라상 실온 사브레 쿠키 3구 + 쇼핑백 선물세트, 1세트'],
#  ['호빵 10개입 + 야채호빵 10개입 1.8kg, 1개'],
#  ['디엔비 초코퐁당 도넛 50입 (냉동), 2500g, 1박스'],
#  ['맘쿠킹 AOP 크로아상 생지 (냉동), 70g, 10개'],
#  ['벨라플레이트 말차 치즈케이크 (냉동), 330g, 1개'],
#  ['곰곰 바게트 하드롤 (냉동), 120g, 4개입'],
#  ['곰곰 클래식 크로플, 25g, 10개입'],
#  ['설공 치아씨드 보리바 5개입, 225g, 1개'],
#  ['필라델피아 치즈케익 라즈베리 스월 (냉동), 794g, 1개'],
#  ['삼립 카페스노우 블루베리 요거트 왕슈 (냉동), 108g, 12입'],
#  ['신성제과 호두파이 선물용 12개입 (냉동), 240g, 1개'],
#  ['쉐푸드 에그마요샌드, 699g, 1개'],
#  ['곰곰 미니 초코 크루아상 냉동생지, 645g, 1개'],
#  ['[쿠팡 직수입] 스키피 수퍼크런치 땅콩버터, 1.13kg, 1개'],
#  ['33티라미수 케이크 고소한 인절미 티라미수 (냉동), 500g, 1개'],
#  ['33티라미수 케이크 진한 녹차 티라미수 (냉동), 500g, 1개'],
#  ['플레잇 베이커리 대만식 샌드위치 햄치즈 (냉동), 77g, 6개'],
#  ['밀러가또 흑당 쏘옥 카스테라 6개입 (냉동), 300g, 1개'],
#  ['큐브 파운드 4종 케이크 (냉동), 440g, 1팩'],
#  ['곰곰 어니언 베이글, 720g, 1개'],
#  ['대만 샌드위치 딸기 (냉동), 70g, 12개'],
#  ['조르니키친 브리치즈 앤 애플 루꼴라 크로와상샌드위치, 130g, 2개'],
#  ['신성제과 우리밀 구겔호프 세트 (냉동), 450g, 1세트'],
#  ['디엔비 초코보스톤 도넛 50입 (냉동), 3000g, 1박스'],
#  ['미니 크로아상 플레인 30ea (냉동), 900g, 1개'],
#  ['샹달프 과일잼 5종 세트, 1세트, 850g'],
#  ['후앙 치즈 치아바타, 130g, 3개'],
#  ['CJ제일제당 크레잇 토마토미트볼 서브샌드위치(냉동), 660g, 1개'],
#  ['플레이버랩 더블 그린티 다쿠아즈 (냉동), 30g, 10개'],
#  ['우유크림 카스테라 (냉동), 120g, 12개'],
#  ['디엔비 단호박곡물 도넛 30입 (냉동), 1500g, 1개'],
#  ['서울브레드 미니치즈 먹물식빵 체다치즈 3ea (냉동), 225g, 1개'],
#  ['플레이버랩 다크초콜릿 다쿠아즈 (냉동), 30g, 10개'],
#  ['몽슈슈 몬테카를로 후람보와즈 케이크 (냉동), 40g, 10개입'],
#  ['쿰스 Coombs 유기농 메이플 시럽, 1개, 236ml'],
#  ['33티라미수 케이크 촉촉한 당근 티라미수 (냉동), 500g, 1개'],
#  ['단백질과자점 카스텔라 (냉동), 150g, 3입'],
#  ['필라델피아 치즈케익 터틀 (냉동), 794g, 1개'],
#  ['후앙 몽블랑 페스츄리 2개입 (냉동), 280g, 1개'],
#  ['삼립 허니 카스테라 4개입, 620g, 1개'],
#  ['곰곰 바닐라 롤케익, 430g, 1개'],
#  ['디엔비 화이트올드훼션 도넛 30입 (냉동), 1650g, 1개'],
#  ['후앙 수제 뚱카롱 세트 5구 (냉동), 1세트'],
#  ['디엔비 초코보스톤 도넛 30입 (냉동), 1800g, 1개'],
#  ['파리크라상 크랜베리 파운드 케익, 490g, 1개'],
#  ['안단잼 하이프로틴 헤이즐넛 초코잼, 430g, 1개'],
#  ['얌!(YAAM!) 부드러운 바닐라 롤케익, 430g, 1개'],
#  ['더바움 녹차 크레이프 (냉동), 600g, 1개'],
#  ['파리크라상 초코 무화과 파운드 케익, 475g, 1개'],
#  ['몽슈슈 쿠키샌드 M, 420g, 1개'],
#  ['곰곰 햄버거용 빵, 50g, 20개입'],
#  ['끼니엔갓빵 무엘르뺑샌드위치 (냉동), 140g, 5개입'],
#  ['아티제 그랑크뤼 식빵, 450g, 1개'],
#  ['코알라 초코 크로와상 (냉동), 300g, 1개'],
#  ['이츠웰 쫀득쫀득 브라우니 쿠키 (냉동), 20g, 20개'],
#  ['더바움 카라멜 크레이프 (냉동), 650g, 1개'],
#  ['신키네도 오렌지 롤 크림 케이크 (냉동), 350g, 1개'],
#  ['맨치트 미니 슈크림파이 (냉동), 525g, 2개'],
#  ['클래식 쿠키 생지 도우 클래식 피넛 쿠키 (냉동), 890g, 1개'],
#  ['레드 다쿠아즈 (냉동), 35g, 12개'],
#  ['베키아에누보 레어 프로마쥬 (냉동), 380g, 1개'],
#  ['벨라플레이트 딸기 치즈케이크 (냉동), 330g, 1개'],
#  ['끼니엔갓빵 시트러스마들렌 (냉동), 45g, 10개입'],
#  ['근대골목단팥빵 생크림 단팥빵 생크림 135g x 3p + 녹차 135g + 딸기 135g (냉동), 1세트'],
#  ['벨라플레이트 순백 롤케이크 (냉동), 400g, 1개'],
#  ['복음자리 딸기 듬뿍 생생 과일잼, 470G, 1PIECE'],
#  ['연세우유 크림치즈 우유롤 (냉동), 390g, 1박스'],
#  ['페이브 플레인 크로츄 (냉동), 30g, 3개입'],
#  ['쉐푸드 듬뿍 크랜베리 치킨 샌드위치, 770g, 1팩'],
#  ['달롤 교토마차롤 홀사이즈 (냉동), 430g, 1개'],
#  ['더바움 레드벨벳 크레이프 6개입 (냉동), 720g, 1개'],
#  ['아티제 테디베어 쿠키세트 (월넛네쥬 100g + 발로나오트밀 80g + 아티제베어), 1세트'],
#  ['맨치트 미니 피자턴오버 (냉동), 600g, 2개'],
#  ['마리브리자드 홈카페 바닐라 시럽 + 헤이즐넛 시럽 + 시럽펌프 세트, 1세트'],
#  ['베키아에누보 구스타스토 리코타케이크 (냉동), 625g, 1개'],
#  ['안단잼 하이프로틴 고구마잼, 420g, 1개'],
#  ['더브레드블루 매콤한 치아바타 3개입 (냉동), 540g, 1개'],
#  ['[로켓프레시]삼립 카페스노우 아이스 플레인 모찌롤케익 (냉동), 105g, 16개'],
#  ['풀무원 비밀빵집 크림치즈 옥수수빵 (냉동), 450g, 1개'],
#  ['삼립 카페스노우 아이스 초코 모찌롤 (냉동), 120g, 16개'],
#  ['나폴레옹베이커리 미니쿠키 바닐라초코 140g + 쇼콜라아망드 140g, 1세트'],
#  ['벨라플레이트 호박 치즈케이크 (냉동), 330g, 1개'],
#  ['더건강한쌀베이글 시나몬레이즌 쌀베이글 3개입 (냉동), 315g, 1개'],
#  ['클래식 쿠키 생지도우 클래식 더블초코쿠키 (냉동), 890g, 1개'],
#  ['마담정 크리스마스 마카롱 30g x 5개입 세트 (냉동), 1세트'],
#  ['아티제 머핀세트 블루베리 크럼블 머핀 100g x 2개 + 발로나 초코 크럼블 머핀 100g x 2개, 1세트'],
#  ['곰곰 후렌치 바게트 빵 (냉동), 300g, 3개입'],
#  ['신라명과 오갓빵 소시지 페스츄리 (냉동), 280g, 1개'],
#  ['콩쉐프 미니애플턴오버 냉동생지 (냉동), 40g, 16개'],
#  ['더바움 딸기 크레이프 6개입 (냉동), 600g, 1개'],
#  ['파미유 대만식 초코 샌드 (냉동), 840g, 1개'],
#  ['더바움 초코 크레이프 (냉동), 650g, 1개'],
#  ['후앙 리얼머핀세트 초코칩 머핀 90g x 3개 + 블루베리 머핀 90g x 3개, 540g, 1세트'],
#  ['이츠웰 마이 리틀 감귤 타르트 (냉동), 35g, 16개'],
#  ['파리크라상 카스테라 천혜향, 266g, 1개'],
#  ['벨라플레이트 쇼콜라 롤케이크 (냉동), 400g, 1개'],
#  ['스윗밸런스 콩불고기 이탈리안 샐러드 랩 2p, 488g, 1개'],
#  ['천일식품 플레인 오믈렛 (냉동), 1kg, 1개'],
#  ['오븐에 구운 바나나빵, 40g, 8입'],
#  ['미니 바닐라 크라운 24ea (냉동), 1032g, 1개'],
#  ['풀무원 비밀빵집 감자빵 (냉동), 450g, 1개'],
#  ['우리밀 허니 카스테라 초코 (냉동), 30g, 30개'],
#  ['코만스 4종 오리지널팩 컵케익 (냉동), 480g, 1팩'],
#  ['조르니키친 브렉퍼스트 BLT 해쉬브라운 머핀과 양송이 스프, 450g, 1개'],
#  ['맨치트 미니 아몬드쿠키 생지 (냉동), 18g, 50개입'],
#  ['아티제 허니 카스텔라, 200g, 1개'],
#  ['후앙 모찌모찌식빵, 500g, 2개'],
#  ['몽슈슈 로즈휘낭시에 (냉동), 32g, 9개'],
#  ['이츠웰 우리밀 쁘띠 초코칩 머핀 (냉동), 28g, 30개'],
#  ['우리밀 페스츄리 씨앗파이 생지 (냉동), 40g, 20개'],
#  ['아티제 허니 카스텔라, 200g, 1개'],
#  ['꽃셰프가 유기농 인증 퓨레 혼합 160g x 4종 세트, 1세트'],
#  ['서울커피 티라미수 140g x 4종 세트 (냉동), 1세트'],
#  ['더바움 티라미슈 크레이프 (냉동), 600g, 1개'],
#  ['몽슈슈 로즈휘낭시에 (냉동), 32g, 12개'],
#  ['곰곰 후렌치 바게트 빵 (냉동), 300g, 3개입'],
#  ['파리크라상 캬라멜 파운드 케익, 480g, 1개'],
#  ['후앙 수제 뚱카롱 세트 5구 (냉동), 1세트'],
#  ['디엔비 올드글레이즈 도넛 30입 (냉동), 1650g, 1개'],
#  ['풀무원 비밀빵집 감자빵 (냉동), 450g, 1개'],
#  ['마카롱 (냉동), 480g, 1개'],
#  ['몽상클레르 카스테라 홍차 (냉동), 350g, 1개'],
#  ['맨치트 미니 레몬 크림치즈파이 (냉동), 600g, 2개'],
#  ['이엘후레쉬 구워먹는 발사믹 머쉬롬 샌드 130g x 3개, 1세트'],
#  ['위고에빅토르 치즈케익 (냉동), 300g, 1개'],
#  ['오븐에 구운 바나나빵, 40g, 8입'],
#  ['나폴레옹베이커리 건쿠키 혼합세트 333g, 1세트'],
#  ['복음자리 딸기 듬뿍 생생 과일잼, 470G, 1PIECE'],
#  ['더바움 바움쿠헨롤 (냉동), 495g, 1개'],
#  ['페이브 팔미까레 (냉동), 64g, 5개입'],
#  ['후앙 모찌모찌식빵, 500g, 2개'],
#  ['미니 애플 코로넷 24ea (냉동), 1032g, 1개'],
#  ['서울브레드 초코크림 케이크 4개입 (냉동), 400g, 1개'],
#  ['코알라 인절미 크로와상 (냉동), 520g, 1개'],
#  ['프레시오늘 국내산 통마늘 양파를 갈아만든 수제 양파마늘빵 (냉동), 300g, 1팩'],
#  ['라쿠치나 바베큐 풀드포크 파니니 (냉동), 125g, 3개'],
#  ['달롤 달미롤 홀사이즈 (냉동), 360g, 1개'],
#  ['세미원 밀 또띠아 25cm 12입 (냉동), 774g, 6개'],
#  ['곰곰 팥호빵 20개입 1.8kg, 1개'],
#  ['근대골목단팥빵 사랑빵손님 딸기 생크림 단팥빵 (냉동), 135g, 5개'],
#  ['제주바다 딱새우 멘보샤 (냉동), 300g, 1개'],
#  ['몽슈슈 아망드 쇼콜라롤 홀 (냉동), 420g, 1개'],
#  ['한끼의품격 더블 디럭스 버거 190g x 3팩 + 매콤한 치킨벅 160g x 3팩 (냉동), 1세트'],
#  ['치즈가 쭉 늘어나는 프리미엄 vvip 두물머리 연잎핫도그 (냉동), 1kg, 1개'],
#  ['이엘후레쉬 불고기 샌드위치, 185g, 2개'],
#  ['몽슈슈 쁘띠 모카 쇼콜라롤, 300g, 1개'],
#  ['스파이시 치킨 치아바타 샌드위치 5ea (냉동), 975g, 1개'],
#  ['우리밀 대나무통 바게트9cm (냉동), 900g, 1개'],
#  ['밀크앤허니 스위트크림 치즈케익 (냉동), 520g, 1개'],
#  ['미니 뺑 오 초코렛 50ea (냉동), 1500g, 1개'],
#  ['그린래빗 포테이토 샐러드 크로와상 샌드위치, 135g, 2개'],
#  ['곰곰 소시지 페스츄리, 35g, 8개입'],
#  ['파리크라상 제주 천혜향 파운드 케익, 475g, 1개'],
#  ['미디 헤이즐넛 드림 16ea (냉동), 1152g, 1개'],
#  ['맘쿠킹 크로아상 생지 (냉동), 40g, 15개'],
#  ['곰곰 커브 크로와상, 54g, 9개입'],
#  ['이엘후레쉬 치킨브레스트 샌드위치, 185g, 2개'],
#  ['안단잼 신선 사과잼, 460g, 1개'],
#  ['스윗밸런스 풀드포크 바비큐 샐러드 랩 2p, 488g, 1개'],
#  ['근대골목단팥빵 치즈라떼번 (냉동), 75g, 5개'],
#  ['미니 스트로베리 스퀘어 (냉동), 42g, 20개입'],
#  ['쿠키 앤 크림 츄러스 25cm (냉동), 78g, 10입'],
#  ['이엘후레쉬 구워먹는 바질페스토 샌드 130g x 3개, 1세트'],
#  ['미니 라즈베리 크라운 24ea (냉동), 1032g, 1개'],
#  ['한끼의품격 더블 디럭스 버거 190g x 3팩 + 달콤한 불벅 140g x 3팩 (냉동), 1세트'],
#  ['곰곰 글레이즈드 도넛 500g, 50g, 10개입'],
#  ['[쿠팡 직수입] 라비에 미니 크루아상 생지 버터 앤 초코 40입 (냉동), 1세트'],
#  ['스페로스페라 럭키 초코 크레이프 케이크 (냉동), 750g, 1개'],
#  ['프레시오늘 이태리 리얼초콜릿 쫀득 수제 브라우니 6p (냉동), 410g, 1개'],
#  ['더바움 스틱바움 5개입 (냉동), 200g, 1개'],
#  ['스파이시 치킨 치아바타 샌드위치 5ea (냉동), 975g, 1개'],
#  ['우리밀 대나무통 바게트9cm (냉동), 900g, 1개'],
#  ['안단잼 신선 사과잼, 460g, 1개'],
#  ['미니 뺑 오 초코렛 50ea (냉동), 1500g, 1개'],
#  ['오늘의일상 브런치 라이스 와플믹스 플레인, 1kg, 1개'],
#  ['미니 스트로베리 스퀘어 (냉동), 42g, 20개입'],
#  ['이엘후레쉬 햄체다치즈 샌드위치, 180g, 2개'],
#  ['이엘후레쉬 구워먹는 바질페스토 샌드 130g x 3개, 1세트'],
#  ['생크림 롤케익 (냉동), 280g, 1개'],
#  ['미디 헤이즐넛 드림 16ea (냉동), 1152g, 1개'],
#  ['미니 라즈베리 크라운 24ea (냉동), 1032g, 1개'],
#  ['그린래빗 대만식 삼색샌드, 80g, 4개'],
#  ['얌!(YAAM!) 부드러운 녹차단팥 롤, 430g, 1개'],
#  ['오븐에 구운 레몬 케이크, 40g, 8입'],
#  ['한끼의품격 더블 디럭스 버거 190g x 3팩 + 달콤한 불벅 140g x 3팩 (냉동), 1세트'],
#  ['근대골목단팥빵 치즈라떼번 (냉동), 75g, 5개'],
#  ['네니아 우리밀 초코머핀 20개입 (냉동), 600g, 1개'],
#  ['위고에빅토르 티라미스 (냉동), 250g, 1개'],
#  ['[쿠팡 직수입] 라비에 미니 크루아상 생지 버터 앤 초코 40입 (냉동), 1세트'],
#  ['네니아 찰보리 팬케익 (냉동), 30g, 20개'],
#  ['스페로스페라 럭키 초코 크레이프 케이크 (냉동), 750g, 1개'],
#  ['서울브레드 커스터드 크림슈 8개입 (냉동), 240g, 1개'],
#  ['이엘후레쉬 햄에멘탈치즈 샌드위치, 180g, 2개'],
#  ['브리오슈 버거번 (냉동), 50g, 48개'],
#  ['올바른 봉평 블랙메밀이 들어간 쫄깃한 호두과자 (냉동), 25g, 50개'],
#  ['호떡당 견과호떡 (냉동), 350g, 2팩'],
#  ['곰곰 딜라이트 치즈케익, 70g, 10개입'],
#  ['지유가오카 샬롯 드 쇼콜라 홀케이크 (냉동), 450g, 1개'],
#  ['서울브레드 녹차테린느 (냉동), 50g, 4개'],
#  ['플레잇 베이커리 더블치즈 베이글 (냉동), 110g, 6개입'],
#  ['달롤 초코롤 홀사이즈 (냉동), 380g, 1개'],
#  ['파리크라상 카스테라 녹차, 266g, 1개'],
#  ['신라명과 오갓빵 미니 크로아상 (냉동), 260g, 1개'],
#  ['페이브 아몬드 크로와상s (냉동), 75g, 4개입'],
#  ['풀무원 풀스키친 호밀이 들어간 딸기쨈포켓파이 생지 (냉동), 800g, 1개'],
#  ['닥터키친 단백질과자점 요거크림바 빵 (냉동), 66g, 3개'],
#  ['커브 크로아상 (냉동), 70g, 22개'],
#  ['곰곰 플레인 베이글, 720g, 1개'],
#  ['이엘후레쉬 터키브레스트 샌드위치, 185g, 2개'],
#  ['위고에빅토르 레드벨벳 (냉동), 270g, 1개'],
#  ['근대골목단팥빵 녹차생크림 단팥빵 (냉동), 135g, 5개'],
#  ['그린래빗 베이컨 에그 프랜치 토스트, 130g, 3개'],
#  ['파리크라상 카페 파운드 케익, 480g, 1개'],
#  ['티오페페스 초코츄러스 38cm (냉동), 55g, 10입'],
#  ['미지엄 다뜨사빵 고구마 (냉동), 120g, 5개입'],
#  ['단백질 과자점 단팥소보로 (냉동), 90g, 3입'],
#  ['벨라플레이트 두부 치즈케이크 (냉동), 150g, 1개'],
#  ['복음자리 딸기잼, 860g, 1개'],
#  ['누텔라 스프레드, 210g, 4개'],
#  ['후앙 리얼카라멜머핀, 90g, 5개'],
#  ['플레잇 베이커리 크로플 (냉동), 25g, 10개입'],
#  ['홍루이젠 호밀빵 햄 치즈 샌드위치, 74g, 4개'],
#  ['CHICAGOCAKE 레드벨벳 마카롱 케익 (냉동), 750g, 1개'],
#  ['그린래빗 듬뿍 햄 치즈 크로와상 샌드위치, 120g, 2개'],
#  ['삼립 허쉬 쿠앤크 스노우롤 3개입, 360g, 1개'],
#  ['나폴레옹베이커리 산딸기 크림치즈롤 (냉동), 395g, 1개'],
#  ['세미원푸드 갈릭버터난 커리소스세트 (냉동), 500g, 2개'],
#  ['플레이버랩 카페모카 다쿠아즈 (냉동), 30g, 10개'],
#  ['꽃셰프가 유기농 인증 야채퓨레 8개입, 640g, 1개'],
#  ['신라명과 오갓빵 애플시나몬파이 12p (냉동), 420g, 1개'],
#  ['예술방앗간 버터 크로플 (냉동), 150g, 1개'],
#  ['충주 사과빵, 420g, 1개'],
#  ['플레잇 커피콩빵 (냉동), 350g, 1개'],
#  ['그린래빗 대만식 트리플베리샌드, 70g, 4개'],
#  ['곰곰 단팥 붕어빵 900g, 1개'],
#  ['호떡당 호두단팥호떡 (냉동), 350g, 2팩'],
#  ['CHICAGO CAKE 그린티 무스케익 (냉동), 570g, 1개'],
#  ['서울브레드 테린느 50g x 4종 세트 (냉동), 1세트'],
#  ['하이원푸드 미니 붕어빵 단호박 (냉동), 1kg, 1개'],
#  ['안단잼 신선 복숭아잼, 460g, 1개'],
#  ['이엘후레쉬 구워먹는 모짜렐라치즈 샌드 130g x 3개, 1세트'],
#  ['CHICAGO CAKE 치즈 티라미수케익 (냉동), 548g, 1개'],
#  ['곰곰 딜라이트 리얼고구마 치즈케익 720g, 1개'],
#  ['빌리엔젤 백설기 롤케이크 (냉동), 500g, 1개'],
#  ['벤티 크로플 (냉동), 50g, 5개'],
#  ['테디 땅콩버터 100% 슈퍼청키, 454g, 1개'],
#  ['처카넛베이 클래식 뉴욕 치즈케이크 113g + 뉴욕 치즈케이크 113g (냉동), 1세트'],
#  ['생생빵상회 밀크비스킷 8개입 (냉동), 440g, 1개'],
#  ['곰곰 우유식빵, 660g, 1봉'],
#  ['지유가오카 샬롯 드 벨벳 홀케이크 (냉동), 450g, 1개'],
#  ['레몬치즈롤 조각 (냉동), 140g, 1개'],
#  ['끼리 크림치즈 롤케익 (냉동), 450g, 1개'],
#  ['더브레드블루 통밀식빵 (냉동), 440g, 1개'],
#  ['꽃셰프가 유기농 인증 고구마 플러스 단호박 퓨레 8개입, 640g, 1개'],
#  ['복음자리 햄치즈 샌드위치 (냉동), 70g, 8개'],
#  ['레디잇 부루마불 시금치 비프 라자냐 (냉동), 400g, 1팩'],
#  ['오뚜기 아임스틱 딸기잼, 20g, 50개'],
#  ['후앙 수제 녹차 브라우니, 130g, 2개'],
#  ['코알라 플레인크로와상 (냉동), 220g, 1개'],
#  ['그린래빗 샌드위치 카야샌드, 70g, 4개'],
#  ['세미원 오코노미야끼 (냉동), 1.4kg, 1개'],
#  ['위고에빅토르 피낭시에 8피스 기프트 세트 (냉동), 1세트'],
#  ['맨치트 단과자빵 생지 (냉동), 50g, 30개입'],
#  ['파스키에 오페라 케이크 (냉동), 260g, 2팩'],
#  ['신라명과 수제 핫도그용빵 (냉동), 50g, 20개입'],
#  ['꽃셰프가 유기농 인증 단호박 퓨레 8개입, 640g, 1개'],
#  ['삼립 고구마케익 5개입 (냉동), 450g, 1개'],
#  ['곰곰 뉴 클레이쿠키, 300g, 1개'],
#  ['신라명과 탕종치아바타 (냉동), 70g, 7개'],
#  ['나폴레옹베이커리 롤케이크 (냉동), 450g, 1개'],
#  ['맨치트 미니 애플턴오버 (냉동), 600g, 2개'],
#  ['벨기에 플레인 와플 (냉동), 75g, 5개'],
#  ['곰곰 대만식샌드위치 카야 280g, 70g, 4개입'],
#  ['삼립 까망베르 크림치즈 케익 5개입 (냉동), 375g, 1개'],
#  ['끼리 크림치즈 마카롱 (냉동), 25g, 6개'],
#  ['삼립 초코무스케익 5개입 (냉동), 425g, 1개'],
#  ['그린래빗 대만식 앙크림샌드, 80g, 4개'],
#  ['쉐푸드 시저치킨랩 샌드위치, 746g, 1팩'],
#  ['유니온트리 발효 A O P 이즈니 버터 쌀 크로와상 (냉동), 70g, 5개입'],
#  ['신라명과 블루베리 베이글S 6개입 (냉동), 720g, 1개'],
#  ['마담정 하트 마카롱 5구 세트 (냉동), 1세트'],
#  ['꽃샘 사양벌꿀, 2.4kg, 1개'],
#  ['커스타드 타르트 (냉동), 50g, 6개'],
#  ['삼립 티라미스 케익 5개입 (냉동), 400g, 1개'],
#  ['꽃셰프가 유기농 인증 고구마 퓨레 8개입, 640g, 1개'],
#  ['세미원 밀 또띠아 15cm 12입 (냉동), 312g, 12개'],
#  ['애프리코트 크라운 (냉동), 98g, 12개'],
#  ['청춘푸드 쑥 비거니 4입 (냉동), 260g, 1박스'],
#  ['초코 롤케익 (냉동), 280g, 1개'],
#  ['삼립 까망베르 크림치즈 케익 5개입 (냉동), 375g, 1개'],
#  ['지유가오카 핫초메 딥쇼콜라케이크 (냉동), 420g, 1개'],
#  ['삼립 초코무스케익 5개입 (냉동), 425g, 1개'],
#  ['한끼의품격 레알 불고기 버거180g x 3팩 + 매콤한 치킨벅 160g x 3팩 (냉동), 1세트'],
#  ['눈꽃치즈콘 어니언 핫도그 (냉동), 155g, 3개'],
#  ['닥터키친 단백질과자점 블루베리바 빵 (냉동), 66g, 3개'],
#  ['건강한 쌀베이커리 무설탕 플레인 쌀식빵 (냉동), 355g, 1개'],
#  ['서울브레드 초코테린느 (냉동), 50g, 4개'],
#  ['삼립 티라미스 케익 5개입 (냉동), 400g, 1개'],
#  ['신라명과 블루베리 베이글S 6개입 (냉동), 720g, 1개'],
#  ['그린래빗 대만식 앙크림샌드, 80g, 4개'],
#  ['더바움 트리플 롤케이크 플레인 105g + 쇼콜라 105g + 스트로베리 105g (냉동), 315g, 1세트'],
#  ['서울브레드 생크림 크로와상 4p (냉동), 320g, 1개'],
#  ['파스키에 라즈베리 타르트 5개입 (냉동), 550g, 1개'],
#  ['곰곰 뉴 클레이쿠키, 300g, 1개'],
#  ['지유가오카 샬롯 드 바나나 홀케이크 (냉동), 450g, 1개'],
#  ['이랜드이츠 애슐리 뉴욕 치즈케이크 (냉동), 460g, 1개'],
#  ['닥터키친 단백질과자점 리얼녹차바 빵 (냉동), 66g, 3개'],
#  ['곰곰 우유식빵, 660g, 1봉'],
#  ['청아냉동식품 발효 고기왕찐빵 15개입 (냉동), 825g, 1개'],
#  ['파리크라상 베이크드 치즈케이크 (냉동), 700g, 1개'],
#  ['맘쿠킹 브리도 미니 시나몬스웰 생지 (냉동), 35g, 20개'],
#  ['리얼 시몬카스테라, 22g, 9개'],
#  ['파이만쥬 팥앙금 55g x 3p + 백앙금 70g x 3p, 1세트'],
#  ['서울커피 먹물 앙버터식빵 (냉동), 100g, 3개'],
#  ['맨치트 미니 딸기쨈파이 (냉동), 345g, 2개'],
#  ['한끼의품격 달콤한 불벅 140g x 3팩 + 고소한 치즈벅 140g x 3팩 (냉동), 1세트'],
#  ['플레잇 불고기베이크 3개입 (냉동), 600g, 1개'],
#  ['커스타드 타르트 미니 (냉동), 25g, 11개'],
#  ['플레인 베이글 6개입 (냉동), 594g, 1개'],
#  ['뉴허니브레드 (냉동), 1190g, 1개'],
#  ['맨치트 서울식품 생지 사각 페스츄리 시트 중 120개입 (냉동), 9000g, 1개'],
#  ['서울브레드 딸기 크림슈 8개입 (냉동), 240g, 1개'],
#  ['달콤 바삭 갈릭스틱, 180g, 2개'],
#  ['맨치트 미니 고구마파이 (냉동), 345g, 2개'],
#  ['착한떡 아기바게트 찰떡생지 초코 (냉동), 50g, 10개'],
#  ['천일식품 초코케이크100 4봉지 (냉동), 240g, 1개'],
#  ['CJ제일제당 크레잇 아메리칸칠리 서브샌드위치(냉동), 552g, 1개'],
#  ['후앙 리얼블루베리머핀, 90g, 5개'],
#  ['맘쿠킹 브리도 미니 애플턴 오버 생지 (냉동), 40g, 15개'],
#  ['CJ제일제당 크레잇 크리미 어니언&할라피뇨 서브 샌드위치(냉동), 580g, 1개'],
#  ['성수동베이커리 우리밀 크림치즈 팥 붕어빵 (냉동), 900g, 1개'],
#  ['삼립 빅 블루베리 롤케익 (냉동), 430g, 1개'],
#  ['몽슈슈 도지마롤 홀, 350g, 1개'],
#  ['청춘푸드 단호박 비거니 4입 (냉동), 260g, 1박스'],
#  ['크로플 (냉동), 275g, 1개'],
#  ['청아냉동식품 애플 팬케익 (냉동), 61g, 30개입'],
#  ['삼립 mini 야채 호빵 20개입 (냉동), 820g, 1개'],
#  ['곰곰 블루베리 베이글, 720g, 1개'],
#  ['한끼의품격 닭가슴살 브리또 (냉동), 180g, 3팩'],
#  ['얌!(YAAM!) 크림 단팥빵, 91g, 12개'],
#  ['서울브레드 까눌레 (냉동), 40g, 4개'],
#  ['모카 마카롱 (냉동), 34g, 12개입'],
#  ['세미원 밀또띠아 20cm 12입 (냉동), 372g, 8개'],
#  ['곰곰 버터 식빵, 450g, 1개'],
#  ['마담정 마카롱 5구 세트 (냉동), 1세트'],
#  ['닥터키친 단백질과자점 얼그레이바 빵 (냉동), 66g, 3개'],
#  ['푸딩팩토리 플레인 와플 (냉동), 360g, 2개'],
#  ['뭉게구름 프리미엄 수제 마카롱 4개입 96g (냉동), 1세트'],
#  ['몽슈슈 쁘띠 도지마롤, 300g, 1개'],
#  ['착한떡 아기바게트 찰떡생지 초코 (냉동), 50g, 10개'],
#  ['맨치트 서울식품 생지 사각 페스츄리 시트 중 120개입 (냉동), 9000g, 1개'],
#  ['청춘푸드 단호박 비거니 4입 (냉동), 260g, 1박스'],
#  ['몽슈슈 쁘띠 도지마롤, 300g, 1개'],
#  ['얌 크림치즈 마늘빵 (냉동), 116g, 6개'],
#  ['존쿡델리미트 마스터의브레드 치아바타 3개입 (냉동), 240g, 4개'],
#  ['서울브레드 까눌레 (냉동), 40g, 4개'],
#  ['푸딩팩토리 플레인 와플 (냉동), 360g, 2개'],
#  ['모카 마카롱 (냉동), 34g, 12개입'],
#  ['홍루이젠 호밀빵 치즈 샌드위치, 67g, 4개'],
#  ['디앤비 바바리안필링 도넛 (냉동), 65g, 10개'],
#  ['서울커피 우유 앙버터식빵 (냉동), 100g, 3개'],
#  ['파스키에 레몬머랭 타르트 2p (냉동), 195g, 2개'],
#  ['곰곰 달달 크림 만쥬, 1개'],
#  ['싱글팩토리 따봉버거 (냉동), 145g, 6개'],
#  ['오늘의일상 브런치 라이스 와플믹스 초코, 1kg, 1개'],
#  ['프레시오늘 신선냉장 달지않은 견과류 약식 흑당카스테라, 630g, 1개'],
#  ['나폴레옹베이커리 마카롱 6구 (냉동), 108g, 1개'],
#  ['고메 베이커리 달콤콘치즈 페스츄리 (냉동), 320g, 1개'],
#  ['제키스 초콜릿 바움쿠헨 (냉동), 165g, 1개'],
#  ['교아당 호땅강정, 28g, 9입'],
#  ['밀크앤허니 허니까망베르 치아바타 샌드위치 3개입 (냉동), 555g, 1개'],
#  ['곰곰 대만식샌드위치 햄치즈에그, 80g, 4개입'],
#  ['서울브레드 미니치즈 우유식빵 체다치즈 3ea (냉동), 225g, 1개'],
#  ['마담정 벚꽃 마카롱 5구 세트 (냉동), 1세트'],
#  ['후앙 왕소보로빵, 140g, 3개'],
#  ['서울브레드 미니치즈 우유식빵 고다치즈 3ea (냉동), 225g, 1개'],
#  ['와상와상 미니 크로와상 (냉동), 600g, 1팩'],
#  ['CHICAGO CAKE 우유생크림 초코케익 (냉동), 600g, 1개'],
#  ['서울브레드 초코 크림 홀케이크 (냉동), 550g, 1개'],
#  ['서울브레드 딸기 크림 홀케이크 (냉동), 550g, 1개'],
#  ['서울브레드 순우유 크림 홀케이크 (냉동), 500g, 1개'],
#  ['뺑 오 초콜릿 24ea (냉동), 1800g, 1개'],
#  ['디엔비 백앙금베터보스톤 도넛 50입 (냉동), 3000g, 1박스'],
#  ['디엔비 아몬드화이트링 도넛 50입 (냉동), 2500g, 1박스'],
#  ['디엔비 단호박곡물 도넛 50입 (냉동), 2500g, 1박스'],
#  ['디엔비 딸기쿠키링 도넛 50입 (냉동), 2500g, 1박스'],
#  ['곰곰 모닝롤 (냉동), 26g, 20개입'],
#  ['CHICAGO CAKE 더블 초코케익 (냉동), 550g, 1개'],
#  ['신라명과 인생모닝롤, 30g, 10개입'],
#  ['근대골목단팥빵 소보로 단팥빵 (냉동), 80g, 5개'],
#  ['프레시오늘 통마늘 양파를 갈아만든 수제 양파육쪽마늘빵 2p (냉동), 540g, 1팩'],
#  ['코만스 뉴트로팩 120g x 4종 티라미수 컵케이크 세트 (냉동), 1세트'],
#  ['간식엔 우리밀 슈크림 붕어빵 (냉동), 800g, 1개'],
#  ['맘쿠킹 브리도 크로와상 생지 (냉동), 60g, 10개'],
#  ['푸아그라 스프레드 플레인, 125g, 1개'],
#  ['위고에빅토르 마블파운드, 350g, 1개'],
#  ['킹즈 치아바타 핫도그 프리미엄 플레인 5개입 (냉동), 925g, 1개'],
#  ['디앤비도너츠 딸기맛필링 도넛 (냉동), 65g, 10개'],
#  ['핫도그빵 (냉동), 100g, 5개'],
#  ['마리브리자드 바닐라 시럽, 700ml, 1개'],
#  ['파미유 떠먹는 뉴욕치즈 (냉동), 165g, 2개'],
#  ['춘천 감자빵 3개입 (냉동), 360g, 1개'],
#  ['우드앤브릭 뺑오 쇼콜라 (냉동), 53g, 4개'],
#  ['삼립 mini 단팥 호빵 20개입 (냉동), 820g, 1개'],
#  ['던킨 딸기 듬뿍 미니도넛 (냉동), 25g, 10개입'],
#  ['까까 카라멜 치즈타르트 4입 (냉동), 140g, 1개'],
#  ['근대골목단팥빵 근대골목 단팥빵 110g + 소보로 단팥빵 80g + 콩떡콩떡 105g + 크림치즈 70g + 치즈라떼번 75g (냉동), 1세트'],
#  ['후앙 굿모닝 세트, 1세트'],
#  ['유니온트리 발효 A O P 이즈니 버터 크로와상 (냉동), 80g, 5개입'],
#  ['던킨도너츠 레인보우 초코링 도넛 (냉동), 51g, 8입'],
#  ['아티제 식빵의 정석, 450g, 1개'],
#  ['삼립 호빵 발효미종 단팥, 92g, 14개입'],
#  ['프리미엄 버터 크로아상 (냉동), 70g, 24개'],
#  ['청춘푸드 카카오 비거니 4입 (냉동), 260g, 1박스'],
#  ['삼립 리얼 스위트 고구마케익 10개입, 720g, 1개'],
#  ['유니온트리 발효 크로와상 (냉동), 70g, 5개입'],
#  ['간식엔 우리밀 팥 붕어빵 (냉동), 800g, 1개'],
#  ['몽상클레르 쇼콜라 파운드 (냉동), 250g, 1개'],
#  ['몽상클레르 시트롱파운드 (냉동), 250g, 1개'],
#  ['삼립 카페스노우 바스크 치즈케익 2개입 (냉동), 270g, 1개'],
#  ['얌 햄에그 클럽 샌드위치, 490g, 1개'],
#  ['복음자리 과일잼(딸기잼)-500g, 500g, 1개'],
#  ['네니아 무농약 우리밀 유자 마들렌 (냉동), 20g, 20개'],
#  ['콘치즈 피자빵 (냉동), 100g, 5개'],
#  ['얌 치즈후레쉬팡 35개입, 700g, 1개'],
#  ['삼립 리얼 미니 생크림 파운드 20개입, 720g, 1개'],
#  ['CUCINA 찰 츄러스 (냉동), 1kg, 2팩'],
#  ['몽슈슈 치즈롤 하프 (냉동), 250g, 1개'],
#  ['한끼의품격 비프 브리또 (냉동), 180g, 3팩'],
#  ['유니온트리 발효 쌀 크로와상 (냉동), 70g, 5개입'],
#  ['헬스레시피 몽크슈 액상 WITH 알룰로스, 530g, 1개'],
#  ['까까 더블치즈 스틱케익 4입 (냉동), 200g, 1개'],
#  ['설탕없는과자공장 단단파운드, 50g, 3개'],
#  ['곰곰 리얼버터 클레이쿠키, 300g, 1개'],
#  ['삼립 빅 실키 롤케익 (냉동), 430g, 1개'],
#  ['곰곰 딸기 필링 도넛 300g, 30g, 10개입'],
#  ['착한떡 아기바게트 찰떡생지 팥 (냉동), 50g, 10개'],
#  ['삼립 골든버터식빵, 420g, 2개'],
#  ['네니아 우리밀 유자머핀 20개입 (냉동), 600g, 1개'],
#  ['밀크앤허니 24결 미니크로와상 (냉동), 168g, 1개'],
#  ['간식엔 빅 크림치즈 프레첼 (냉동), 100g, 4개'],
#  ['신라명과 오갓빵 플레인 크로플 (냉동), 160g, 1개'],
#  ['오뚜기 리얼 멕시칸 브리또 페페로니 트리플치즈 (냉동), 125g, 4개'],
#  ['건강한 쌀베이커리 무설탕 어니언 쌀식빵 (냉동), 365g, 1개'],
#  ['청춘푸드 비건 앙파운드 단호박 앤 고구마 3입 (냉동), 300g, 1박스'],
#  ['서울브레드 초코 크림슈 8개입 (냉동), 240g, 1개'],
#  ['조트 몬테 스낵, 29g, 8개'],
#  ['푸딩카페 바움쿠헨 플레인 (냉동), 360g, 1개'],
#  ['성수동베이커리 우리밀 칼슘 슈크림 붕어빵 (냉동), 900g, 1개'],
#  ['카야하우스 프리미엄 카야잼 그린, 2.5kg, 1개'],
#  ['한끼의품격 레알 불고기 버거 180g x 3팩 + 고소한 치즈벅 140g x 3팩 (냉동), 1세트'],
#  ['후앙 크랜베리크림 치즈식빵, 180g, 2개'],
#  ['리본 페스츄리파이 8개입, 304g, 1개'],
#  ['유니온트리 발효 크로와상 (냉동), 80g, 5개입'],
#  ['곰곰 크로크 무슈 (냉동), 130g, 2개'],
#  ['푸딩카페 바움쿠헨 쇼콜라 (냉동), 360g, 1개'],
#  ['페이브 플레인 크로와상s (냉동), 43g, 4개입'],
#  ['디앤비 블랙라즈베리맛 필링 도넛 (냉동), 60g, 10개'],
#  ['몽슈슈 몬테카를로 오리지널 (냉동), 44g, 5개'],
#  ['유니온트리 발효 A O P 이즈니 버터 크로와상 (냉동), 70g, 5개입'],
#  ['소시지롤빵 (냉동), 80g, 6개'],
#  ['파스키에 팡올레 빵 (냉동), 280g, 2팩'],
#  ['던킨도너츠 레인보우 핑크링 도넛 (냉동), 51g, 8입'],
#  ['삼립 정통 밤 만쥬, 1080g, 1개'],
#  ['유니온트리 청양고추 소세지 페스츄리 (냉동), 110g, 4개입'],
#  ['더건강한쌀베이글 어니언 쌀베이글 3개입 (냉동), 330g, 1개'],
#  ['더브레드블루 통밀발효종빵 2개입 (냉동), 600g, 1개'],
#  ['미니 헤이즐넛 초코 스퀘어 (냉동), 42g, 20개입'],
#  ['삼립 카페스노우 스노우롤초코 2개입 (냉동), 240g, 1개'],
#  ['안단잼 저칼로리 블루베리잼, 220g, 1개'],
#  ['눈꽃치즈 사천 핫도그 (냉동), 155g, 3개'],
#  ['베키아에누보 발타자 올리브 바게트 (냉동), 320g, 2개'],
#  ['키플 흑임자 아이스케이크바 (냉동), 90g, 2개'],
#  ['삼립 허니버터브레드 (냉동), 1450g, 1개'],
#  ['쉐푸드 닭가슴살 흑임자 샌드위치, 512g, 1개'],
#  ['디앤비도너츠 바닐라후로스트 도넛 (냉동), 50g, 10개'],
#  ['생생빵상회 미니 메이플피칸 & 미니 크로와상 (냉동), 355g, 1개'],
#  ['설탕없는과자공장 고단파운드, 73g, 3개'],
#  ['오뚜기 리얼 멕시칸 브리또 치폴레살사치킨 (냉동), 125g, 4개'],
#  ['디엔비 딸기맛필링 도너츠 50입 (냉동), 3250g, 1박스'],
#  ['프레시지 갈릭 가득 바게트볼 (냉동), 105g, 5개'],
#  ['청아냉동식품 자색이 어우러진 고구마 찐빵 15개입 (냉동), 825g, 1개'],
#  ['청춘푸드 비건 앙파운드 쑥 앤 팥 3입 (냉동), 300g, 1박스'],
#  ['맘쿠킹 브리도 미니 뺑라크림 생지 (냉동), 40g, 15개'],
#  ['세미원 갈릭 버터 난 (냉동), 1kg, 1개'],
#  ['근대골목단팥빵 밤콘소프트 5개입 (냉동), 600g, 1개'],
#  ['바른웰 우리밀 단팥품은 붕어빵 (냉동), 50g, 20개'],
#  ['프레시오늘 에어프라이어 바삭고소 수제 바게트 3p (냉동), 690g, 1개'],
#  ['청아냉동식품 발효왕찐빵 15개입 (냉동), 825g, 1개'],
#  ['푸딩팩토리 갈릭 허니브레드 (냉동), 600g, 2개'],
#  ['곰곰 브라운브레드, 100g, 6개'],
#  ['푸딩팩토리 우리쌀 앙꼬붕 빵 (냉동), 500g, 2개'],
#  ['그녀의 빵공장 쌀샌드위치 불고기 (냉동), 160g, 2개입'],
#  ['그녀의 빵공장 쌀샌드위치 콘샐러드 (냉동), 150g, 2개입'],
#  ['진주햄 포차 전통찹쌀호떡 (냉동), 300g, 3개입'],
#  ['파미유 흑임자 찰떡샌드위치 (냉동), 70g, 4개'],
#  ['쉐푸드 BELT(베이컨 에그 양상추 토마토) 샌드위치, 488g, 1개'],
#  ['파미유 인절미 찰떡샌드위치 (냉동), 70g, 4개'],
#  ['파스키에 쁘띠포 (냉동), 179g, 1개'],
#  ['몽슈슈 몬테카를로 후람보와즈 케이크 (냉동), 40g, 5개입'],
#  ['까까 애플타르트 4입 (냉동), 180g, 1개'],
#  ['맘쿠킹 피낭시에 올버터 생지 (냉동), 45g, 7개'],
#  ['[몽상클레르] 베이컨치즈키슈 2입 (냉동), 300g, 1개'],
#  ['맘쿠킹 브리도 뺑라크림 생지 (냉동), 90g, 8개'],
#  ['신라명과 플레인 베이글G 6개입 (냉동), 720g, 1개'],
#  ['설탕없는과자공장 파단파운드, 72g, 3개'],
#  ['설탕없는과자공장 스콘 플레인 48g + 흑임자 48g + 시나몬 48g 세트, 1세트'],
#  ['풀무원 토이쿠키 만들기 브레드이발소 (냉동), 305g, 1개'],
#  ['삼립 밀크후레쉬팡, 560g, 1개'],
#  ['밀러가또 김밥을 꿈꾸는 라즈베리 롤케익 (냉동), 415g, 1개'],
#  ['페이브 미스터리 플레넷(냉동), 150g, 2개'],
#  ['몽슈슈 떠먹는치즈케이크 (냉동), 200g, 1개'],
#  ['오븐에 구운 바나나 파운드, 50g, 10입'],
#  ['더브레드블루 시금치 치아바타 3개입 (냉동), 600g, 1개'],
#  ['더건강한쌀베이글 플레인 쌀베이글 3개입 (냉동), 330g, 1개'],
#  ['미니 애플 스퀘어 (냉동), 42g, 20개입'],
#  ['생생빵상회 미니 시나몬 롤 (냉동), 43g, 8개'],
#  ['착한떡 바게트찰떡생지 달콤한맛 (냉동), 50g, 10개'],
#  ['유니온트리 녹차 생크림 스콘 (냉동), 100g, 4개입'],
#  ['토이쿠키 만들기 숲속 동물들 생일파티 (냉동), 1세트, 6종 컬러 반죽 + 모양틀 + 선물용봉투'],
#  ['테이트 바질 치킨랩샌드위치 (냉동), 125g, 3개입'],
#  ['서울브레드 미니치즈 우유식빵 콜비잭치즈 3ea (냉동), 225g, 1개'],
#  ['파미유 떠먹는 우유케익 (냉동), 150g, 2개'],
#  ['얄라 후무스 비트토마토 (냉동), 100g, 3개'],
#  ['반데모르텔 미니 크로아상 (냉동), 25g, 20개'],
#  ['한끼의품격 달콤한 불벅버거 5팩 (냉동), 700g, 1개'],
#  ['신성제과 우리밀초코구겔호프 6개입 (냉동), 300g, 1개'],
#  ['맘쿠킹 커스타드 미니도넛 생지 (냉동), 25g, 15개'],
#  ['신라명과 인생식빵, 420g, 1개'],
#  ['프렌치 미니 크로아상 생지 10입 (냉동), 250g, 1개'],
#  ['곰곰 통밀 식빵, 430g, 2개'],
#  ['유니온트리 발효 A O P 이즈니 버터 크로와상 (냉동), 80g, 5개입'],
#  ['삼립 56시간 저온숙성 탕종 숙식빵, 840g, 1개'],
#  ['플레잇 호두과자 (냉동), 600g, 1개'],
#  ['빵어니스타 노오일 파운드 인절미 2봉지 (냉동), 280g, 1개'],
#  ['건강한 쌀베이커리 블루베리 쌀식빵 (냉동), 365g, 1개'],
#  ['산내들농원 사양벌꿀, 2kg, 1개'],
#  ['생생빵상회 미니 시나몬롤 & 미니 크로와상 (냉동), 292g, 1개'],
#  ['싱글팩토리 숯불 따봉버거 (냉동), 150g, 6개'],
#  ['설탕없는과자공장 플레인 콩쿠키, 45g, 3개'],
#  ['위고에빅토르 플레인 스콘 (냉동), 95g, 3개'],
#  ['파스키에 피치 초코렛칩 브리오슈 6개입 (냉동), 225g, 2팩'],
#  ['푸딩팩토리 몬테크리스토 샌드위치 (냉동), 680g, 1개'],
#  ['파스키에 플란 에그타르트 (냉동), 750g, 1개'],
#  ['바닐라 크림 크라운 12ea (냉동), 1176g, 1개'],
#  ['버리푸드 어니언 베이글 6개입 (냉동), 594g, 1개'],
#  ['몽슈슈 떠먹는 도지마 (냉동), 180g, 1개'],
#  ['남대문가메골손만두 왕찐빵 (냉동), 700g, 1개'],
#  ['곰곰 프렌치버터 토스트, 420g, 1개'],
#  ['맘쿠킹 라이 브레드 생지 (냉동), 45g, 10개'],
#  ['빵어니스타 노오일 파운드 단호박 2봉지 (냉동), 280g, 1개'],
#  ['유니온트리 발효 A O P 이즈니 버터 크로와상 (냉동), 70g, 5개입'],
#  ['몽슈슈 도지마롤 하프, 175g, 1개'],
#  ['삼립 로만밀 통밀식빵, 420g, 2개입'],
#  ['푸딩팩토리 후렌치 토스트 (냉동), 400g, 2개'],
#  ['존쿡델리미트 모타델라 샌드위치 (냉동), 254g, 1팩'],
#  ['맘쿠킹 플레인 미니도넛 생지 (냉동), 16g, 20개'],
#  ['빵어니스타 노오일 파운드 쑥 2봉지 (냉동), 280g, 1개'],
#  ['오리온 초코파이 하우스 오리지널, 52g, 4입'],
#  ['더브레드블루 두부라우니 2개입 (냉동), 240g, 1개'],
#  ['아티제 헤이질넛 코코넛 쿠키, 80g, 1개'],
#  ['오뚜기 고소한 쌀 또띠아, 240g, 1개'],
#  ['빵어니스타 말차 두부 케이크 2봉지 (냉동), 220g, 1개'],
#  ['베즐리 바스크 치즈 케이크 (냉동), 180g, 1개'],
#  ['나폴레옹베이커리 파이쿠키, 119g, 1개'],
#  ['곰곰 우유토스트 식빵, 350g, 2개'],
#  ['맘쿠킹 프랑스 프렌치 미니도넛 생지 (냉동), 37g, 9개'],
#  ['써드베이커리 갈릭파이 15개입 (냉동), 360g, 1개'],
#  ['건강한 쌀베이커리 시나몬 레이즌 쌀식빵 (냉동), 365g, 1개'],
#  ['대림선 국민간식 옛날 붕어빵 단팥맛 (냉동), 500g, 1개'],
#  ['곰곰 우유식빵, 330g, 1봉'],
#  ['바비브레드 할라피뇨 치아바타 (냉동), 300g, 1개'],
#  ['맘쿠킹 브리도 플레인 치아바타 생지 (냉동), 140g, 5개'],
#  ['삼립 아침엔 우유토스트 식빵, 330g, 2개'],
#  ['세미원 수제꽃빵 (냉동), 30g, 30개'],
#  ['삼립 연유버터 스프레드, 500g, 1개'],
#  ['달롤 진천 흑임자 쌀파운드 (냉동), 150g, 1개'],
#  ['삼립 카페스노우 생크림카스테라 2개입 (냉동), 190g, 1개'],
#  ['근대골목단팥빵 콩떡콩떡 (냉동), 105g, 5개'],
#  ['푸딩팩토리 크로크무슈 (냉동), 640g, 1개'],
#  ['유니온트리 생크림 스콘 (냉동), 100g, 4개입'],
#  ['제로베이커리 제로 스콘 (냉동), 55g, 1봉'],
#  ['곰곰 통밀식빵, 420g, 1개'],
#  ['바비브레드 까망 쫀득 크런치 (냉동), 260g, 1개'],
#  ['교토마차롤 조각 (냉동), 130g, 1개'],
#  ['쿠앤크 치즈케익 (냉동), 110g, 2개'],
#  ['삼립 토종효모로 만든 통밀식빵, 755g, 1개'],
#  ['바비브레드 먹물 치즈 치아바타 (냉동), 300g, 1개'],
#  ['티라미스롤 조각 (냉동), 130g, 1개'],
#  ['푸딩팩토리 후렌치 토스트 (냉동), 400g, 2개'],
#  ['맘쿠킹 플레인 미니도넛 생지 (냉동), 16g, 20개'],
#  ['빵어니스타 노오일 파운드 쑥 2봉지 (냉동), 280g, 1개'],
#  ['미각제빵소 이즈니버터롤, 520g, 1개'],
#  ['오리온 초코파이 하우스 오리지널, 52g, 4입'],
#  ['더브레드블루 두부라우니 2개입 (냉동), 240g, 1개'],
#  ['오뚜기 고소한 쌀 또띠아, 240g, 1개'],
#  ['빵어니스타 말차 두부 케이크 2봉지 (냉동), 220g, 1개'],
#  ['베즐리 바스크 치즈 케이크 (냉동), 180g, 1개'],
#  ['나폴레옹베이커리 파이쿠키, 119g, 1개'],
#  ['곰곰 우유토스트 식빵, 350g, 2개'],
#  ['맘쿠킹 프랑스 프렌치 미니도넛 생지 (냉동), 37g, 9개'],
#  ['써드베이커리 갈릭파이 15개입 (냉동), 360g, 1개'],
#  ['건강한 쌀베이커리 시나몬 레이즌 쌀식빵 (냉동), 365g, 1개'],
#  ['대림선 국민간식 옛날 붕어빵 단팥맛 (냉동), 500g, 1개'],
#  ['곰곰 우유식빵, 330g, 1봉'],
#  ['대림선 국민간식 옛날 붕어빵 슈크림맛 (냉동), 500g, 1개'],
#  ['삼립 소프트 에그타르트 6p (냉동), 300g, 1개'],
#  ['바비브레드 할라피뇨 치아바타 (냉동), 300g, 1개'],
#  ['맘쿠킹 브리도 플레인 치아바타 생지 (냉동), 140g, 5개'],
#  ['더바움 아이펠바움 (냉동), 70g, 1개'],
#  ['더브레드블루 고구마 바게트 2개입 (냉동), 360g, 1개'],
#  ['삼립 아침엔 우유토스트 식빵, 330g, 2개'],
#  ['세미원 수제꽃빵 (냉동), 30g, 30개'],
#  ['삼립 연유버터 스프레드, 500g, 1개'],
#  ['달롤 진천 흑임자 쌀파운드 (냉동), 150g, 1개'],
#  ['근대골목단팥빵 콩떡콩떡 (냉동), 105g, 5개'],
#  ['푸딩팩토리 크로크무슈 (냉동), 640g, 1개'],
#  ['유니온트리 생크림 스콘 (냉동), 100g, 4개입'],
#  ['제로베이커리 제로 스콘 (냉동), 55g, 1봉'],
#  ['비스테까 골드피콜로 허니블루 티라미수 (냉동), 100g, 1개'],
#  ['곰곰 통밀식빵, 420g, 1개'],
#  ['CJ제일제당 화권 꽃빵 (냉동), 550g, 1개'],
#  ['풀무원 신 생가득 통밀 또띠아, 150g, 1개'],
#  ['바비브레드 까망 쫀득 크런치 (냉동), 260g, 1개'],
#  ['쿠앤크 치즈케익 (냉동), 110g, 2개'],
#  ['삼립 토종효모로 만든 통밀식빵, 755g, 1개'],
#  ['바비브레드 먹물 치즈 치아바타 (냉동), 300g, 1개'],
#  ['끼리 베이크 치즈케익 찰떡 (냉동), 60g, 9개'],
#  ['티라미스롤 조각 (냉동), 130g, 1개'],
#  ['제로베이커리 제로와플 코코넛 (냉동), 48g, 1봉'],
#  ['제로베이커리 제로 크림치즈타르트 조각 (냉동), 55g, 1봉'],
#  ['맘쿠킹 초코 미니 도넛 생지 (냉동), 42g, 9개'],
#  ['단백질과자점 카카오 크림치즈 소보로 (냉동), 90g, 3개'],
#  ['바비브레드 황제를 위하여 (냉동), 340g, 1개'],
#  ['초코롤 조각 (냉동), 120g, 1개'],
#  ['올바른 새싹 귀리 츄러스 스틱 (냉동), 1kg, 1개'],
#  ['크리스피크림도넛 오리지널 글레이즈드, 47g, 9개'],
#  ['크림가득 부드럽고 달콤한 만쥬 (냉동), 600g, 1개'],
#  ['밀크앤허니 월넛파운드 케이크, 650g, 1개'],
#  ['복음자리 진심의 딸기, 1kg, 1개'],
#  ['그린래빗 샌드위치 트리플베리, 70g, 8개'],
#  ['후앙]노아르블랑 케익 (냉동), 520g, 1개'],
#  ['후앙 산딸기롤케익, 600g, 1개'],
#  ['복음자리 딸기 샌드위치 (냉동), 65g, 8개'],
#  ['후앙 에스프레소생크림롤케익, 550g, 1개'],
#  ['집으로온 핑크퐁 아기상어 클레이쿠키 만들기 (냉동), 250g, 1개'],
#  ['후앙 녹차 생크림 롤케익, 540g, 1개'],
#  ['아티제 바스크 치즈케이크, 500g, 1개'],
#  ['안단잼 저칼로리 블루베리 콩포트, 220g, 1개'],
#  ['신성제과 에그타르트 선물용 12개입 (냉동), 260g, 1개'],
#  ['플레이버랩 다크초콜릿 다쿠아즈 (냉동), 30g, 10개'],
#  ['밀크앤허니 바질치즈 치아바타 샌드위치 4개입 (냉동), 780g, 1개'],
#  ['후앙 반전 용돈 케익 만들기 세트 1호 330g, 1세트'],
#  ['지유가오카 샬롯 드 쇼콜라 케이크 (냉동), 450g, 1개'],
#  ['메나쥬리 강릉초당두부 케이크 (냉동), 450g, 1개'],
#  ['풍요한아침 에그타르트 (냉동), 540g, 1개'],
#  ['꽃샘 아카시아 꿀, 1kg, 1개'],
#  ['가가농장 팩벌집꿀, 470g, 1개'],
#  ['지유가오카 딥쇼콜라 케이크 (냉동), 420g, 1개'],
#  ['벤탄마켓 스위트갈릭 반미바게트 10p (냉동), 850g, 1개'],
#  ['나뚜루 뉴썬리치 아이스크림 케이크 947ml (냉동) + 보냉백, 1개'],
#  ['곰곰 바질 치킨 파니니 샌드위치, 1개'],
#  ['프레시오늘 신선냉장 한끼든든 한돈한우 수제버거, 280g, 2개'],
#  ['안나 크로플 (냉동), 60g, 6개'],
#  ['콩쉐프 미니슈크림파이 냉동생지 (냉동), 35g, 20개'],
#  ['안단잼 오리지널 코코넛잼, 220g, 1개'],
#  ['그린래빗 옛날식 감자고로케 158g x 3개입, 474g, 1개'],
#  ['백화산 벌꿀, 2kg, 1개'],
#  ['조인 누테이블 에그 타르트 6개입 (냉동), 270g, 1개'],
#  ['카야 화이트 생크림 케이크 (냉동), 200g, 2개'],
#  ['까까 떠먹는 더블치즈 케익 3입 (냉동), 480g, 1개'],
#  ['삼립 카페스노우 쿠키앤크림 왕슈 (냉동), 108g, 12입'],
#  ['빌리엔젤 고구마케이크 S, 1000g, 1개'],
#  ['나폴레옹 슈톨렌 (냉동), 287g, 1개'],
#  ['비스테까 골드 피콜로 티라미수 3종 기프트세트 (냉동), 100g, 3개'],
#  ['오리온 초코파이하우스 베리러브, 60g, 8입'],
#  ['몽슈슈 롤쿠키 M, 408g, 1개'],
#  ['신라명과 브라우니 쿠키 16p, 304g, 1개'],
#  ['명류당 제주 찰보리빵, 30g, 20개'],
#  ['그린래빗 듬뿍햄 페스트리 샌드위치C, 155g, 2개'],
#  ['설탕없는과자공장 스콘 플레인 48g + 흑임자 48g + 시나몬 48g + 마늘올리브 50g + 초코무화과 50g + 모카 50g 세트, 294g, 1세트'],
#  ['사조 한입피자 콤비네이션 4개입, 320g, 2개'],
#  ['비스테까 티라미수 골드 피콜로 기프트세트 오리지널 (냉동), 100g, 3개'],
#  ['푸른빈 동결건조 로얄제리분말, 100g, 1개'],
#  ['다크 치아바타 (냉동), 108g, 10개'],
#  ['복음자리 대상 잼 선물세트 8호, 1세트'],
#  ['오뚜기 리얼 멕시칸 라이스 브리또 불고기 (냉동), 125g, 4개'],
#  ['몽슈슈 몬테카를로 깔루아 밀크 케이크 (냉동), 40g, 10개'],
#  ['우리밀 대나무통 바게트6cm (냉동), 500g, 1개'],
#  ['1883메종루틴 로스티드 헤이즐넛향 시럽 1L + 시럽펌프 세트, 1세트'],
#  ...]

# %%
import pandas as pd
df=pd.DataFrame(total_data_list)

# %%
df.to_csv('wordtext4-1.txt',index=False)

# %%
from konlpy.tag import Twitter 
from collections import Counter

# %%
file = open('wordtext4-1.txt', 'r', encoding="UTF-8")

lists = file.readlines()

file.close()

#lists

# %%
twitter = Twitter() 
morphs = [] 

for sentence in lists: 
    morphs.append(twitter.pos(sentence)) 
print(morphs)
# Out:
# [[('0', 'Number'), ('\n', 'Foreign')], [('"', 'Punctuation'), ('크리스피크림', 'Noun'), ('도넛', 'Noun'), ('오', 'Modifier'), ('리지', 'Noun'), ('널', 'Noun'), ('글레이', 'Noun'), ('즈', 'Modifier'), ('드', 'Noun'), (',', 'Punctuation'), ('47', 'Number'), ('g', 'Alpha'), (',', 'Punctuation'), ('6', 'Number'), ('개', 'Noun'), ('"', 'Punctuation'), ('\n', 'Foreign')], [('"', 'Punctuation'), ('후', 'Noun'), ('앙', 'Adverb'), ('동물', 'Noun'), ('케익', 'Noun'), ('만들기', 'Noun'), ('2', 'Number'), ('호', 'Noun'), ('토끼', 'Noun'), ('와', 'Josa'), ('곰', 'Noun'), (',', 'Punctuation'), ('537', 'Number'), ('g', 'Alpha'), (',', 'Punctuation'), ('1', 'Number'), ('개', 'Noun'), ('"', 'Punctuation'), ('\n', 'Foreign')], [('"', 'Punctuation'), ('신라', 'Noun'), ('명과', 'Noun'), ('달', 'Noun'), ('보드', 'Noun'), ('레', 'Noun'), ('카스테라', 'Noun'), (',', 'Punctuation'), ('36', 'Number'), ('g', 'Alpha'), (',', 'Punctuation'), ('16', 'Number'), ('개', 'Noun'), ('"', 'Punctuation'), ('\n', 'Foreign')], [('"', 'Punctuation'), ('그린', 'Noun'), ('래빗', 'Noun'), ('대만', 'Noun'), ('식', 'Suffix'), ('앙크', 'Noun'), ('림', 'Noun'), ('샌드', 'Noun'), (',', 'Punctuation'), ('80', 'Number'), ('g', 'Alpha'), (',', 'Punctuation'), ('8', 'Number'), ('개', 'Noun'), ('"', 'Punctuation'), ('\n', 'Foreign')], [('"', 'Punctuation'), ('그린', 'Noun'), ('래빗', 'Noun'), ('대만', 'Noun'), ('식', 'Suffix'), ('삼색', 'Noun'), ('샌드', 'Noun'), (',', 'Punctuation'), ('80', 'Number'), ('g', 'Alpha'), (',', 'Punctuation'), ('8', 'Number'), ('개', 'Noun'), ('"', 'Punctuation'), ('\n', 'Foreign')], [('"', 'Punctuation'), ('후', 'Noun'), ('앙', 'Adverb'), ('케익', 'Noun'), ('만들기', 'Noun'), ('세트', 'Noun'), (',', 'Punctuation'), ('441', 'Number'), ('g', 'Alpha'), (',', 'Punctuation'), ('1', 'Number'), ('세트', 'Noun'), ('"', 'Punctuation'), ('\n', 'Foreign')], [('"', 'Punctuation'), ('오설록', 'Noun'), ('그린티', 'Noun'), ('롤', 'Noun'), ('케익', 'Noun'), ('(', 'Punctuation'), ('냉동', 'Noun'), ('),', 'Punctuation'), ('400', 'Number'), ('g', 'Alpha'), (',', 'Punctuation'), ('1', 'Number'), ('개', 'Noun'), ('"', 'Punctuation'), ('\n', 'Foreign')], [('"', 'Punctuation'), ('플레인', 'Noun'), ('치아바타', 'Noun'), ('(', 'Punctuation'), ('냉동', 'Noun'), ('),', 'Punctuation'), ('108', 'Number'), ('g', 'Alpha'), (',', 'Punctuation'), ('10', 'Number'), ('개', 'Noun'), ('"', 'Punctuation'), ('\n', 'Foreign')], [('"', 'Punctuation'), ('조인', 'Noun'), ('누', 'Noun'), ('테이블', 'Noun'), ('블루베리', 'Noun'), ('치즈', 'Noun'), ('타르트', 'Noun'), ('6', 'Number'), ('개입', 'Noun'), ('(', 'Punctuation'), ('냉동', 'Noun'), ('),', 'Punctuation'), ('330', 'Number'), ('g', 'Alpha'), (',', 'Punctuation'), ('1', 'Number'), ('개', 'Noun'), ('"', 'Punctuation'), ('\n', 'Foreign')], [('"', 'Punctuation'), ('곰곰', 'Adverb'), ('달달', 'Noun'), ('카스테라', 'Noun'), (',', 'Punctuation'), ('36', 'Number'), ('g', 'Alpha'), (',', 'Punctuation'), ('16', 'Number'), ('입', 'Noun'), ('"', 'Punctuation'), ('\n', 'Foreign')], [('"', 'Punctuation'), ('신성', 'Noun'), ('제과', 'Noun'), ('에그타르트', 'Noun'), ('28', 'Number'), ('개입', 'Noun'), ('(', 'Punctuation'), ('냉동', 'Noun'), ('),', 'Punctuation'), ('610', 'Number'), ('g', 'Alpha'), (',', 'Punctuation'), ('1', 'Number'), ('개', 'Noun'), ('"', 'Punctuation'), ('\n', 'Foreign')], [('"', 'Punctuation'), ('춘천', 'Noun'), ('감자', 'Noun'), ('빵', 'Noun'), ('오', 'Modifier'), ('리지', 'Noun'), ('널', 'Noun'), ('10', 'Number'), ('개입', 'Noun'), ('(', 'Punctuation'), ('냉동', 'Noun'), ('),', 'Punctuation'), ('1200', 'Number'), ('g', 'Alpha'), (',', 'Punctuation'), ('1', 'Number'), ('개', 'Noun'), ('"', 'Punctuation'), ('\n', 'Foreign')], [('"', 'Punctuation'), ('미니', 'Noun'), ('크로와상', 'Noun'), ('(', 'Punctuation'), ('냉동', 'Noun'), ('),', 'Punctuation'), ('600', 'Number'), ('g', 'Alpha'), (',', 'Punctuation'), ('1', 'Number'), ('개', 'Noun'), ('"', 'Punctuation'), ('\n', 'Foreign')], [('"', 'Punctuation'), ('그린', 'Noun'), ('래빗', 'Noun'), ('샌드위치', 'Noun'), ('카야', 'Noun'), ('샌드', 'Noun'), (',', 'Punctuation'), ('70', 'Number'), ('g', 'Alpha'), (',', 'Punctuation'), ('8', 'Number'), ('개', 'Noun'), ('"', 'P ...

# %%
noun_adj_adv_list=[] 
for sentence in morphs : 
    for word, tag in sentence : 
        if tag in ['Noun'] and ("입" not in word)and("세트" not in word)and("팩" not in word)and("산" not in word)and("것" not in word)and("냉동" not in word)and("개" not in word)and("냉장" not in word)and("용" not in word)and ("내" not in word)and ("나" not in word)and ("수"not in word) and("게"not in word)and("말"not in word): 
            noun_adj_adv_list.append(word) 

print(noun_adj_adv_list)
# Out:
# ['크리스피크림', '도넛', '리지', '널', '글레이', '드', '후', '동물', '케익', '만들기', '호', '토끼', '곰', '신라', '명과', '달', '보드', '레', '카스테라', '그린', '래빗', '대만', '앙크', '림', '샌드', '그린', '래빗', '대만', '삼색', '샌드', '후', '케익', '만들기', '오설록', '그린티', '롤', '케익', '플레인', '치아바타', '조인', '누', '테이블', '블루베리', '치즈', '타르트', '달달', '카스테라', '신성', '제과', '에그타르트', '춘천', '감자', '빵', '리지', '널', '미니', '크로와상', '그린', '래빗', '샌드위치', '카야', '샌드', '후', '생크림', '롤', '케익', '삼립', '뉴욕', '치즈', '케익', '신성', '제과', '호두', '파이', '후', '쿠키', '종', '후', '솔티', '카라멜', '케익', '르', '타오', '더블', '프로', '마쥬', '치즈', '케이크', '조인', '누', '테이블', '바스크', '치즈케이크', '밀크', '앤', '허니', '결', '데니', '쉬', '식빵', '봉', '플레이', '버랩', '다쿠아즈', '종', '치트', '발효', '미니', '버터', '크로와상', '후', '까망베르', '케익', '아티', '제', '바스크', '치즈케이크', '미니', '로', '상', '봉', '후', '동물', '케익', '만들기', '호', '사자', '기린', '플레잇', '베이커리', '크림', '치즈', '프레즐', '끼리', '스틱', '치즈', '케익', '플레인', '파', '유', '대만', '샌드위치', '햄', '치즈', '크리스피크림', '도넛', '어소', '티드', '가가', '농장', '아카시아', '꿀', '튜브', '밀크', '앤', '허니', '연유', '생크림', '카스텔라', '키친', '풀드', '포크', '치아바타', '샌드위치', '밀크', '앤', '허니', '호두', '파이', '키친', '햄', '앤', '루꼴', '크로와상', '샌드위치', '신성', '제과', '호두', '파이', '치', '바오', '대만', '햄', '치즈', '샌드', '후', '초코', '생크림', '롤', '케익', '삼립', '계란', '옷', '몬테', '크리스', '토', '토스트', '청아', '팬케익', '필라델피아', '치즈', '케익', '플레인', '후', '마스', '카포네', '생크림', '롤', '케익', '안단', '잼', '코코넛', '잼', '치트', '스퀘어', '파이', '소', '생', '미니', '로', '상', '봉', '아침', '콘', '참치', '샌드위치', '풍년제', '우리', '밀', '초코파이', '리지', '널', '화이트', '미니', '버터', '크루아상', '냉', '동생', '담꽃', '팥잼', '키친', '치아바타', '샌드위치', '루앙', '초코', '샌드위치', '오', '달카롱', '종', '쿠팡', '포르투갈', '에그타르트', '그린', '래빗', '크랜베리', '치킨', '샌드위치', '플레이', '버랩', '리얼', '레몬', '다쿠아즈', '대만', '샌드위치', '햄', '치즈', '맘쿠킹', '브리', '미니', '로', '상', '생', '아침', '듬뿍', '샌드위치', '풍년제', '우리', '밀', '초코파이', '리지', '널', '화이트', '아침', '듬뿍', '샌드위치', '플레이', '버랩', '현미', '일', '쿠키', '그린', '래빗', '튜', '샐러드', '샌드위치', '프렌치', '버터', '롤', '슈거', '볼', '마들렌', '아이스', '찰보리', '마들렌', '그린', '래빗', '햄', '치즈', '페스트리', '샌드위치', '더', '쌀', '베이글', '블루베리', '쌀', '베이글', '신라', '명과', '빵', '펄', '슈가', '화가', '우유', '우유', '크림', '롤케이크', '쿠팡', '스톤', '오븐', '생', '크림', '치즈', '프레즐', '아티', '제', '녹차', '카스텔라', '후', '블루베리', '생크림', '카스테라', '기안', '슈가', '와플', '슈거', '볼', '마들렌', '루앙', '햄', '치즈', '샌드위치', '오설록', '티', '마들렌', '종', '피낭', '시', '종', '스윗', '밸런스', '훈제', '연어', '파인애플', '샐러드', '랩', '크로와상', '얌', '트러플', '불고기', '치아바타', '파리크라상', '바삭', '우리', '찹쌀', '쇼핑', '진화', '과자', '우리', '밀', '만쥬', '구', '화과자', '구', '선물', '달콤', '바삭', '쁘띠', '르', '타오', '초코', '프로', '마쥬', '치즈', '케이크', '얌', '멕시칸', '치킨', '치아바타', '이엘', '후', '레쉬', '치킨', '브레스트', '샌드위치', '킹즈', '치아바타', '샌드위치', '신성', '제과', '마카롱', '타르트', '후', '레드', '벨벳', '크림', '치즈', '케익', '진화', '과자', '우리', '밀', '만쥬', '구', '화과자', '구', '선물', '쿠팡', '사워도', '롤', '생', '슐스타드', '크루아상', '미니', '초코', '크림', '빵', '삼립', '모닝', '잉글리쉬', '머핀', '떡', '과정', '화과자', '구', '만쥬', '구', '선물', '오설록', '그린', '다쿠아즈', '호', '초콜릿', '다쿠아즈', '아티', '제', '발', '초코', '롤', '키친', '핫', '치킨', '치아바타', '샌드위치', '청정', '미니미', '파', '스키', '브리', '오슈', '트레쎄', '식빵', '그린', '래빗', '실속', '핫도그', '그린', '래빗', '바질', '치킨', '머쉬룸', '파니니', '그린', '래빗', '피넛', '치킨', '패스트리', '샌드위치', '청정', '달콤포', '신세계', '푸드', '스노우', '크림', '케이크', '콩', '쉐프', '미니', '크림', '치즈', '파이', '냉', '동생', '버터', '크루아상', '생', '파리크라상', '골드', '치즈케이크', '그린', '래빗', '고르곤졸라', '불고기', '파니니', '샌드위치', '화가', '우유', '초코', '크림', '롤케이크', '콩', '쉐프', '미니', '버터', '크로와상', '아티', '제', '뉴욕', '치즈', '케이크', '플레이', '버랩', '스트로베리', '다쿠아즈', '삼립', '호빵', '발효', '종', '팥', '야채', '그린', '래빗', '쉬', '림프', '미트', '랩', '그린', '래빗', '포크', '첼', '랩', '그린', '래빗', '단', '계', '감', '모닝', '샌드위치', '아티', '제', '양과자', '레몬', '마들렌', '크랜베리', '휘', '낭시', '월넛', '휘', '낭시', '치트', '플레이', '쿠키', '쿠팡', '라비', '미니', '버터', '로', '상', '생', '파', '스키', '마카롱', '그린', '래빗', '햄', '모짜렐라', '치즈', '파니니', '샌드위치', '생크림', '롤', '케익', '쿠팡', '벨기에', '와플', '상하', '치즈', '바스크', '치즈케이크', '아티', '제', '브레드', '미니', '버터', '크루아상', '냉', '동생', '신성', '제과', '앙금', '파이', '만쥬', '치트', '서울', '식품', '생', '스퀘어', '파이', '봉', '베이커리', '구로', '칸토', '슈', '그린', '래빗', '오리', '햄', '크로와상', '샌드위치', '파', '스키', '라즈베리', '타르트', '니아', '무', '농약', '우리', '밀', '와플', '진화', '과자', '우리', '밀', '만쥬', '구', '화과자', ' ...

# %%
count = Counter(noun_adj_adv_list)

# %%
words = dict(count.most_common())

# %%
from wordcloud import WordCloud 
import matplotlib.pyplot as plt 
import nltk 
from nltk.corpus import stopwords

# %%
# %matplotlib inline 

import matplotlib 
from matplotlib import rc
rc('font', family='NanumBarunGothic')

# %%
from wordcloud import WordCloud

wordcloud = WordCloud(
    font_path = 'C:/Users/win10/workspace/font/NanumBarunGothic.ttf',    # 맥에선 한글폰트 설정 잘해야함.
    background_color='white',                             # 배경 색깔 정하기
    colormap = 'Accent_r',                                # 폰트 색깔 정하기
    width = 800,
    height = 800
)

wordcloud_words = wordcloud.generate_from_frequencies(words)

# %%
array = wordcloud.to_array()
print(type(array)) # numpy.ndarray
print(array.shape) # (800, 800, 3)

fig = plt.figure(figsize=(10, 10))
plt.imshow(array, interpolation="bilinear")
plt.axis('off')
plt.show()
fig.savefig('business_anlytics_worldcloud.png')
# Out:
# <class 'numpy.ndarray'>
# (800, 800, 3)
