# %%
import requests
import bs4
import time
import random

# %%
my_headers={"referer": "https://www.coupang.com/np/categories/195576",
     "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/97.0.4692.71 Safari/537.36"
}

# %%
total_data_list=[]
for page_number in range (1,18):
    url="https://www.coupang.com/np/categories/195578?page={}".format(page_number)
    res = requests.get(url=url, headers=my_headers)
    
    soup=bs4.BeautifulSoup(res.text)
    
    div_elements =soup.select("dd.descriptions > div.name")
    for e in div_elements:
        div_elements = e
        data_list=[]
        data_list.append(div_elements.text.strip())
        total_data_list.append(data_list)
    time.sleep(1)

# %%
total_data_list
# Out:
# [['지리산처럼 행복한 정은씨의 고소한 들깨가루, 150g, 1개'],
#  ['배대감 들깨가루, 200g, 1개'],
#  ['태광선식 국산서리태로 더욱 고소해진 귀리쉐이크, 1개, 1.2kg'],
#  ['곰곰 국내산 고춧가루, 250g, 1개'],
#  ['곰곰 국내산 고춧가루, 1kg, 1개'],
#  ['[쿠팡 직수입] 밥스레드밀 베이킹 파우더, 397g, 1개'],
#  ['햇님마을 국물땡기는 국산 고운 고춧가루 보통매운맛, 120g, 1개'],
#  ['태광선식 옛날 11곡 미숫가루, 2kg, 1개'],
#  ['[쿠팡 직수입] 밥스레드밀 유기농 통밀가루, 2.27kg, 1개'],
#  ['곰곰 간편한 미숫가루 스틱, 24g, 50개'],
#  ['배대감 찹쌀가루, 1kg, 1개'],
#  ['곰표 밀가루, 1kg, 10개'],
#  ['백설 5가지 자연에서 얻은 재료 부침가루, 1kg, 1개'],
#  ['백설 박력 밀가루, 2.5kg, 1개'],
#  ['오뚜기 찹쌀호떡믹스, 540g, 1개'],
#  ['국내산 햇쌀마루 박력 쌀가루 베이킹 3kg 1개 KOR2CCEA3'],
#  ['배대감 들깨가루, 200g, 1개'],
#  ['CJ백설 핫케익믹스, 1kg, 1개'],
#  ['곰표 중력 밀가루, 2.5kg, 6개'],
#  ['배대감 볶음콩가루, 500g, 1개'],
#  ['자연채움 하루애 1생식 스페셜 28p, 1개'],
#  ['해오름 고운 고춧가루 매운맛, 1kg, 1개'],
#  ['오뚜기 부침가루, 2kg, 1개'],
#  ['백설 우리쌀로 만든 바삭 튀김가루, 1kg, 1개'],
#  ['곰표 밀가루 중력다목적용, 3kg, 1개'],
#  ['오뚜기 부침가루, 1kg, 1개'],
#  ['오큐비 감자전분, 1kg, 1개'],
#  ['농부의뜰 감자전분, 1kg, 1개'],
#  ['배대감 12곡 미숫가루, 1개, 1kg'],
#  ['다농원 청정제주 유기 가루 녹차, 200g, 1개'],
#  ['햇님마을 양념이 잘 어우러지는 국산 고춧가루 보통매운맛, 110g, 1개'],
#  ['백설 중력밀가루, 2.5kg, 1개'],
#  ['오뚜기 핫케이크믹스, 1kg, 1개'],
#  ['햇님마을 국물땡기는 국산 고운 고춧가루 매우매운맛, 120g, 1개'],
#  ['웰넛 자연두레 아몬드분말, 1kg, 1개입'],
#  ['국산서리태로 더욱 고소해진 귀리쉐이크, 2개, 1.2kg'],
#  ['백설 바삭한빵가루, 450g, 1개'],
#  ['르사프 드라이 이스트, 500g, 1개'],
#  ['백설 찰밀가루, 2.5kg, 1개'],
#  ['백설 강력 밀가루, 2.5kg, 1개'],
#  ['쿠킹스토리 아몬드가루, 500g, 1개'],
#  ['생율무가루, 500g, 1개'],
#  ['국산 들깨의 껍질만 벗겨 볶지 않은 날들깨가루, 200g, 1개'],
#  ['곰표 강력 밀가루, 2.5kg, 1개'],
#  ['오뚜기 바삭하고 고소한 튀김가루, 1kg, 1개'],
#  ['보의당 박경호 통곡물 한끼 선식가루, 30g, 40개'],
#  ['엄마사랑 아침이 든든한 통곡물 선식, 1.3kg, 1개'],
#  ['배대감 이스트, 90g, 4개'],
#  ['배대감 국산 고소한 미숫가루, 1kg, 1개'],
#  ['백설 찹쌀 호떡믹스, 400g, 10개'],
#  ['백설 중력밀가루, 3kg, 1개'],
#  ['쿠킹스토리 슈크림 붕어빵 만들기 붕어빵 믹스 1kg + 슈크림 믹스 300g 세트, 1세트'],
#  ['청은 감자전분 국산, 1kg, 1개'],
#  ['곰곰 국내산 고춧가루, 600g, 1개'],
#  ['그대로 탈피 들깨가루, 1kg, 1개'],
#  ['백설 식빵 믹스, 760g, 10개'],
#  ['오뚜기 베이킹소다, 400g, 1개'],
#  ['갑당약초 생율무 분말, 300g, 1개'],
#  ['엄마사랑 아침이 든든한 검정콩 선식, 1.2kg, 1개'],
#  ['웰넛 자연두레 아몬드분말, 1kg, 1개'],
#  ['스웰 마카롱 아몬드분말 랜덤발송, 1kg, 1개'],
#  ['[오뚜기] 빵가루, 1kg, 1개'],
#  ['태광선식 국산서리태로 더욱 고소해진 귀리쉐이크, 1.2kg, 1개'],
#  ['오뚜기 튀김가루, 2kg, 1개'],
#  ['칠갑농산 십곡 미싯가루, 1kg, 1개'],
#  ['[청정원] 우리밀 튀김가루, 450g, 1개입'],
#  ['브레드가든 무알루미늄 착한 베이킹 파우더, 1개, 1kg'],
#  ['착한습관 볶은아마씨가루, 200g, 5팩'],
#  ['복이네먹거리 고춧가루 보통맛 찜/무침용 상, 1kg, 1개'],
#  ['넛츠베리 참식품 보리떡용가루, 3kg, 1개'],
#  ['백설 인절미 호떡 믹스, 300g, 1개'],
#  ['오뚜기 쌀핫케이크 믹스, 400g, 1개'],
#  ['농부의뜰 감자전분, 500g, 1개'],
#  ['농부의뜰 부침가루, 1kg, 1개'],
#  ['빅마마 이혜정의 시크릿코인205개(총1세트), 205'],
#  ['[쿠팡 직수입] 밥스레드밀 유기농 통밀가루, 1.36kg, 1개'],
#  ['청은 옥수수맛전분, 1kg, 2개'],
#  ['아몬드 분말, 1kg, 1개'],
#  ['밀가루 대신 글루텐 프리 타피오카 전분, 1개, 1.2kg'],
#  ['오일러스 고소해서 들깨가루, 200g, 1개'],
#  ['내가본 국내산 양념용 매운청양 고운 고춧가루, 150g, 1개'],
#  ['컬러푸드 국산 검은콩가루, 500g, 1개'],
#  ['곰표 밀가루, 2kg, 1개'],
#  ['[쿠팡 직수입] 밥스레드밀 액티브 드라이 이스트, 227g, 1개'],
#  ['배대감 국산 통 들깨가루, 200g, 1개'],
#  ['청오 유기농 쌀가루, 350g, 1개'],
#  ['구월의아침 국산100%쪄서볶은 서리태콩물가루 검은콩가루 500g, 1팩'],
#  ['배대감 생 찹쌀가루, 500g, 1개'],
#  ['화개농협 가루녹차, 500g, 1개'],
#  ['온샘 안동 참마분말, 300g, 1개'],
#  ['백설 초코케익 믹스, 350g, 1개'],
#  ['오일러스 고소해서 들깨가루, 200g, 1개'],
#  ['쿠킹스토리 한천가루, 200g, 1개'],
#  ['오큐비 알파옥수수 가루, 1kg, 1개'],
#  ['대한다업 보성산 유기농 가루녹차, 50g, 1개'],
#  ['백설 찰밀가루, 3kg, 1개'],
#  ['곰표 우리밀 밀가루, 900g, 1개'],
#  ['컬러푸드 국산 들깨가루, 200g, 1개'],
#  ['담터 마가 들어간 15곡 미숫가루, 20g, 80개'],
#  ['Hungry Jack 컴플리트 버터밀크 팬케이크 앤 와플 믹스, 2개, 907g'],
#  ['오토 감자전분, 20kg, 1개'],
#  ['니신 핫케익믹스 고쿠모찌, 540g, 1개'],
#  ['곰표 아메리칸 와플 파이용 믹스, 1kg, 2개'],
#  ['뉴케어 데이밀 슈퍼블랙 선식가루, 35g, 28개'],
#  ['[청정원]우리밀 부침가루, 450g, 1개'],
#  ['백설 붕어빵믹스, 10kg, 1개'],
#  ['SIB 베이킹 파우더, 150g, 1개'],
#  ['복이네먹거리 국산 들깨가루, 300g, 1개'],
#  ['오설록 프리미엄 가루 녹차, 40g, 1개'],
#  ['21년 수확한 국산 햇 고춧가루 1kg 5가지 맵기와 굵기, (02)일반맵기아주곱게500g * 1팩'],
#  ['백설 아메리칸 와플믹스, 10kg, 1개'],
#  ['랩노쉬 마시는 식사 마일드 카카오, 350ml, 6개'],
#  ['백설 박력 밀가루, 1kg, 10개'],
#  ['복이네먹거리 청양고추가루 김치/찜용 매운맛, 1kg, 1개'],
#  ['쿠킹스토리 브뤼셀 와플믹스, 1kg, 1개'],
#  ['쿠킹스토리 아몬드가루, 200g, 2개'],
#  ['우리 유기농 우리밀 통밀가루, 600g, 2개'],
#  ['백설 영양균형 핫케익 믹스, 800g, 1개'],
#  ['초야식품 식혜만들기, 35g, 12개'],
#  ['오뚜기 치킨 튀김가루, 1kg, 1개'],
#  ['니신 핫케익믹스 고쿠모찌, 540g, 1개'],
#  ['새한 콩고물, 1kg, 1개'],
#  ['태광선식 검은콩이 들어간 블랙푸드 미숫가루, 1.5kg, 1개'],
#  ['커피빈 헤이즐넛 파우더 750g, 1개'],
#  ['백설 중력1등 밀가루, 10kg, 1개'],
#  ['복이네먹거리 베트남고추가루 소스용분말, 1kg, 1개'],
#  ['우리밀로 옛날 통밀가루, 1kg, 2개'],
#  ['배대감 날콩가루 500g, 1개'],
#  ['오큐비 부침가루, 2kg, 1개'],
#  ['태광선식 옛날 11곡 미숫가루, 2kg, 1개'],
#  ['영양고춧가루, 보통매운 1kg'],
#  ['청은 옥수수맛 전분, 3kg, 1개'],
#  ['청은 베이킹파우더, 150g, 10개입'],
#  ['우리밀로 옛날 통밀가루, 1kg, 1개'],
#  ['CJ 백설 부침가루, 1kg, 4개'],
#  ['브레드가든 무알루미늄 착한 베이킹파우더, 155g, 1개'],
#  ['식용 베이킹소다 2kg + 계량 스푼, 1세트'],
#  ['증안리약초마을 서리태분말, 500g, 1개'],
#  ['해오름 굵은 고춧가루 매운맛, 1kg, 1개'],
#  ['올가니카 식물성 채식쉐이크 스마트밀 OMG 내추럴, 770g, 1개'],
#  ['복이네먹거리 베트남 고춧가루 소스분말용, 180g, 1개'],
#  ['국산 들깨의 껍질만 벗겨 볶지 않은 날들깨가루, 200g, 1개'],
#  ['오뚜기 초간편 김치전 믹스, 320g, 1개'],
#  ['뚜레반 옥수수 전분, 3kg, 1개'],
#  ['뚜레반 찹쌀가루 국산 A+, 1kg, 1개'],
#  ['곰표 튀김가루, 2kg, 1개'],
#  ['우리가스토리 오 마이 오트 볶은귀리분말, 900g, 1개'],
#  ['농부의뜰 튀김가루, 1kg, 1개'],
#  ['모리나가 핫케익믹스 300g, 1개'],
#  ['올가 유기농 생쌀가루, 350g, 1개'],
#  ['[쿠팡 직수입] 밥스레드밀 베이킹 파우더, 397g, 1개'],
#  ['대한제분 강력밀가루 제빵전용분, 20kg, 1개'],
#  ['다농원 청정제주담은 유기농 가루녹차, 40g, 1개'],
#  ['오뚜기 도나스믹스, 1kg, 1개'],
#  ['뿌띠 국산 누룩팩 잡티 기미관리, 1개, 국산 누룩'],
#  ['동원 고운 빵가루, 1개, 1kg'],
#  ['쿠킹스토리 호밀가루, 1kg, 1개'],
#  ['오큐비 아몬드분말, 800g, 1개'],
#  ['곰표 부침가루, 1kg, 5개'],
#  ['곰표 부침가루, 2kg, 1개'],
#  ['브레드가든 초코칩쿠키믹스, 320g, 1개'],
#  ['내가본 태양초 고운 고춧가루 양념용, 150g, 1개'],
#  ['웰넛 자연두레 아몬드 분말, 200g, 1개'],
#  ['브레드가든 진저브레드 쿠키 믹스, 270g, 1개'],
#  ['방앗간청년 국산 햇 흑임자 검은깨 가루(주문 볶아 고소함이 다른), 1개, 500g'],
#  ['뚜레반 옥수수 전분, 1kg, 1개'],
#  ['배대감 국산 고소한 미숫가루, 1kg, 1개'],
#  ['백설 브라우니 믹스, 320g, 10개'],
#  ['성진식품 메주가루, 500g, 1개'],
#  ['담터 미숫가루 라떼, 40개입, 20g'],
#  ['브레드가든 붕어빵 만들기세트, 1세트'],
#  ['큐원 와플믹스, 500g, 10개'],
#  ['성진식품 감자전분맛 용기형, 450g, 1개'],
#  ['곰표 밀가루 박력, 2.5kg, 1개'],
#  ['태광선식 아침이 든든한 검정콩선식가루, 1.2kg, 1개'],
#  ['백세식품 매스틱정 프리미엄, 36g, 1개'],
#  ['뚜레반 17곡 미숫가루 A+, 1kg, 3개입'],
#  ['화왕산산성누룩 밀분말누룩(얼굴팩용 기미 주근깨 미백 보습)1kg, 1kg, 1개'],
#  ['봉평촌 메밀가루, 800g, 1개'],
#  ['청은 옥수수맛전분, 1kg, 1개'],
#  ['봉평촌 메밀가루, 800g, 1개'],
#  ['청은 옥수수맛전분, 1kg, 1개'],
#  ['오큐비 유기농 국산 쌀가루, 500g, 1개'],
#  ['대한제분 암소 박력 밀가루, 10kg, 1개'],
#  ['청은에프엔비 국산 찹쌀가루, 300g, 1개'],
#  ['안동옛맛된장 막장용메주가루, 1kg, 1개'],
#  ['브레드가든 베이킹소다, 170g, 1개'],
#  ['대한제분 코끼리 빵용 강력 밀가루, 20kg, 1개'],
#  ['국내산 예천방앗간 고춧가루 1kg 1개'],
#  ['정식품 [TV]담백한 베지밀 에이 검은콩두유 6박스/총 96팩, (녹율)담백한 베지밀에이 검은콩두유'],
#  ['예천 방앗간 고추가루 보통맛 500g 1개'],
#  ['배대감 생 찹쌀가루, 500g, 1개'],
#  ['안동옛맛된장 고추장용 메주가루, 500g, 1개'],
#  ['칠갑농산 감자 전분, 500g, 1개'],
#  ['컬러푸드 검은콩 검은깨 선식, 500g, 1개'],
#  ['해가원 깨끗한 고춧가루, 100g, 1개'],
#  ['태광선식 퀴노아 10곡 미숫가루 스틱, 20g, 100개'],
#  ['대한제분 코끼리 강력 밀가루, 10kg, 1개'],
#  ['컬러푸드 국산 들깨가루, 200g, 1개'],
#  ['오뚜기 녹두 빈대떡 가루, 500g, 1개'],
#  ['뚜레반 찹쌀가루 국산 A+, 3kg, 1개'],
#  ['곰표 부침가루, 1kg, 10개'],
#  ['장명식품 국내산 검은 콩가루, 300g, 1개'],
#  ['복이네먹거리 고춧가루 보통맛 김치용 상, 1kg, 1개'],
#  ['칠갑농산 고춧가루, 500g, 1개'],
#  ['곰표 핫케잌가루, 1kg, 1개'],
#  ['볶은율무가루, 500g, 2개'],
#  ['백설 치킨튀김가루, 1kg, 1개'],
#  ['대한제분 곰표 중력 밀가루, 10kg, 1개'],
#  ['헝그리잭 컴플리트 버터밀크 팬케이크 & 와플 믹스, 1개, 2.26kg'],
#  ['백설 찹쌀 호떡믹스, 400g, 2개'],
#  ['쿡앤베이크 고운 아몬드분말, 600g, 1개'],
#  ['우리 유기농 우리밀 통밀가루, 600g, 1개'],
#  ['구월의아침 쪄서볶은 귀리분말쉐이크 1kg, 500g, 2팩'],
#  ['키토라푸드 글루텐프리 베이킹파우더, 500g, 1개'],
#  ['백설 강력 밀가루, 1kg, 10개'],
#  ['플라티나 박력분, 1kg, 1개'],
#  ['화미 빵가루, 8kg, 1개'],
#  ['큰산큰강 도토리묵 가루 1kg/국내가공확인하십시오/2021년 자연산 100퍼센트 햇도토리를 갈았어요/품질위주상품'],
#  ['컬러푸드 국산 볶음 검은깨가루, 250g, 1개'],
#  ['햇님마을 국산 청양 고춧가루, 130g, 1개'],
#  ['21년 수확한 국산 햇 고춧가루 1kg 5가지 맵기와 굵기, (03)매운청양중간굵기500g * 1팩'],
#  ['햇쌀마루 골드 강력 쌀가루 국산, 3kg, 1개'],
#  ['곰곰 간편한 블랙푸드 선식, 30g, 30개입'],
#  ['동서 현미 지리산 가루 녹차 40g, 1개'],
#  ['복이네먹거리 안매운 고춧가루 순한맛 김치용, 150g, 1개'],
#  ['칠갑농산 고춧가루, 500g, 1개'],
#  ['식자재왕 엿기름가루, 1kg, 1개'],
#  ['키알라 유기농 와플 믹스, 345g, 1개'],
#  ['뚜레반 국내산 쌀가루, 1kg, 1개'],
#  ['청수생약 계피 가루 분말 1kg(500gx2), 2개, 500g'],
#  ['농협 쌀부침가루, 500g, 7개'],
#  ['복이네먹거리 청양고추가루 김치/찜용 매운맛, 1kg, 1개'],
#  ['올가 우리쌀로 만든 유기농 찹쌀가루 고운입자, 180g, 1개'],
#  ['[오가닉스토리] 오가닉스토리 유기농 찹쌀가루, 500g'],
#  ['너츠브라더 아몬드 분말, 500g, 2개'],
#  ['처음햇살 고춧가루 보통매운맛 김치 깍두기용, 1kg, 1개'],
#  ['콘스타치 옥수수 전분, 2kg, 1개'],
#  ['오뚜기 달걀 하나 톡 넣는 쌀컵케이크 초코, 60g, 16개'],
#  ['이홈베이킹 우지마차가루, 100g, 1개'],
#  ['너츠브라더 아몬드 분말, 500g, 2개'],
#  ['처음햇살 고춧가루 보통매운맛 김치 깍두기용, 1kg, 1개'],
#  ['콘스타치 옥수수 전분, 2kg, 1개'],
#  ['오뚜기 달걀 하나 톡 넣는 쌀컵케이크 초코, 60g, 16개'],
#  ['이홈베이킹 우지마차가루, 100g, 1개'],
#  ['볶은율무가루, 500g, 1개'],
#  ['쿡앤베이크 머핀 믹스 프리, 1kg, 1개'],
#  ['국산 검은콩 미숫가루 선식 500g 100% 곡물 현미 흑미 아침식사대용, 1개'],
#  ['성진 이스트 용기형, 70g, 3개'],
#  ['21년 수확한 국산 햇 고춧가루 1kg 5가지 맵기와 굵기, (05)안매운어린이용 500g * 1팩'],
#  ['사프 인스턴트 이스트 레드, 125g, 1개'],
#  ['갑당약초 팥볶음가루, 300g, 1개'],
#  ['이홈베이킹 아메리칸 스콘믹스, 1kg, 1개'],
#  ['온뜨락 유기농 생콩가루, 180g, 1개'],
#  ['연세대학교 연세백세생식, 30g, 25개'],
#  ['청은 식소다, 1kg, 1개'],
#  ['갑당약초 귀리 오트밀 분말, 1100g, 1개'],
#  ['CJ 백설 팬케익 믹스, 400g, 2개'],
#  ['담터 마가 들어간 15곡 미숫가루, 1개, 800g'],
#  ['복이네먹거리 고춧가루 보통맛 김치용 상, 1kg, 1개'],
#  ['올가홀푸드 유기농 생 찹쌀가루, 350g, 1개'],
#  ['백설 중력 밀가루, 1kg, 10개'],
#  ['송학곡자 우리밀 누룩, 1kg, 1개'],
#  ['류씨네 중국산 진고춧가루 김치용, 1kg, 1개'],
#  ['비스퀵 홈메이드 버터밀크, 212g, 3개'],
#  ['복이네먹거리 국산 햇고추가루 김치/김장용 보통맛, 1kg, 1개'],
#  ['곰곰 간편한 미숫가루 스틱, 24g, 50개'],
#  ['올가홀푸드 유기농 부침가루, 350g, 1개'],
#  ['곰표 호떡믹스, 10kg, 1개입'],
#  ['백설 찹쌀호떡믹스, 400g, 5개'],
#  ['화미 고춧가루 미분용, 1kg, 1개'],
#  ['오큐비 튀김가루, 2kg, 1개'],
#  ['곰표 와플파이믹스, 10kg, 1개입'],
#  ['태광선식 국산서리태로 더욱 고소해진 귀리쉐이크 1.5kg'],
#  ['해오름 통곡물 현미 하우스 막걸리 키트 5병분량, 530g, 1세트'],
#  ['곰곰 국내산 간편한 고운 고춧가루 국물용, 150g, 1개'],
#  ['브레드가든 통밀 식빵믹스, 364g, 10개'],
#  ['복이네먹거리 베트남고추가루 김치 찜용, 180g, 1개'],
#  ['곰표 붕붕믹스, 10kg, 1개입'],
#  ['배대감 20곡 미숫가루, 1kg, 1개'],
#  ['소율곡 전통누룩, 1kg, 3개'],
#  ['키토라푸드 글루텐프리 베이킹파우더, 250g, 1개'],
#  ['올가홀푸드 유기 현미가루, 300g, 1개'],
#  ['[국산] 100% 봉평 메밀가루 1kg 순메밀가루, 1개'],
#  ['청은 도토리묵 가루, 400g, 1개'],
#  ['해가원 깨끗한 고춧가루, 200g, 1개'],
#  ['참식품 Offcial 보리떡용 가루, 1kg, 1개'],
#  ['내가본 국내산 양념용 매운청양 고운 고춧가루, 150g, 1개'],
#  ['화미 고춧가루 한식용, 1kg, 1개'],
#  ['백설 찹쌀 호떡믹스, 400g, 10개'],
#  ['티아시아 플레인 난 믹스, 200g, 1개'],
#  ['복이네먹거리 국산 햇고추가루 김치 / 김장용 보통맛, 500g, 1개'],
#  ['딜리셔스마켓 케이엔페퍼 베트남 고춧가루, 60g, 1개'],
#  ['팔도 뿌려먹는 시즈닝 틈새 레드페퍼 40g, 2개'],
#  ['국산 탈피 거피 기피 들깨가루 300g (들깨팩), 1개'],
#  ['컬러푸드 국산 현미가루, 500g, 1개'],
#  ['싸리재 고소한 콩가루, 300g, 1개'],
#  ['뚜레반 엿기름가루 국산100%, 1kg, 1개'],
#  ['청은 식소다, 150g, 20개'],
#  ['성진 인절미 콩가루, 2kg, 1개'],
#  ['엄마사랑 아침이 든든한 검정콩 선식, 1.2kg, 1개'],
#  ['해표 부침가루, 1kg, 10개입'],
#  ['아티장 제빵 오리지널 밀가루, 20kg, 1개'],
#  ['방앗간청년 쪄서 볶은 국산 서리태60% 흑임자 20% 미숫가루 선식, 1개, 500g'],
#  ['구월의아침 국산100% 쪄서볶은 율무가루분말 500g, 1팩'],
#  ['[상주이장님농장] 국산 100% 서리태가루 검은콩 검정콩 곡물 쉐이크 미숫 가루, 500g, 1봉'],
#  ['초록들 볶은 콩가루, 500g, 1개'],
#  ['복이네먹거리 고춧가루 보통맛 소스용 상, 1kg, 1개'],
#  ['키알라 유기농 팬케익믹스 오리지날, 345g, 1개입'],
#  ["Bob's Red Mill 오가닉 코코넛 플라어, 453g, 1개"],
#  ['토종마을 국산 볶은 귀리가루, 800g, 1개'],
#  ['다노 흑임자선식 (10개), 10개'],
#  ['사프 인스턴트 고당 이스트 골드, 500g, 1개'],
#  ['곰곰 국내산 간편한 고춧가루 양념용, 150g, 1개'],
#  ['성진 쌀가루, 1kg, 3개'],
#  ['푸드림 아몬드 분말, 1kg, 1개'],
#  ['풀무원 [풀무원] 고단백 두부바 플레인60gx10개, 상세 설명 참조'],
#  ['청은 생쌀가루 국산, 1kg, 2개'],
#  ['청은 매쉬드 포테이토 플레이크, 600g, 1개'],
#  ['컬러푸드 국산 검은콩가루, 500g, 1개'],
#  ['청은 청포묵가루, 400g, 1개'],
#  ['백설 영양균형 핫케익 믹스, 800g, 2개'],
#  ['밥스레드밀 슈퍼 파인 블렌치드 아몬드 분말, 453g, 1개'],
#  ['오뚜기 부침가루 1kg 3개 + 튀김가루 1kg 2개'],
#  ['참쑥의 어린잎으로 만든 프리미엄 국산 쑥가루 쑥라떼 쑥차 쑥우유 분말 250g 500, 1개, 500g'],
#  ['LALVIN 와인효모, 5g, 5개'],
#  ['모리나가 핫케익 믹스 2p, 300g, 2개'],
#  ['[오뚜기] 빵가루, 200g, 10개'],
#  ['허니버터맛 시즈닝 가루, 500g, 1개'],
#  ['블랙푸드 미숫가루 1kg x5개 곡물명가 선식'],
#  ['키토라푸드 글루텐프리 코코넛가루, 500g, 1개'],
#  ['[푸드득]곰표 튀김가루1kg(10개) 대용량 업소용 사무실 간식 식자재, CDU_단일옵션'],
#  ['브레드가든 밀크 앤 밀크 식빵믹스, 364g, 1개'],
#  ['해표 튀김가루, 1kg, 10개입'],
#  ['예천 방앗간 고춧가루 매운맛 500g, 1개'],
#  ['신선약초 쌀겨 미강가루, 300g, 1개'],
#  ['곰표 밀가루, 1kg, 10개입'],
#  ['푸른빈 녹두 가루, 1개, 1kg'],
#  ['백설 감자수제비가루500gx3개, 1세트'],
#  ['엔지스트 인스턴트 저당 드라이 이스트, 500g, 1개'],
#  ['습식 찹쌀가루 100%, 1kg, 1개'],
#  ['모리나가 홋카이도 핫케익 믹스 2p, 300g, 2개'],
#  ['[다온농산] 국산 찰수수가루 -1Kg- 수수부꾸미/수수팥떡/팥죽새알심'],
#  ['해표 지리산 100% 우리밀 밀가루, 750g, 1개'],
#  ['오가닉스토리 유기농 밀가루, 500g, 1개'],
#  ['대한다업 수채화 같은 보성다원 가루녹차, 500g, 1개'],
#  ['고미네 한천 가루, 200g, 1개'],
#  ['밥스레드밀 베이킹 파우더, 397g, 2개'],
#  ['복이네먹거리 국산 안매운 고추가루 김치용 순한맛, 500g, 1개'],
#  ['컬러푸드 국산 검은콩 가루, 250g, 1개'],
#  ['다농원 검은콩 20곡 미숫가루, 20g, 40개입'],
#  ['백설 옛날호떡믹스, 10kg, 1개'],
#  ['초야 참이맛 볶은콩가루, 1kg, 1개'],
#  ['산아래토종우리밀가루 앉은뱅이 백밀가루 박력분, 1kg, 1개'],
#  ['키알라 유기농 밀가루 강력, 1kg, 1개'],
#  ['쿡앤베이크 슈크림믹스 350g 커스터드크림믹스, 1개'],
#  ['대현상회 50년 전통 국산 집된장, 1kg, 1개'],
#  ['[1박스 추가]박경호 통곡물 한끼선식 5박스+1박스 총6박스, 없음, 상세설명 참조'],
#  ['백설 통밀 영양가득 곱게빻은 밀가루, 750g, 1개'],
#  ['백설 식빵믹스, 760g, 2개'],
#  ['쿡앤베이크 슈크림믹스 350g 커스터드크림믹스, 1개'],
#  ['대현상회 50년 전통 국산 집된장, 1kg, 1개'],
#  ['[1박스 추가]박경호 통곡물 한끼선식 5박스+1박스 총6박스, 없음, 상세설명 참조'],
#  ['백설 통밀 영양가득 곱게빻은 밀가루, 750g, 1개'],
#  ['백설 식빵믹스, 760g, 2개'],
#  ['[녹차원] 국내산가루녹차 50G, 1개'],
#  ['클라버걸 더블 액팅 베이킹 파우더, 230g, 1개'],
#  ['브레드가든 퍼지브라우니믹스, 400g, 1개'],
#  ['담터 검은콩 검은참깨 흑미 미숫가루, 40개, 20g'],
#  ['백설 초코칩 핫케익믹스, 500g, 2개'],
#  ['아임요 빙수용 콩고물, 600g, 1개'],
#  ['쿡앤베이크 보리떡믹스, 1kg, 1개'],
#  ['큐원 우리아이 영양쿠키믹스, 250g, 10개'],
#  ['해표 우리밀 통밀가루, 14개, 750g'],
#  ['처음햇살 고춧가루 국내산 김치 깍두기용 청양매운맛, 1kg, 1개'],
#  ['금송가루촌 청결 고운 고춧가루, 1kg, 1개'],
#  ['쿡앤베이크 멀티쿠키믹스, 1kg, 1개'],
#  ['오타후쿠 오코믹스 소프트 파우더, 1kg, 1개'],
#  ['푸르벨 녹차가루 A-0862-1, 500g, 1개'],
#  ['밸런스밀 귀리, 50g, 1개'],
#  ['곰표 도너츠가루, 1kg, 1개'],
#  ['장명식품 검은콩 검은깨 볶음가루, 300g, 1개'],
#  ['성보식품 국내산 수수 생 분말, 150g, 1개'],
#  ['배대감 도토리묵 가루, 500g, 1개'],
#  ['CJ제일제당 통감자를 갈아 넣은 바삭부침가루, 1kg, 2개'],
#  ['오뚜기 쵸코 핫케이크 믹스, 1kg, 1개'],
#  ['해가원 햇살나래 베이킹파우더 A 플러스, 500g, 1개'],
#  ['백설 식빵 믹스, 760g, 10개'],
#  ['태광선식 검은콩 미숫가루, 700g, 1개'],
#  ['곰표 중력 밀가루, 2.5kg, 6개'],
#  ['국산 도토리가루 100% 1Kg, 1개'],
#  ['CJ제일제당 바삭한 부침가루(백설 2K), 2kg, 1개'],
#  ['뚜레반 12곡 미숫가루, 1kg, 3개입'],
#  ['거친생율무가루, 500g, 1개'],
#  ['야키팩토리 오이시이 타코야키 믹스1kg, 1kg, 1개'],
#  ['온샘 안동 참마분말, 300g, 1개'],
#  ['칠갑농산 고춧가루, 250g, 1개'],
#  ['오큐비 치킨튀김가루, 2kg, 1개'],
#  ['좋은세상 냄새적은 청국장가루 500gx3통, 500g, 3개'],
#  ['나우리얼푸드 잔탄 검 퓨어 파우더, 170g, 1개'],
#  ['오뚜기 달걀하나 톡 넣는 쌀컵케이크 3종 세트 (9개입) (치즈3+초코3+스윗바나나3) + 블루존물티슈, 1세트'],
#  ['칠갑농산 메주가루, 1kg, 1개'],
#  ['랩노쉬 마시는 식사 마일드 카카오, 350ml, 6개'],
#  ['뚜레반 검은콩 미숫가루, 1kg, 1개'],
#  ['복이네먹거리 고춧가루 조금매운맛 김치용 상, 1kg, 1개'],
#  ['백설 초코칩쿠키믹스, 290g, 3개'],
#  ['청은 이스트, 60g, 1개'],
#  ['백설 감자수제비가루, 500g, 2개'],
#  ['국내산 최상급 고춧가루 1kg 1개. 보통맛/최근제조/김치양념용, 1개'],
#  ['백설 바삭한빵가루, 450g, 6개'],
#  ['현미그린 콩이랑 현미통밀빵 DIY 믹스, 350g, 2개'],
#  ['선인 베이킹 파우더EP 150g 2개 세트'],
#  ['다농원 청정제주 유기 가루 녹차, 200g, 1개'],
#  ['더아몬드파머 아몬드 가루, 200g, 1개'],
#  ['곰표 공작밀가루 20kg, 1개'],
#  ['볶은 아마씨 500g ×2봉 아마씨 샴푸용 헤어팩용, 단품'],
#  ['곰표 튀김가루, 1kg, 10개입'],
#  ['웰리유 식사대용 하루생식, 25g, 28개'],
#  ['화미 돈까스 튀김가루 베타믹스, 3kg, 1개'],
#  ['기라델리 프리미엄 브라우니 믹스, Double Chocolate, 1개'],
#  ['Birch Benders 팬케이크 & 와플 믹스 프로틴, 454g, 1개'],
#  ['가득찬 탈피들깨가루, 1kg, 1개'],
#  ['다노 쑥선식 (10개), 10개'],
#  ['감성먹거리 한천 가루, 300g, 1개'],
#  ['칠갑농산 고춧가루, 1kg, 1개'],
#  ['[다온농산] 국산 순메밀가루 100% -1Kg- 국산 메밀쌀 100% 판매자 직접가공 판매 저렴'],
#  ['갑당약초 홍화씨가루, 300g, 1개'],
#  ['성진 이스트, 60g, 5개'],
#  ['올가홀푸드 유기농 볶음 현미가루, 250g, 1개'],
#  ['킹아더 글루텐 프리 팬케이크 믹스, 425g, 1개'],
#  ['담터 슈퍼 곡물 12곡 미숫가루, 20g, 40개'],
#  ['곰표 밀가루, 500g, 20개'],
#  ['볶은 아마씨 500g ×1봉 아마씨 샴푸용 헤어팩용, 단품'],
#  ['푸른빈 찹쌀가루, 1kg, 1개'],
#  ['곰표 고급제면용 밀가루, 20kg, 1개'],
#  ['브레드가든 플레인식빵믹스, 1개'],
#  ['곰표 대한제분 벨기에 와플믹스, 10kg, 1개'],
#  ['햇쌀마루 골드강력 쌀가루, 1개, 1kg'],
#  ['착한습관 볶은아마씨가루, 200g, 1팩'],
#  ['잇츠온 하루 곡물 멀티 그레인, 40g, 20개'],
#  ['방앗간청년 쪄서 볶은 국산 서리태60% 흑임자 20% 미숫가루 선식, 1개, 300g'],
#  ['오설록 말차스틱, 17g, 5개'],
#  ['뉴케어 데이밀 슈퍼그린 선식가루, 35g, 28개'],
#  ['볶은 콩가루, 1kg, 1개'],
#  ['오큐비 유기농 국산 찹쌀가루, 500g, 1개'],
#  ['암앤해머 퓨어 베이킹 소다, 454g, 1개'],
#  ['일년래래 햇살담은 베트남 아주매운맛 김치용 고춧가루, 1kg, 1개'],
#  ['삼립 생빵가루2kg, 2kg, 없음'],
#  ['컬러푸드 검은콩 검은깨 선식, 1개, 다시마+검은콩+검은깨'],
#  ['백설 부침가루, 500g, 20개'],
#  ['잔다리 볶은검은콩가루, 500g, 1개'],
#  ['식용 베이킹소다, 200g, 4개'],
#  ['전통발효연구원 발효효소 순, 3g, 30개입'],
#  ['뉴케어 데이밀 슈퍼블랙 선식가루, 35g, 28개'],
#  ['금꽃 식용금가루100mg 순수국내산, 100mg, 1'],
#  ['올가홀푸드 유기 발아현미 미숫가루, 500g, 1개'],
#  ['방앗간청년 국산 햇 흑임자 검은깨 가루(주문 볶아 고소함이 다른), 1개, 200g'],
#  ['태광선식 퀴노아 10곡 미숫가루, 20g, 50개'],
#  ['성진식품 15곡 미숫가루, 1kg, 1개'],
#  ['오설록 프리미엄 가루녹차, 40g, 1개'],
#  ['산들햇쌀 습식 쌀가루 2.5kg 산들본가 100% 우리쌀로 만든 멥쌀가루 습식쌀가루 쌀가루 습식 멥쌀가루 백설기 송편 떡케익 냉동쌀가루, 1팩'],
#  ['청은 식소다, 1kg, 2개'],
#  ['딜리셔스마켓 케이엔페퍼 베트남 고춧가루, 450g, 1개'],
#  ['화미제당 베이킹 파우더, 150g, 10개'],
#  ['처음햇살 고춧가루 국내산 김치 깍두기용 보통매운맛, 1kg, 1개'],
#  ['햇싹원 개량메주가루, 1kg, 1개'],
#  ['(동아식품) 타피오카 전분가루 1kg (밀가루 찹쌀 대용), 1개, 타피오카 전분 1kg'],
#  ['내가본 고춧가루 양념용, 150g, 1개'],
#  ['갑당약초 검은콩 가루, 300g, 1개'],
#  ['엄마사랑 스틱형 블랙푸드 하루선식 가루, 20g, 40개입'],
#  ['태광선식 아침이 든든한 검정콩선식가루, 1.2kg, 1개'],
#  ['보리채움 무설탕 황금보리떡용가루3kg, 1개, 3kg'],
#  ['산초가루, 40g, 1개'],
#  ['홍국쌀가루, 100g, 1개'],
#  ['코코넛가루, 1kg, 1개'],
#  ['화미_옥수수전분(복합) 3KG 1팩'],
#  ['브레드가든 플레인스콘믹스, 1kg, 1개'],
#  ['국산 검은콩 가루 600g(300g*2)번들 서리태 분말 검정콩, 2개, 300g'],
#  ['비스퀵 믹스 (허니버터/버터밀크), 4, 01.허니버터'],
#  ['세미 녹차라떼파우더 500g 2개'],
#  ['태영농산 국산100% 검정콩가루 서리태가루1kg 검정콩물 대두분말, 1개, 1kg'],
#  ['배대감 이스트, 90g, 4개'],
#  ['셀핀다 가바100% 750mg, 1'],
#  ['쿠킹스토리 붕어빵믹스, 1kg, 1개'],
#  ['방앗간사람들 시골애 들깨가루, 600g'],
#  ['쿠킹스토리 한천가루, 200g, 1개'],
#  ['갑당약초 볶은 흰강낭콩가루, 500g, 2개'],
#  ['소소생활 소소한끼 그릭요거트 뮤즐리, 1개, 65g x 5개입'],
#  ['화왕산산성누룩 밀분말누룩 1kg- 얼굴팩용 선식용, 1kg, 1개'],
#  ['쿠킹스토리 녹차가루, 100g, 2개'],
#  ['국산 생강가루 분말 100% 300g, 1개'],
#  ['브레드가든 복합 옥수수 전분, 1kg, 1개'],
#  ['농심 건강한 쌀 부침가루 450g X 2개'],
#  ['McCormick 맥코믹 브라운 그레이비 믹스 Brown Gravy Mix 21oz(595g), 1. 브라운 그레이비(Brown Gravy)'],
#  ['갑당약초 미강 가루, 300g, 1개'],
#  ['기라델리 프리미엄 브라우니 믹스, Dark Chocolate, 1개'],
#  ['성림 알파콘 옥수수가루, 5kg, 1개'],
#  ['백설 찹쌀 호떡믹스, 400g, 3개'],
#  ['하니엘 국산 습식 제분 쌀가루 1kg 국내산 100% 쌀분말, 1개'],
#  ['2021년 국산 고운(장용) 햇고춧가루 1kg 경북 의성 고추가루, 1개'],
#  ['인차 녹차분말, 200g, 1개'],
#  ['곰표 부침가루, 1kg, 5개'],
#  ['허니버터맛 시즈닝 가루, 500g, 1개'],
#  ['신광식품 식소다1kg 베이킹소다 1kg, 1개, 1kg'],
#  ['닥터오앤 보식 습관 볶음 곡물 선식, 50g, 14개'],
#  ['21년햇초 괴산청결 고춧가루1kg/국내산100%/고추가루/청양/매운맛/보통맛/haccp가공/고추장용, 김치양념용1kg(보통맛)'],
#  ['쿡앤베이크 깨찰빵 프리믹스, 1kg, 1개'],
#  ['백설 오븐용 머핀 믹스, 500g, 10개'],
#  ['곡물가게궁 리얼팥물, 5g, 10개입'],
#  ['칠갑농산 식혜가루, 240g, 1개'],
#  ['미래웰푸드 콘플레이크 다시마차 40p, 800g, 1개'],
#  ['화미 볶음 콩가루, 800g, 1팩'],
#  ['킹아더 언블리치드 브레드 플로어, 2.27kg, 1개'],
#  ['곰곰 새싹보리가 들어간 오트쉐이크, 1kg, 1개'],
#  ['노브랜드 간편한 감자전믹스, 3팩, 200g'],
#  ['백설 박력 밀가루, 1kg, 2개'],
#  ['현재농원 박찬웅 메밀가루, 350g, 1개'],
#  ['튼튼닷컴 웰빙한끼생식 30 g x 28 포, 840g, 1개'],
#  ['아몬드 분말 100% 1 kg/아몬드 가루/냉각 시스템으로 유분 억제, 1개'],
#  ['해표 지리산 100% 우리밀 통밀가루 1.5kg 청정지역에서 재배된 국내산, 1개'],
#  ['태광선식 한끼선식, 20g, 30개'],
#  ['Yes!Global Atta Whole Wheat Flour 아타 통밀 밀가루 (5kg India Rajdhani), 1팩, 5kg'],
#  ['화미 고춧가루 김치용 매운맛, 1kg, 1개'],
#  ['우리농가수 고춧가루 명품 조미 순한맛, 1kg, 1개'],
#  ['성진 이스트 용기형 70g + 지퍼형 60g x 3p 세트, 1세트'],
#  ['2021년 국산 미강 1kg 저두강 쌀겨 팩 미강가루, 1kg 1개'],
#  ['배대감 국산 고소한 33곡 미숫가루, 4개, 1kg'],
#  ['초보자용 막걸리만들기 누룩 1kg+효모 20g 세트, 우리밀(국내산)누룩+전용효모'],
#  ['아르고 퓨어 콘 스타치 글루텐 프리, 454g, 1개'],
#  ['[백설] 우리밀 튀김가루, 500g, 3봉'],
#  ['큐원홈메이트 와플믹스 500g x 2개'],
#  ['TORIMALL 간편하게 부쳐먹는 백설 김치전 210gx3개 김치전믹스 김치전가루 컵부침개, 백설 김치전 210g 3개'],
#  ['브레드가든 하트쿠키믹스, 200g, 1개'],
#  ['국산 메밀 가루 100% 순메밀 분말 1kg'],
#  ['메티에 그린티 파우더, 320g, 1개'],
#  ['백설 도넛믹스, 1kg, 2개'],
#  ['배대감 옥수수맛 전분, 350g, 4개'],
#  ['우리밀 [우리농촌살리기공동네트워크] 무농약 백밀가루, 800g, 1개'],
#  ['국내산 100프로 옥수수 감자 고구마 전분맛 용기, 햇살빚은 옥수수전분맛 400g용기'],
#  ['곰표 우리밀 밀가루, 900g, 3개'],
#  ['백설 도넛믹스, 1kg, 2개'],
#  ['배대감 옥수수맛 전분, 350g, 4개'],
#  ['우리밀 [우리농촌살리기공동네트워크] 무농약 백밀가루, 800g, 1개'],
#  ['국내산 100프로 옥수수 감자 고구마 전분맛 용기, 햇살빚은 옥수수전분맛 400g용기'],
#  ['곰표 우리밀 밀가루, 900g, 3개'],
#  ['토종마을 국산 현미쌀눈 1kg, 1개'],
#  ['럼포드 콘 스타크 넌-GMO 글루텐 프리, 340g, 1개'],
#  ['복이네먹거리 국산 안매운 고추가루 소스용 순한맛, 500g, 1개'],
#  ['사계절약초 국내산 수수가루 300g, 1개'],
#  ['보향다원 유기농 녹차가루 그린티라떼, 200g, 1개'],
#  ['태광선식 간편형 스마트 미숫가루, 50개입, 24g'],
#  ['누내츄럴스 뉴그레인 오트 파이버 비건, 454g, 1개'],
#  ['잇츠온 하루곡물 달달미숫가루, 50g, 20개'],
#  ['백설 중력2등 밀가루 20kg'],
#  ['파인소프트T 믹스가루, 1kg, 1개'],
#  ['고르다선식 영양 선식가루, 1개'],
#  ['오양식품 안동 참마 건강밀, 800g, 1개'],
#  ['발아3곡든 곡물한끼, 35g, 30개입'],
#  ['식자재왕 고구마전분 99%, 1kg, 1개'],
#  ['나우푸드 코코넛 플라어, 454g, 1개'],
#  ['브레드가든 BG 초코 머핀믹스, 380g, 1개'],
#  ['곰표 바사삭 와플믹스, 1kg, 1개'],
#  ['청은 감자전분, 400g, 2개'],
#  ['자연미가 유기농 녹차가루, 300g, 1개'],
#  ['봉평촌 국내산 메밀 부침가루, 800g, 1개'],
#  ['범표 실고추 10g x 5개'],
#  ['삿갓유통 국산 고춧가루 일반굵기, 300g, 1개'],
#  ['곰표 부침가루, 500g, 20개'],
#  ['백설 아메리칸 와플믹스, 10kg, 1개'],
#  ['젤오 젤라틴 디저트 젤리 믹스 85g, 체리(Cherry), 1개'],
#  ['Foods Alive 뉴트리셔널 이스트, 170g, 1개'],
#  ['기라델리 프리미엄 브라우니 믹스, Triple Fudge, 1개'],
#  ['배대감 메밀가루, 400g, 4개'],
#  ['백설 CJ제일제당 감자 수제비 가루 500g * 4개'],
#  ['본고장 건더기스프 250g 우동끓이기 우동후레이크 오뎅스프 건조동결야채, 1개'],
#  ['산촌마을 인절미 볶은 콩가루, 100g, 3개'],
#  ['대한제분 곰표 호도과자가루, 10kg, 1개'],
#  ['변산 메밀 부침가루, 500g, 1개'],
#  ['청은 메밀가루, 1kg, 1개'],
#  ['국산 보리가루, 4kg'],
#  ['뿌띠 해초가루, 130g, 1개'],
#  ['청오 국산 유기농 볶음 콩가루, 200g, 1개'],
#  ['키토라푸드 글루텐프리 아몬드가루, 1kg, 1개'],
#  ['Maseca 인스턴트 옐로우 콘 마사 플라워, 1kg, 1개'],
#  ['브레드가든 플레인 스콘 믹스, 250g, 1개'],
#  ['국내산 100% 도토리 녹말 가루 / 2021년 햇 도토리 가루 (강원도 충청도 도토리 )/ 도토리 묵 가루 / 도토리 전분 1 KG'],
#  ['곰표 밀가루 중력다목적용, 1kg, 2개'],
#  ["Bob's Red Mill 라지 플레이크 뉴트리셔널 이스트, 142g, 1개"],
#  ['밥스레드밀 통곡물 현미 가루 홀 그레인, 680g, 1개'],
#  ['곰표 밀가루 중력다목적용, 3kg, 6개'],
#  ['곰표 핫도그가루 2호, 2kg, 5개입'],
#  ['태광선식 바른선식, 1kg, 1개'],
#  ['쿡앤베이크 국산보리 70% 함유 보리떡믹스(용량선택), 3kg, 1개'],
#  ['백설 찰 밀가루, 1kg, 10개'],
#  ['삼정농산 쌀겨, 600g, 3팩+서비스300g1팩'],
#  ['성진식품 도토리묵가루, 500g, 1개'],
#  ['청년곡물 100% 국산 볶은율무가루 500g, 1팩'],
#  ['오뚜기 찹쌀 미니 도나스 믹스가루, 500g, 1개'],
#  ['오뚜기 찹쌀호떡믹스 540g 2개 + 핫케이크믹스 500g 2개, 오뚜기 찹쌀호떡믹스 2개 + 핫케이크믹스 500g 2개'],
#  ['베티크로커 초콜릿 칩 쿠키 믹스, 496g, 1개'],
#  ['뚜레반 콩국수용 콩가루, 850g, 1개'],
#  ['CJ 밸런스밀 4종 (귀리2 고구마2 바나나3 견과3), 상세정보참조, 상세정보참조'],
#  ['보리떡용가루 (황금)보리떡용가루3kg, 3kg, 1봉'],
#  ['오설록 프리미엄 말차, 40g, 1개'],
#  ['화이바솔 2 난소화성말토덱스트린 식이섬유 분말, 1kg, 1개'],
#  ['식용 베이킹 소다, 1kg, 3개'],
#  ["Bob's Red Mill 글루텐 프리 베이킹 밀가루, 1.24kg, 1개"],
#  ['국산 생 현미가루(분말) 1kg, 1개'],
#  ['청년곡물 100% 볶은귀리가루 1kg, 2개'],
#  ['브레드가든 비앤씨마켓 마법 쿠키 믹스, 1개, 1kg'],
#  ['총각네 영양보강 선식, 30g, 10개입'],
#  ['배대감 고구마맛 전분, 500g'],
#  ['밥스레드밀 콘스타치, 510g, 1개'],
#  ['오뚜기 찹쌀호떡믹스 540g, 4개'],
#  ['금꽃식용금가루200mg 순수국산금가루, 200mg, 1'],
#  ['꼬미다 한천 분말, 500g, 1개'],
#  ['백설 식빵믹스760gx3개, 1세트'],
#  ['태광선식 검은콩이들어간 블랙푸드 미숫가루, 1.5kg, 2개'],
#  ['CJ제일제당 밸런스밀 귀리X20개, 단품, 단품'],
#  ['배대감 20곡 미숫가루, 4개, 1kg'],
#  ['곰표 밀가루 박력, 2.5kg, 4개'],
#  ['동아식품 타피오카 일반전분, 20kg, 1개'],
#  ['성진 찹쌀 가루, 400g, 3개'],
#  ['컬러푸드 검은콩 검은깨 선식, 1개, 검은콩+검은깨'],
#  ['우리가스토리 아몬드 볶음 분태, 1개, 500g'],
#  ['화미 고춧가루 미분용, 2.5kg, 1개'],
#  ['푸른빈 붕붕 붕어빵 믹스 가루, 1kg, 1개'],
#  ['사쿠다금박 유리병 식용금가루300mg 코마카(작은입자)먹는금 먹는금가루, 300mg, 1개'],
#  ['에로우헤드밀즈 오트 플로어 저지방 홀 그레인, 453g, 1개'],
#  ['젤라틴가루, 300g'],
#  ['백세식품 매스틱정 프리미엄, 36g, 2개'],
#  ['오뚜기 오쉐프 빵가루 습식빵가루 생빵가루 식빵가루, 옵션1. 오뚜기 바삭한 생빵가루 2kg'],
#  ['대한제분 중력 밀가루 2등급, 20kg, 1개'],
#  ['닥터페퍼 고운 고춧가루, 1kg, 1개'],
#  ['유스마일 내몸에착한 밀기울, 600g, 1개'],
#  ['쿠킹스토리 흑임자가루, 1개, 100g'],
#  ['(동아식품) 타피오카 전분 1kg * 5개 (밀가루 찹쌀 대용)'],
#  ['뚜레반 콩국수용 콩가루, 850g, 3개입'],
#  ['베트남 고운 고춧가루, 1kg, 1개'],
#  ['코코랩 곡물&효소 요거트&콜라겐 단호박*옥수수수염 50g*5팩 코코랩 한끼 리뉴얼 신제품, 코코랩 한끼 라이트 곡물&효소 50gx5팩'],
#  ['오큐비 알파옥수수 가루, 5kg, 1개'],
#  ['복이네먹거리 국산 안매운고추가루 (어린이김치용 순한맛), 1kg, 1개'],
#  ['오뚜기 찹쌀 미니도나스 믹스, 500g, 14개입'],
#  ['고려홍삼절편 + 쇼핑백, 20g, 10개'],
#  ['신제품~곰표 수플레 팬케익믹스 420g(팬케익믹스160gx2 커스터드믹스 100g), 1개, 420g'],
#  ['청은 볶음콩가루, 1kg, 2개'],
#  ['이든타운 커스터드분말, 1kg, 1개'],
#  ['밥스레드밀 언블리치드 화이트 올-퍼포즈 플로어 무설탕, 2.27kg, 1개'],
#  ['쿠킹스토리 슈가파우더, 500g, 1개'],
#  ['태광선식 검은콩 미숫가루, 700g, 1개'],
#  ['구도 계피가루, 1kg, 1개'],
#  ['호밀가루 A-0571, 3kg, 1개'],
#  ['해오름 굵은 고춧가루 매운맛, 1kg, 1개'],
#  ['곰곰 오트 쉐이크, 25g, 28개입'],
#  ['헝그리잭 팬케이크 & 와플 믹스 버터밀크, 1개, 907g'],
#  ['브레드가든 진저브레드 멀티 쿠키믹스, 1개, 1kg'],
#  ['화왕산 메주가루, 1개'],
#  ['국산 햇 고운 고추가루 500g/ 국내산고춧가루, 500g x 1개'],
#  ['바른약초 간편하게 아마씨가루(볶음), 1kg, 1개'],
#  ['키알라 유기농 중력밀가루, 1kg, 1개'],
#  ['청솔 콩국가루, 850g, 1개'],
#  ['예이니식품 오뚜기 튀김가루+부침가루 각1개씩(총2개x500g) 부침개파전김치새우, 1세트'],
#  ['오뚜기 식소다 100g, 2개'],
#  ['스위트사워믹스 사워믹스(스위트 삼조 동원 1K) X 10, 1kg, 1개'],
#  ['장명식품 병아리콩 볶음가루, 1kg, 1개'],
#  ['청은 찹쌀가루 국산, 1kg, 1개'],
#  ['뚜레반 찹쌀가루 국산 A+, 3kg, 1개'],
#  ['청은 식소다, 150g, 10개'],
#  ['청양농부 100%국내산 매운 햇고추씨가루, 1kg'],
#  ['영농조합법인안동엿기름 누룩, 850g, 1개'],
#  ['가득찬 순볶음 들깨가루, 1kg, 1개'],
#  ['보성제다 유기농 아름다운 보성 가루녹차, 50g, 1개'],
#  ['복이네먹거리 국산 햇고추가루 김치 / 김장용 보통맛, 1kg, 1개'],
#  ['청은 17곡 미숫가루, 2개, 1kg'],
#  ['오일러스 감자전분, 400g, 1개'],
#  ['맷돌표 아주존 식소다 60g, 3개'],
#  ['코알라 프라임골드빵가루 2kg (아이스박스 아이스팩), [2290-0]프라임 골드굵은빵가루 2kg 코알라'],
#  ['행복우리식품 프리미엄 현미 마죽 선식가루 스틱형, 30g, 40개'],
#  ['태광선식 서리태콩물 쉐이크 선식가루, 1개, 40g x 6개입'],
#  ['복이네먹거리 베트남고추가루 김치 찜용, 2.5kg, 1개'],
#  ['슈펴라이스 고소한 우유백설기 20개입 (40gx20개입), 없음'],
#  ['크루스티즈 컴플리트 팬케이크 믹스 버터밀크, 1개, 907g'],
#  ['상세페이지 참조 폴렌타(디벨라), 500g, 1개'],
#  ['동원홈푸드 스위트사워믹스 1kg, 1개'],
#  ['이너블릭 젤라틴 가루 분말, 1000g, 1개'],
#  ['고르다 블랙선식, 1개, 1kg'],
#  ['신선약초 보성 녹차분말가루, 300g, 1개'],
#  ['국산 생 수수분말(가루) 500g, 1개'],
#  ["Bob's Red Mill 블랜치드 아몬드 밀가루, 907g, 1개"],
#  ['밥스레드밀 골든 콘 플라워 마사 하리나, 680g, 1개'],
#  ['SK바이오랜드 푸로찜 에스(연육제) 1kg'],
#  ['심플리오가닉 카옌, 82g, 1개'],
#  ['[오가닉스토리] 오가닉스토리 유기농 찹쌀가루, 500g'],
#  ['큐원 중력 밀가루, 20kg, 1개'],
#  ['곰표 찰진햇밀가루, 3kg, 1개'],
#  ['화미 고춧가루 한식용, 2.5kg, 1개'],
#  ['밥스레드밀 타피오카 플로어, 454g, 1개'],
#  ['국산 도토리 묵 가루 300g 분말 국내산 100% 21년 햇 도토리, 1개'],
#  ['쿡앤베이크 인스턴트 드라이이스트 4g, 1개'],
#  ['곰표 박력밀가루 20kg 1등급 케잌전용분 박력분'],
#  ['붕어빵믹스 붕붕믹스 붕어빵반죽 붕어빵재료 1kg, 1개'],
#  ['청은 식소다, 2kg, 1개'],
#  ['이경제원장의 건강보감 이경제 더힘찬 선식100, 120포, 30g'],
#  ['농부의뜰 감자전분, 1kg, 2개'],
#  ['푸른빈 쌀 가루 분말 100% 국내산, 2개, 1kg'],
#  ['누리원 고춧가루, 1kg, 1개'],
#  ['뿌띠 유기농 율피가루- 피지 모공관리, 1개, 85'],
#  ['뫼달해 청양 고추가루, 38g, 1개'],
#  ['키토라푸드 글루텐프리 아몬드가루, 500g, 1개'],
#  ['배대감 감자맛전분, 350g, 1개'],
#  ['진주곡자앉은뱅이 밀 누룩, 1kg, 1개'],
#  ['드라이이스트 500g 2종 샤프 인스턴트 이스트 레드 골드 효모 제과제빵용 바게트용, 골드500g'],
#  ['오허브 옥수수전분 NON GMO 100%, 1개, 1kg'],
#  ['암앤해머 베이킹소다 6.12kg 2개 + 빈즈물티슈10매, 1세트'],
#  ['일본 나리주카 말차가루 100g/녹차가루/그린파우더/우지마차, 우지 말차가루 100g'],
#  ['달곰베이킹 오징어먹물추출분말, 1개, 100g'],
#  ['베스톰 드라이이스트 4g 20개, 1개'],
#  ['대현상회 국산 고추씨가루 세트, 300g, 4개'],
#  ['고르다선식 블랙 선식가루, 1개, 500g'],
#  ['가루선생 흑임자 소이 라떼 가루, 300g, 1개'],
#  ['넛츠베리 참식품 보리떡용가루, 3kg, 2개'],
#  ['조은약초 프리미엄 볶은 홍화씨 가루, 300g, 2개'],
#  ['이홈베이킹 녹차가루 100g, 단품'],
#  ['브레드가든 인스턴트 드라이이스트 라빠리장 4g*8개입 홈베이킹, 4g, 8개'],
#  ['21년 수확한 국산 햇 고춧가루 1kg 5가지 맵기와 굵기, (04)매운청양아주곱게500g * 1팩'],
#  ['화미_생찹쌀가루100%(국산/면세), 300g, 2팩'],
#  ['보의당 박경호 통곡물 한끼 선식가루, 40개, 30g'],
#  ['진주곡자 우리밀 누룩, 1kg, 1개'],
#  ['바리스타퀸 플러스 요거트 파우더, 1kg, 1개'],
#  ['백설 찹쌀 호떡믹스, 400g, 3개'],
#  ['청은에프엔비 국산 찹쌀가루, 300g, 2개'],
#  ['산과들 국내산 100% 건식 찹쌀가루 3kg'],
#  ['푸른빈 메밀가루, 1kg, 1개'],
#  ['큐원 우리아이영양쿠키믹스, 250g, 2개'],
#  ['휴나인 100% 순수 국산 생 들깨 분말 가루 300g, 1개'],
#  ['곡물가게궁 리얼팥물, 5g, 10개입'],
#  ['식품명인 김영근의 100%국산 도토리묵가루120g 7봉+건조묵50g 1봉, 없음, 상세설명 참조'],
#  ['곰표 밀가루 중력다목적용, 2.5kg, 2개'],
#  ['복만네 콩국수용 콩가루, 1개, 850g'],
#  ['햇살나래 식소다, 1kg, 1개'],
#  ['복이네먹거리 고춧가루 매운맛 김치용 상, 1kg, 1개'],
#  ['청은 고구마전분 국산, 1kg, 1개'],
#  ['복이네먹거리 떡볶이용 고추가루 소스용 순한맛, 1kg, 1개'],
#  ['[뚜나샵] 오뚜기 부침가루1kg 1개 + 튀김가루 1kg 1개'],
#  ['굿허브 하동 가루녹차, 300g, 1개'],
#  ['할매손 들깨가루, 1kg, 1개'],
#  ['베티크로커 딜라이트 슈퍼 모이스트 케이크 믹스 레드 벨벳, 432g, 1개'],
#  ['기타 임실치즈가 듬뿍 구워먹는 임실치즈떡 2봉'],
#  ['밥스레드밀 스톤 그라운드 홀 위트 패스트리, 2.27kg, 1개'],
#  ['초록들 생콩가루, 1kg, 1개'],
#  ['밥스레드밀 홈스타일 팬케이크 & 와플 믹스, 1개, 680g'],
#  ['올가홀푸드 슈퍼곡물 퀴노아를 더한 블랙 미숫가루, 500g, 1개'],
#  ['우영식품 찹쌀가루, 1kg, 1개'],
#  ['브레드가든 레드벨벳 머핀믹스, 340g, 1개'],
#  ['[오뚜기] 쉐이크앤팬 핫케이크믹스 150gx3개, 오리지널'],
#  ['푸르벨 녹차가루 A-0862, 1kg, 1개'],
#  ['백설 박력 1등 밀가루, 20kg, 1개'],
#  ['예천 볶지않은 국산 생들깨가루200gX1병'],
#  ['해오름 통곡물 현미 하우스 막걸리 키트 분말 250g + 효소 15g, 1세트'],
#  ['밥스레드밀 애로우루트 스타치 글루텐 프리, 454g, 1개'],
#  ['21년 청정식품 HACCP 국산 태양초 햇 고춧가루 고은가루 1kg CJA001-7, CJA001-7_국산 고운 고춧가루 1kg'],
#  ['대한제분 곰표 피자용 밀가루, 10kg, 1개'],
#  ['프리미엄 웰선식 클래식, 20개, 50g'],
#  ['뚜레반 땅콩가루, 1kg, 1개'],
#  ['PAN 콘밀 옥수수가루 화이트 CORNMEAL 1kg, 1봉'],
#  ['밸런스밀 고구마, 50g, 1개'],
#  ['백설 냉면다시다300g, 단일 수량'],
#  ['뿌띠 백복령가루 곡물팩 한방팩, 110g, 1개'],
#  ['붕어빵믹스-1kg, 1개'],
#  ['밸런스밀 견과, 1개, 50g'],
#  ['그린통상 찹쌀가루 1kg (냉동/습식) *아이스박스포장'],
#  ['오뚜기 달걀하나톡넣는 쌀컵케이크 스윗바나나, 60g, 16개'],
#  ['쿡앤베이크 꿀물이 주루륵~ 송편소 겸용 호떡속 1kg'],
#  ['청수식품 [무료배송]우동다시 1.8L 8개 국물의 참맛, 1개'],
#  ['쿡앤베이크 물우유만 넣어 만드는 스콘 & KFC비스켓 믹스 500g, 1개'],
#  ['모리나가 핫케익 믹스, 600g, 1개'],
#  ['쿠킹스토리 아몬드 분말, 60g, 5개'],
#  ['화왕산산성누룩 쌀분말누룩(얼굴팩용 기미 주근깨 미백 보습)1kg, 1kg, 1개'],
#  ['백설 브라우니 믹스, 320g, 3개'],
#  ['셀핀다 가바100% 1500mg, 1'],
#  ['코알라 프라임골드 빵가루 2kg 2개 습식빵가루'],
#  ['푸드림 아몬드분말100% 1Kg+1Kg (넌패럴)-햇견과 키토빵 마카롱 제빵, 1kg, 2개'],
#  ['아몬푸드 헤이즐넛분말, 300g, 1개'],
#  ['백설 찹쌀호떡믹스, 400g, 2개'],
#  ['해썹인증 국내 안심제조 중국산 고춧가루, 굵은굵기[김치용], 1kg'],
#  ['청오 무농약 원료 미숫가루, 500g, 1개'],
#  ['엄마사랑 통곡물이 고소한 미숫가루, 2.8kg, 1개'],
#  ['올가니카 식물성 채식쉐이크 스마트밀 OMG 카카오, 770g, 1개'],
#  ['중화요리 짬뽕용 순한맛 고추가루, 1kg, 1개'],
#  ['가루선생 흑임자 소이 라떼, 500g, 1개'],
#  ['하이네 한끼든든 19곡 미숫가루, 50개, 20g'],
#  ['행복우리식품 현미 양배추죽 선식가루 스틱형, 25g, 40개'],
#  ['행성 건빵가루 8kg 대용량, 1포'],
#  ['화미_감자전분(99%) 3KG 1팩'],
#  ['백설 초코츄러스맛 호떡믹스300G, 1개'],
#  ['해가원 옥수수전분 300g'],
#  ['초야 참이맛 미숫가루, 1kg, 10개입'],
#  ['해피베이비 어린이 팬케이크 & 와플 믹스, 1개, 226g'],
#  ['승진F&C 베이킹파우다(승진 맷돌표 아주존 150g)X2, 1개'],
#  ['어니언 시즈닝 가루, 500g, 1개'],
#  ['아리울떡공방 굳지않는 백미 앙금절편 1kg, 없음'],
#  ['푸른빈 도토리 묵 가루 분말 국내산, 2개, 500g'],
#  ['연세백세생식 30g x 100포 하루1포 (25포 x 4박스), 기타'],
#  ['실로팜 카사바 플로어, 680g, 1개'],
#  ['밥스레드밀 내추럴 아몬드 플라어, 453g, 1개'],
#  ['농협 아름찬 쌀튀김가루, 500g, 7개'],
#  ['IoM 유산균막걸리 키트, 600g, 1개'],
#  ['키알라 유기농 통밀가루, 1kg, 1개'],
#  ['PINA / 암앤해머 베이킹소다 2100g 베이킹소다/과일세척베이킹소다/탄산수소나트륨/주방청소/빨래삶기, 단일 수량, 홀LET상품'],
#  ['증안리약초마을 쥐눈이콩분말, 500g, 1개'],
#  ['성진식품 녹두가루, 1kg, 1개'],
#  ['안동옛맛된장 고추장용 메주가루, 1000g, 1개'],
#  ['이츠웰 고소한 하얀빵가루, 1kg, 1개'],
#  ["Bob's Red Mill 글루텐 프리 베이킹 밀가루, 624g, 1개"],
#  ['잇츠온 하루 곡물 블랙 그레인, 40g, 20개'],
#  ['FAMSCUBEFK 박력 밀가루(백설 1K), 단품'],
#  ['포베이커 햇쌀마루 홍국쌀가루 기능성쌀 컬러쌀 50g (소분상품)'],
#  ['복이네먹거리 국산 검은깨가루, 300g, 1개'],
#  ['CJ백설찹쌀호떡믹스, 400g, 1개'],
#  ['화미 복합 감자맛 전분, 3kg, 1개'],
#  ['백세식품 프리미엄 국내산 여주정 90정, 54g, 2개'],
#  ['(국산) 2021년 햇빛찬 청결 햇고춧가루 1kg (김치용 보통맛)'],
#  ['성진 찹쌀 가루 용기형, 500g, 2개'],
#  ['담백한 베지밀에이 검은콩두유 6박스/총 96팩, 상세 설명 참조, 단일옵션'],
#  ['암앤해머 베이킹소다 6.12kg 1개 + 빈즈물티슈10매, 1세트'],
#  ['[오가닉스토리] 오가닉스토리 유기농 쌀가루, 500g, 1개'],
#  ['구도 아몬드가루, 1kg, 1개'],
#  ['[브레드가든] 체망필요없는 슈가파우더 통 210g 2개입, 단품'],
#  ['고미네 볶은현미가루, 500g, 1개'],
#  ['백설 우리쌀로 만든 바삭 튀김가루, 1kg, 2개'],
#  ['산과들에 더 고소한 블랙 미숫가루 스틱 20g 100봉, 1개'],
#  ['태광선식 귀리우유 쉐이크, 30g, 10개입'],
#  ['청오 무농약 원료 미숫가루, 1kg, 1개'],
#  ['누리원 고춧가루, 1kg, 1개'],
#  ['백설 CJ백설 다목적면용20kg 밀가루20kg, 수량, 20kg'],
#  ['호주키알라 유기농팬케익믹스(오리지날믹스1병+오리지날믹스1병), 1세트, 345g'],
#  ['뚜레반 팥가루, 1kg, 1개'],
#  ['국산 최상급 고춧가루 500g+2개 김치양념용 찌게'],
#  ['신대감 옹고집 고추가루 보통맛 찜 무침용, 1kg, 1개'],
#  ['이슬나라 월계수잎, 1개, 230g'],
#  ['호주키알라 유기농팬케익믹스(오리지날믹스1병+오리지날믹스1병), 1세트, 345g'],
#  ['뚜레반 팥가루, 1kg, 1개'],
#  ['국산 최상급 고춧가루 500g+2개 김치양념용 찌게'],
#  ['신대감 옹고집 고추가루 보통맛 찜 무침용, 1kg, 1개'],
#  ['이슬나라 월계수잎, 1개, 230g'],
#  ['브레드가든 뉴욕 스타일 와플믹스, 1kg, 1개'],
#  ['이홈베이킹 라빠리장드라이이스트4g x 10개, 4g'],
#  ['전통과 장인정신이 깃든 백준호 효소마을 쥐눈이콩 청국장가루 1kg'],
#  ['생율무가루 500g + 볶은율무가루 500g, 1세트'],
#  ['[천천중국식품]뉴나이 우유가루 300g, 1개'],
#  ['[이경제원장의 건강보감] 이경제 더힘찬 선식100 60포+쉐이커, 60포, 30g'],
#  ['뚜레반 12곡 미숫가루, 1kg, 1개'],
#  ['방앗간청년 빈속에도 속이 편한 옛날 보리 미숫가루 선식, 1개, 1kg'],
#  ['[올가홀푸드] 유기튀김가루, 350g, 1개'],
#  ['오뚜기 부침가루, 1kg, 4개'],
#  ['백설 중력밀가루 면 부침 만두 밀가루, 1kg, 2개'],
#  ['베티크로커 다이너소어 쿠키 키트, 1개, 328g'],
#  ['백세식품 빌베리정, 92g, 1개'],
#  ['크루스티즈 프로틴 팬케이크 믹스 버터밀크 홀 그레인, 1개, 566g'],
#  ['비스퀵 믹스 4봉 - 홈베이킹/허니버터/버터밀크, 02_버터밀크X2봉, 01_허니버터X2봉'],
#  ['이든타운 화이바솔-2 1kg - 난소화성 말토덱스트린 식이섬유 증량제'],
#  ['수제나라 자연의숲 들깨분말 들깨가루 들깨가루팩 천연분말, 들깨분말 50g'],
#  ['쿡앤베이크 붕어빵믹스 길거리 노점표 500g, 1개'],
#  ['뚜레반 식소다, 1kg, 4개입'],
#  ['백설 강력 밀가루, 2.5kg, 2개'],
#  ['벅스웨이 일회용 떡볶이 분말스프, 10개'],
#  ['58가지 원료 하루생식 4주 28포, 28팩'],
#  ['웰프로틴 그레인, 15개, 40g'],
#  ['[코스빅몰] 삼립 촉촉 우유 치즈케익 70g*10입'],
#  ['(상온)[백설]초코칩쿠키믹스290gx4'],
#  ['백설 튀김가루, 500g, 20개'],
#  ['처음햇살 고춧가루 국내산 김치 깍두기용 청양매운맛, 1kg, 1개'],
#  ['성진식품 고구마전분맛, 1kg, 1개'],
#  ['셋째딸농부 통밀 와플믹스 핫케이크 가루 우리밀 현미 식사대용, 85g, 10봉'],
#  ['복이네먹거리 국산 청양고춧가루 매운맛 김치용, 150g, 1개'],
#  ['화미 생찹쌀가루, 1kg, 1개'],
#  ['고미네 볶은 렌틸콩가루, 500g, 1개'],
#  ['성진식품 베이킹파우더 150g, 1개'],
#  ['일년래래 햇살담은 베트남 아주매운맛 미분용 고춧가루, 1kg, 1개'],
#  ['국산 산초 가루 산초 분말 100g, 1개'],
#  ['태광선식 국산선식35, 700g, 1개'],
#  ['배대감 12곡 미숫가루, 4개, 1kg'],
#  ["Bob's Red Mill 오가닉 골든 플랙시드 밀, 453g, 1개"],
#  ['바이오믹스 한끼대신 오트볼 초콜릿 쉐이크 미숫가루, 24개, 50g'],
#  ['밥스레드밀 바이탈 위트 프로틴 글루텐 베이킹 플라어, 1개, 567g'],
#  ['양반 바삭 부침가루, 1kg, 10개입'],
#  ['크루스티즈 글루텐 프리 팬케이크 믹스 버터밀크 라이트 & 플러피 홀 그레인, 453g, 1개'],
#  ['타코야끼 파우더 1kg 소스 300g 세트 재료 분말 타코야키 반죽 다코야끼 문어 다코파우더, 타코파우더소스세트'],
#  ['지라이프 데일리밀 동결건조 선식가루 고소한맛, 1개, 600g'],
#  ['금정 산성누룩1kg 국내산 우리밀 누룩분말 막걸리제조, 단품'],
#  ['와일드하베스트 코코넛 플라어, 454g, 1개'],
#  ['고미네 볶은 아마씨분말, 1kg, 1개'],
#  ['큐원 홈메이드 파운드케익믹스, 500g, 10개'],
#  ['초야식품 참조은 개량메주가루, 1kg, 1개'],
#  ['가루랑 검정깨A 볶음 분말, 200g, 1개'],
#  ['삼정농산 쌀겨 생미강, 600g, 4개'],
#  ['오뚜기 초간편 김치전믹스 320g 2개 + 감자전믹스 200g 1개, 오뚜기 김치전믹스 2개 + 감자전믹스 1개'],
#  ['더 착한 국산콩비지 가루 500g 100% 한국콩으로 만든 유전자 변형 걱정 없는 비지가루'],
#  ['100% 국산 생감자로 만든 감자전분 1kg, 단품'],
#  ['신진식품 호떡속 믹스, 2kg, 1개'],
#  ['우리집농장 강원도 엿질금가루 1kg, 2개'],
#  ['포베이커 가림 황치즈맛 분말 황치즈가루 100g (소분상품)'],
#  ['아주 매운맛 베트남 땡초 고춧가루(고운용) 1kg, 1개'],
#  ['신일 빵가루 2kgX5개, 1박스, 10kg'],
#  ['[베이크]호밀가루(997)3kg/100%호밀/독일빵/호밀빵, 3kg, 1개'],
#  ['청년곡물 100% 볶은귀리가루 1kg, 3개'],
#  ['매일아침 볶은 유기농 100% 국산 귀리 가루 쉐이크 분말 700g 오트밀, 유기농 볶은귀리가루 700g, 1개'],
#  ['신선약초 율무가루, 300g, 1개'],
#  ['브레드가든 베이킹 소다, 1kg, 1개'],
#  ['(배터짐) 강력매운 베트남 고운고추가루 1kg 씨고추가루 청양고추 10배 맵다 고추가루 매운고추가루 통고추 건고추 베트남고추가루 마라탕 훠궈 건두부 푸주 마라샹궈 마라탕 훠궈, 1개, 베트남씨고추가루1kg'],
#  ['[할인한정판매] 볶음 아몬드 분말 1 kg/아몬드 가루/, 1개'],
#  ['베트남 미코 반쎄오 가루 분말 파우더 BOT BANH XEO 2개, 500g*2'],
#  ['해오름 100% 중국산 굵은 고춧가루, 1kg, 1개'],
#  ['오큐비(O.Q.B) 국산 생율무가루 500g 1개, 500g / 1개'],
#  ['백설 초코츄러스맛호떡믹스 300G, 2개'],
#  ['큐원 강력밀가루20kg 1등급, 20kg, 1개'],
#  ['명신한천 한천가루, 20g, 1개'],
#  ['브리오쉬 소보로 파우더 1kg 소보루 가루 소보로가루 곰보빵'],
#  ['100% 타피오카 전분 1kg 분말 가루, 1봉'],
#  ['참새방아 베트남고춧가루 땡초 500g - 고운고춧가루, 1개'],
#  ['바닐라빈 플라니폴리아(버번) 고메 A+ 등급 50g'],
#  ['모리나가 핫케익믹스 300g, 3개'],
#  ['이든타운 구아검 분말, 1kg, 1개'],
#  ['참쑥의 어린잎으로 만든 프리미엄 국산 쑥가루 쑥라떼 쑥차 쑥우유 분말 250g 500, 1개'],
#  ['팬케익믹스 큐원 홈메이드 팬케익믹스1kg(100g X 10입), 10개'],
#  ['CJ제일제당 통감자를 갈아 넣은 바삭부침가루, 1kg, 1개'],
#  ['중화요리 짬뽕용 고운입자 매운맛 혼합고추가루, 1kg, 1개'],
#  ['로럭스 아몬드 분말, 1kg, 1개'],
#  ['큐원 홈메이드 계란빵믹스 전자레인지용, 50g, 10개입'],
#  ['오뚜기 부침가루, 1kg, 2개'],
#  ['경기방앗간 국산 옛날 미숫가루 방앗간제조 1kg, 국산 미숫가루 1kg'],
#  ['베이킹얌 드라이이스트 3gx20개'],
#  ['1+1 현아몰 CJ 백설 부침 튀김 밀가루 1kg 튀김가루 부침가루, 1+1 CJ 백설 튀김가루 1kg'],
#  ['베티크로커 설탕 쿠키 믹스, 496g, 1개'],
#  ['해가원 깨끗한 고춧가루, 400g, 1개'],
#  ['윌튼 머랭 파우더 에그 화이트 서브스티튜트, 113g, 1개'],
#  ['오토 감자전분, 3kg, 1개'],
#  ['[춘장보다 맛있는] 짜장 만능소스 짜장요리 소스, 쏘다소스 짜장요리 1박스(10봉)'],
#  ['베트남고추가루1kg 베트남고춧가루, 베트남김치용고춧가루1kg'],
#  ['크루스티즈 파운드 케이크 믹스 메이어 레몬 글레이즈 포함, 1개, 467g'],
#  ['뚜레반 날콩가루, 1kg, 1개'],
#  ['CJ/제일제당/백설 2.5 1kg -1개/조미료/발효조미료, 1개입'],
#  ['방앗간사람들 국산 들깨 들깨가루, 300g'],
#  ['대주식품 고소한 블랙푸드 미숫가루, 1kg, 3개'],
#  ['하눅 통호밀가루, 400g, 1개'],
#  ['다이찌 돈까스 베타믹스 표준형 5kg, 다이찌베타믹스표준형*1'],
#  ['소맥분100% 활성밀글루텐 1kg, 1개'],
#  ['갑당약초 녹두가루, 300g, 1개'],
#  ['브레드가든 뉴욕스타일 와플믹스, 280g, 1개'],
#  ['오뚜기 초간편 감자전믹스, 200g, 5개'],
#  ['큐원 계란빵믹스 50g X 10입'],
#  ['회룡포장수진품 살짝 볶아 거피해 고소한 어머니들깨가루 (국산들깨100%사용), 250g, 1개'],
#  ['곰표 밀가루 중력다목적용, 1kg, 5개'],
#  ['오뚜기 부침가루, 500g, 3개'],
#  ['참고을 햇살가득한 참고을 고춧가루, 1kg, 1개'],
#  ['곰표와플파이믹스10kg 1+1 2포, 10kg+10kg'],
#  ['산아래 토종 우리 밀가루 앉은뱅이밀 백밀가루 박력분, 3kg, 1개'],
#  ['젤오 젤라틴 디저트 젤리 믹스 85g, 레몬(Lemon), 1개'],
#  ['맛뜨락 국산콩 100% 생콩가루200g국내산, 단품, 단품'],
#  ['베티크로커 슈퍼 모이스트 케이크 믹스 밀크 초콜릿, 432g, 2개'],
#  ['곰표와플파이믹스10kg 1+1 2포, 10kg+10kg'],
#  ['산아래 토종 우리 밀가루 앉은뱅이밀 백밀가루 박력분, 3kg, 1개'],
#  ['젤오 젤라틴 디저트 젤리 믹스 85g, 레몬(Lemon), 1개'],
#  ['맛뜨락 국산콩 100% 생콩가루200g국내산, 단품, 단품'],
#  ['베티크로커 슈퍼 모이스트 케이크 믹스 밀크 초콜릿, 432g, 2개'],
#  ['도깨비방앗간 중국산 고춧가루 보통맛 한식용, 1개, 3kg'],
#  ['막걸리 만들기 재료, 1개, 전용효모 20g'],
#  ['자연미가 고소한 기피 들깨가루, 1kg, 1개'],
#  ['국산 엿기름 240g 티백 식혜 재료 식혜만들기 국내산 보리 100%, 굿아이템 1'],
#  ['대주식품 슈퍼푸드 귀리 미숫가루, 1kg, 3개'],
#  ['오오무라 고마도후 참깨분말, 100g, 1개'],
#  ['권여사 녹차가루, 500g, 1개'],
#  ["Bob's Red Mill 포테이토 스타크, 623g, 1개"],
#  ['베티크로커 슈퍼 모이스트 케이크 믹스 버터 레시피 옐로우, 432g, 1개'],
#  ['글루텐프리 제빵용 쌀가루 (1kg) 쌀빵 비건식 밀가루프리 베지푸드 밀가루대체식 푸드림스, 개'],
#  ['50년전통대현상회 검은콩검은깨 영양선식 1kg, 1개'],
#  ['아티장 밀가루 T55, 2kg, 6개'],
#  ['[상주이장님농장] 21년산 국산 햇 고춧가루 반 태양초 청양 고추가루 (6단계 매운맛선택), 1봉, 가장매운맛(청양100%) -250g'],
#  ['고추연구소 굵은 고춧가루, 1kg, 1개'],
#  ['밥스레드밀 스톤 그라운드 병아리콩 가루 글루텐 프리, 453g, 1개'],
#  ['배대감 생 찹쌀가루, 500g, 4개'],
#  ['송학곡자 송학누룩 우리밀 누룩 1kg 2개 묶음'],
#  ['매일유업 소프트믹스 M5 1L x 2박스 12개 아이스크림, 2박스(12개)'],
#  ['소소생활 소소한끼 자색고구마 뮤즐리, 65g, 5개입'],
#  ['Crisco 올 베지터블 쇼트닝 버터 맛, 1.36kg, 1개'],
#  ['아침대용식 한끼대용 고소한 곡물 쉐이크 브이퀄 귀리 선식 5개, 귀리 1세트(5개입)'],
#  ['밥스레드밀 스톤 그라운드 통 밀가루, 2.27kg, 1개'],
#  ['우리가스토리 아몬드 가루, 1kg, 1개'],
#  ['오뚜기 찹쌀호떡믹스 540g 2개+찹쌀미니도나스 500g 1개+올따옴세정티슈 10매1개, 1세트'],
#  ['금꽃식용금가루50mg 순수국산금가루, 50mg, 1'],
#  ['아몬드 분말 95% 1kg/마카롱용/아몬드 가루/냉각 시스템으로 유분 억제, 1개'],
#  ['미세스버터월스 버터밀크 컴플리트 팬케이크 & 와플 믹스, 1개, 907g'],
#  ['자연웰 올방개묵가루, 500g, 1개'],
#  ['우지마차 믹스 말차가루, 100g, 2개'],
#  ['초록들 찹쌀가루, 500g, 1개'],
#  ['곰표 밀가루, 500g, 2개'],
#  ['칠갑농산 십곡 미싯가루, 1kg, 2개'],
#  ['바닐라빈 플라니폴리아(버번) 고메 A+ 등급 25g'],
#  ['보리가루 보리떡믹스 보리빵가루 3kg(무가당), 보리떡용믹스 3kg(무가당)'],
#  ['방앗간청년 쪄서 볶아 빈속에도 속이 편한 통곡물 미숫가루 선식, 1개, 500g'],
#  ...]

# %%
import pandas as pd
df=pd.DataFrame(total_data_list)

# %%
df.to_csv('wordtext7.txt',index=False)

# %%
from konlpy.tag import Twitter 
from collections import Counter

# %%
file = open('wordtext7.txt', 'r', encoding="UTF-8")

lists = file.readlines()

file.close()

#lists

# %%
twitter = Twitter() 
morphs = [] 

for sentence in lists: 
    morphs.append(twitter.pos(sentence)) 
print(morphs)
# Out:
# [[('0', 'Number'), ('\n', 'Foreign')], [('"', 'Punctuation'), ('지리산', 'Noun'), ('처럼', 'Josa'), ('행복한', 'Adjective'), ('정은', 'Noun'), ('씨', 'Suffix'), ('의', 'Josa'), ('고소한', 'Adjective'), ('들깨', 'Noun'), ('가루', 'Noun'), (',', 'Punctuation'), ('150', 'Number'), ('g', 'Alpha'), (',', 'Punctuation'), ('1', 'Number'), ('개', 'Noun'), ('"', 'Punctuation'), ('\n', 'Foreign')], [('"', 'Punctuation'), ('배', 'Noun'), ('대감', 'Noun'), ('들깨', 'Noun'), ('가루', 'Noun'), (',', 'Punctuation'), ('200', 'Number'), ('g', 'Alpha'), (',', 'Punctuation'), ('1', 'Number'), ('개', 'Noun'), ('"', 'Punctuation'), ('\n', 'Foreign')], [('"', 'Punctuation'), ('태', 'Noun'), ('광선', 'Noun'), ('식', 'Suffix'), ('국산', 'Noun'), ('서리', 'Noun'), ('태', 'Noun'), ('로', 'Josa'), ('더욱', 'Noun'), ('고소해진', 'Adjective'), ('귀리', 'Noun'), ('쉐이크', 'Noun'), (',', 'Punctuation'), ('1', 'Number'), ('개', 'Noun'), (',', 'Punctuation'), ('1.2', 'Number'), ('kg', 'Alpha'), ('"', 'Punctuation'), ('\n', 'Foreign')], [('"', 'Punctuation'), ('곰곰', 'Adverb'), ('국내', 'Noun'), ('산', 'Noun'), ('고춧가루', 'Noun'), (',', 'Punctuation'), ('250', 'Number'), ('g', 'Alpha'), (',', 'Punctuation'), ('1', 'Number'), ('개', 'Noun'), ('"', 'Punctuation'), ('\n', 'Foreign')], [('"', 'Punctuation'), ('곰곰', 'Adverb'), ('국내', 'Noun'), ('산', 'Noun'), ('고춧가루', 'Noun'), (',', 'Punctuation'), ('1', 'Number'), ('kg', 'Alpha'), (',', 'Punctuation'), ('1', 'Number'), ('개', 'Noun'), ('"', 'Punctuation'), ('\n', 'Foreign')], [('"[', 'Punctuation'), ('쿠팡', 'Noun'), ('직수입', 'Noun'), (']', 'Punctuation'), ('밥스', 'Noun'), ('레드', 'Noun'), ('밀', 'Noun'), ('베이', 'Noun'), ('킹', 'Noun'), ('파우더', 'Noun'), (',', 'Punctuation'), ('397', 'Number'), ('g', 'Alpha'), (',', 'Punctuation'), ('1', 'Number'), ('개', 'Noun'), ('"', 'Punctuation'), ('\n', 'Foreign')], [('"', 'Punctuation'), ('햇님', 'Noun'), ('마을', 'Noun'), ('국물', 'Noun'), ('땡기는', 'Verb'), ('국산', 'Noun'), ('고운', 'Adjective'), ('고춧가루', 'Noun'), ('보통', 'Noun'), ('매운', 'Adjective'), ('맛', 'Noun'), (',', 'Punctuation'), ('120', 'Number'), ('g', 'Alpha'), (',', 'Punctuation'), ('1', 'Number'), ('개', 'Noun'), ('"', 'Punctuation'), ('\n', 'Foreign')], [('"', 'Punctuation'), ('태', 'Noun'), ('광선', 'Noun'), ('식', 'Suffix'), ('옛날', 'Noun'), ('11', 'Number'), ('곡', 'Noun'), ('미숫가루', 'Noun'), (',', 'Punctuation'), ('2', 'Number'), ('kg', 'Alpha'), (',', 'Punctuation'), ('1', 'Number'), ('개', 'Noun'), ('"', 'Punctuation'), ('\n', 'Foreign')], [('"[', 'Punctuation'), ('쿠팡', 'Noun'), ('직수입', 'Noun'), (']', 'Punctuation'), ('밥스', 'Noun'), ('레드', 'Noun'), ('밀', 'Noun'), ('유기농', 'Noun'), ('통밀', 'Noun'), ('가루', 'Noun'), (',', 'Punctuation'), ('2.27', 'Number'), ('kg', 'Alpha'), (',', 'Punctuation'), ('1', 'Number'), ('개', 'Noun'), ('"', 'Punctuation'), ('\n', 'Foreign')], [('"', 'Punctuation'), ('곰곰', 'Adverb'), ('간편한', 'Adjective'), ('미숫가루', 'Noun'), ('스틱', 'Noun'), (',', 'Punctuation'), ('24', 'Number'), ('g', 'Alpha'), (',', 'Punctuation'), ('50', 'Number'), ('개', 'Noun'), ('"', 'Punctuation'), ('\n', 'Foreign')], [('"', 'Punctuation'), ('배', 'Noun'), ('대감', 'Noun'), ('찹쌀', 'Noun'), ('가루', 'Noun'), (',', 'Punctuation'), ('1', 'Number'), ('kg', 'Alpha'), (',', 'Punctuation'), ('1', 'Number'), ('개', 'Noun'), ('"', 'Punctuation'), ('\n', 'Foreign')], [('"', 'Punctuation'), ('곰표', 'Noun'), ('밀가루', 'Noun'), (',', 'Punctuation'), ('1', 'Number'), ('kg', 'Alpha'), (',', 'Punctuation'), ('10', 'Number'), ('개', 'Noun'), ('"', 'Punctuation'), ('\n', 'Foreign')], [('"', 'Punctuation'), ('백설', 'Noun'), ('5', 'Number'), ('가지', 'Noun'), ('자연', 'Noun'), ('에서', 'Josa'), ('얻은', 'Verb'), ('재료', 'Noun'), ('부침', 'Verb'), ('가루', 'Noun'), (',', 'Punctuation'), ('1', 'Number'), ('kg', 'Alpha'), (',', 'Punctuation'), ('1', 'Number'), ('개', 'Noun'), ('"', 'Punctuation'), ('\n', 'Foreign')], [('"', 'Punctuation'), ('백설', 'Noun'), ('박력', 'Noun'), ('밀가루', 'Noun'), (',', 'Punctuation'), ('2.5', 'Number'), ('kg', 'Alpha'), (',', 'Punctuation'), ('1', 'Number'), ('개', 'Noun'), ('"', 'Punctuation'), ('\n', 'Foreign')], [('"',  ...

# %%
noun_adj_adv_list=[] 
for sentence in morphs : 
    for word, tag in sentence : 
        if tag in ['Noun'] and("믹스" not in word)and("인분" not in word)and ("입" not in word)and("세트" not in word)and("팩" not in word)and("산" not in word)and("것" not in word)and("냉동" not in word)and("개" not in word)and("냉장" not in word)and("용" not in word)and ("내" not in word)and ("나" not in word)and ("수"not in word) and("게"not in word)and("말"not in word): 
            noun_adj_adv_list.append(word) 

print(noun_adj_adv_list)
# Out:
# ['정은', '들깨', '가루', '배', '대감', '들깨', '가루', '태', '광선', '서리', '태', '더욱', '귀리', '쉐이크', '고춧가루', '고춧가루', '쿠팡', '밥스', '레드', '밀', '베이', '킹', '파우더', '햇님', '마을', '국물', '고춧가루', '보통', '맛', '태', '광선', '옛날', '곡', '미숫가루', '쿠팡', '밥스', '레드', '밀', '유기농', '통밀', '가루', '미숫가루', '스틱', '배', '대감', '찹쌀', '가루', '곰표', '밀가루', '백설', '가지', '자연', '재료', '가루', '백설', '박력', '밀가루', '오뚜기', '찹쌀', '호떡', '햇쌀', '마루', '박력', '쌀', '가루', '베이', '킹', '배', '대감', '들깨', '가루', '백설', '핫케익', '곰표', '중력', '밀가루', '배', '대감', '볶음', '콩가루', '자연', '하루', '애', '생식', '스페셜', '해', '오름', '고춧가루', '맛', '오뚜기', '가루', '백설', '우리', '쌀', '바삭', '튀김', '가루', '곰표', '밀가루', '중', '목적', '오뚜기', '가루', '큐비', '감자전', '농부', '뜰', '감자전', '배', '대감', '곡', '미숫가루', '다농', '청정', '제주', '유기', '가루', '녹차', '햇님', '마을', '양념', '고춧가루', '보통', '맛', '백설', '중력', '밀가루', '오뚜기', '핫케이크', '햇님', '마을', '국물', '고춧가루', '매우', '맛', '웰넛', '자연', '두레', '아몬드', '서리', '태', '더욱', '귀리', '쉐이크', '백설', '바삭', '빵가루', '르사프', '드라이', '이스트', '백설', '찰', '밀가루', '백설', '강력', '밀가루', '쿠킹', '스토리', '아몬드', '가루', '생', '율무', '가루', '들깨', '껍질', '날', '들깨', '가루', '곰표', '강력', '밀가루', '오뚜기', '바삭', '튀김', '가루', '보', '의당', '박경호', '통', '곡물', '끼', '선', '가루', '엄마', '사랑', '아침', '통', '곡물', '선', '배', '대감', '이스트', '배', '대감', '미숫가루', '백설', '찹쌀', '호떡', '백설', '중력', '밀가루', '쿠킹', '스토리', '슈크림', '붕어빵', '만들기', '붕어빵', '슈크림', '청', '감자전', '고춧가루', '그대로', '탈피', '들깨', '가루', '백설', '식빵', '오뚜기', '베이', '킹소', '약초', '생', '율무', '엄마', '사랑', '아침', '검정', '콩', '선', '웰넛', '자연', '두레', '아몬드', '스웰', '마카롱', '아몬드', '랜덤', '발송', '오뚜기', '빵가루', '태', '광선', '서리', '태', '더욱', '귀리', '쉐이크', '오뚜기', '튀김', '가루', '곡', '미싯', '가루', '청정', '우리', '밀', '튀김', '가루', '브레드', '가든', '무', '알루미늄', '베이', '킹', '파우더', '습관', '아마', '가루', '복', '먹거리', '고춧가루', '보통', '맛', '찜', '상', '넛츠', '베리', '식품', '보리', '가루', '백설', '인절미', '호떡', '오뚜기', '쌀', '핫케이크', '농부', '뜰', '감자전', '농부', '뜰', '가루', '빅마마', '이혜정', '시크릿', '코인', '총', '쿠팡', '밥스', '레드', '밀', '유기농', '통밀', '가루', '청', '맛', '전분', '아몬드', '밀가루', '대신', '글루텐', '프리', '타피오카', '전분', '오일러', '스', '들깨', '가루', '양념', '청양', '고춧가루', '컬러', '푸드', '콩가루', '곰표', '밀가루', '쿠팡', '밥스', '레드', '밀', '액티브', '드라이', '이스트', '배', '대감', '통', '들깨', '가루', '청오', '유기농', '쌀', '가루', '구월', '아침', '서리', '태', '콩물', '가루', '콩가루', '배', '대감', '생', '찹쌀', '가루', '화', '농협', '가루', '녹차', '샘', '안동', '참마', '백설', '초코케익', '오일러', '스', '들깨', '가루', '쿠킹', '스토리', '가루', '큐비', '알파', '가루', '대한', '업', '보성', '유기농', '가루', '녹차', '백설', '찰', '밀가루', '곰표', '우리', '밀', '밀가루', '컬러', '푸드', '들깨', '가루', '담터', '마가', '곡', '미숫가루', '컴', '리트', '버터', '밀크', '팬케이크', '앤', '와플', '오토', '감자전', '신', '핫케익', '쿠', '모찌', '곰표', '아메리칸', '와플', '뉴', '케어', '데이', '밀', '슈퍼', '블랙', '선', '가루', '청정', '우리', '밀', '가루', '백설', '붕어빵', '베이', '킹', '파우더', '복', '먹거리', '들깨', '가루', '오설록', '프리미엄', '가루', '녹차', '햇', '고춧가루', '가지', '맵', '기와', '일반', '아주', '곱', '백설', '아메리칸', '와플', '랩노쉬', '식사', '마', '일드', '카카오', '백설', '박력', '밀가루', '복', '먹거리', '청양고추', '가루', '김치', '맛', '쿠킹', '스토리', '브뤼셀', '와플', '쿠킹', '스토리', '아몬드', '가루', '우리', '유기농', '우리', '밀', '통밀', '가루', '백설', '영양', '균형', '핫케익', '초야', '식품', '식혜', '만들기', '오뚜기', '치킨', '튀김', '가루', '신', '핫케익', '쿠', '모찌', '새한', '콩', '고물', '태', '광선', '콩', '블랙', '푸드', '미숫가루', '커피빈', '헤이즐넛', '파우더', '백설', '중력', '밀가루', '복', '먹거리', '베트남', '고추', '가루', '소스', '우리', '밀로', '옛날', '통밀', '가루', '배', '대감', '날', '콩가루', '큐비', '가루', '태', '광선', '옛날', '곡', '미숫가루', '영양', '고춧가루', '보통', '청', '맛', '전분', '청', '베이킹파우더', '우리', '밀로', '옛날', '통밀', '가루', '백설', '가루', '브레드', '가든', '무', '알루미늄', '베이킹파우더', '베이', '킹소', '계량', '스푼', '증', '약초', '마을', '서리', '태', '해', '오름', '고춧가루', '맛', '카', '식물성', '채식', '쉐이크', '스마트', '밀', '복', '먹거리', '베트남', '고춧가루', '소스', '들깨', '껍질', '날', '들깨', '가루', '오뚜기', '초', '간편', '김치전', '뚜레반', '전분', '뚜레반', '찹쌀', '가루', '곰표', '튀김', '가루', '우리', '스토리', '오', '마이', '오트', '귀리', '농부', '뜰', '튀김', '가루', '핫케익', '유기농', '생쌀', '가루', '쿠팡', '밥스', '레드', '밀', '베이', '킹', '파우더', '제분', '강력', '밀가루', '제빵', '다농', '청정', '제주', '유기농', '가루', '녹차', '오뚜기', '도', '뿌띠', '누룩', '잡티', '기미', '관리', '누룩', '동원', '빵가루', '쿠킹', '스토리', '호밀', '가루', '큐비', '아몬드', '곰표', '가루', '곰표', '가루', '브레드', '가든', '초코', '칩', '쿠키', '태양', '초', '고춧가루', '양념', '웰넛', '자연', '두레', '아몬드', '브레드', '가든' ...

# %%
count = Counter(noun_adj_adv_list)

# %%
words = dict(count.most_common())

# %%
from wordcloud import WordCloud 
import matplotlib.pyplot as plt 
import nltk 
from nltk.corpus import stopwords

# %%
# %matplotlib inline 

import matplotlib 
from matplotlib import rc
rc('font', family='NanumBarunGothic')

# %%
from wordcloud import WordCloud

wordcloud = WordCloud(
    font_path = 'C:/Users/win10/workspace/font/NanumBarunGothic.ttf',    # 맥에선 한글폰트 설정 잘해야함.
    background_color='white',                             # 배경 색깔 정하기
    colormap = 'Accent_r',                                # 폰트 색깔 정하기
    width = 800,
    height = 800
)

wordcloud_words = wordcloud.generate_from_frequencies(words)

# %%
array = wordcloud.to_array()
print(type(array)) # numpy.ndarray
print(array.shape) # (800, 800, 3)

fig = plt.figure(figsize=(10, 10))
plt.imshow(array, interpolation="bilinear")
plt.axis('off')
plt.show()
fig.savefig('business_anlytics_worldcloud.png')
# Out:
# <class 'numpy.ndarray'>
# (800, 800, 3)
